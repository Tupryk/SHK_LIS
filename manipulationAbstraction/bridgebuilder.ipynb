# %%
import robotic as ry
import numpy as np
import random
from bridgebuild_env import create_n_boxes

# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robot_execution as robex

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
list = ["boxes1"]
list[-1]
# Out:
# 'boxes1'

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
for l in range(3):
    box = np.random.choice(boxes)
    qStart = C.getJointState()
    graspDirection = "x"  # random.choice(['y', 'z']) #'x' not possible: box too large
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {l}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1e-1, accumulated_collisions=True
    )
    M.grasp_box(1.0, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if l > 1:
        offset_xyz = [0.0, 0.0, 0.00]
        poses_from_memory = np.vstack(
            (
                C.getFrame(last_box_memory[-2]).getPosition(),
                C.getFrame(last_box_memory[-1]).getPosition(),
            )
        )
        middle_between_towers = np.mean(poses_from_memory, 0) + offset_xyz

        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.08])

        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e3], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

    if l == 1:
        M.place_box(2.0, box, table, palm, placeDirection)

        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.positionRel,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1.0],
            [0.0, 0.0, 0.1],
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if l == 0:
        M.place_box(2.0, box, table, palm, placeDirection)

        M.target_relative_xy_position(
            2.0, box, table, [np.random.uniform(0.0, 0.3), np.random.uniform(0.0, 0.3)]
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    ways = M.solve()

    if not M.feasible:
        print("True")
        continue

    M2 = M.sub_motion(0)
    # M = manip.ManipulationModelling(C, info, helpers=[gripper])
    # M.setup_point_to_point_motion(qStart, ways[0])
    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.13)
    M2.approach([0.8, 1.0], gripper)
    M2.solve()
    if not M2.feasible:
        continue

    M3 = M.sub_motion(1)
    # manip.ManipulationModelling(C, info)
    # M.setup_point_to_point_motion(ways[0], ways[1])
    M3.keep_distance([], table, box)

    M3.solve()
    if not M3.ret.feasible:
        continue

    M2.play(C)
    C.attach(gripper, box)
    M3.play(C)
    C.attach(table, box)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]


del M
# Out:
# === placement 0: grasp x place z
# place direction: z
#   -- feasible:placement 0: grasp x place z
#      { time: 0.040058, evals: 67, done: 1, feasible: 1, sos: 0.0951737, f: 0, ineq: 0.00620283, eq: 0.360138 }
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.120397, evals: 35, done: 1, feasible: 1, sos: 3.0043, f: 0, ineq: 1.3489e-07, eq: 0.320239 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.283716, evals: 128, done: 1, feasible: 1, sos: 0.187263, f: 0, ineq: 0.00589613, eq: 0.323675 }
# === placement 1: grasp x place z
# place direction: z
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.028481, evals: 64, done: 1, feasible: 0, sos: 0.0594516, f: 0, ineq: 0.225673, eq: 0.830157 }
# True
# === placement 2: grasp x place z
# place direction: z
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 29
#      25 if l > 1:
#      26     offset_xyz = [0.0, 0.0, 0.00]
#      27     poses_from_memory = np.vstack(
#      28         (
# ---> 29             C.getFrame(last_box_memory[-2]).getPosition(),
#      30             C.getFrame(last_box_memory[-1]).getPosition(),
#      31         )
#      32     )
#      33     middle_between_towers = np.mean(poses_from_memory, 0) + offset_xyz
#      35     dir_vec = (
#      36         C.getFrame(last_box_memory[-2]).getPosition()
#      37         - C.getFrame(last_box_memory[-1]).getPosition()
#      38     )
#
# IndexError: list index out of range

# %% [markdown]
# ### On real robot: BotOp

# %%
import robotic as ry
import numpy as np
from bridgebuild_env import create_n_boxes
import robot_execution as robex
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import random

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=False)
bot.goHome(C)
# Out:
# -- bot.cpp:~BotOp:128(0) shutting down BotOp...
# -- simulation.cpp:~BotThreadedSim:56(0) shutting down SimThread
# -- simulation.cpp:~Simulation:149(0) shutting down Simulation

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
paths = []
vis = 1
n_success = 0
boxz = [box1, box3, box2]
while n_success <= 2:
    box = np.random.choice(boxes)
    # box = boxz[n_success]
    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])  # z grasp removed
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1.2e-1, accumulated_collisions=True
    )
    M.grasp_box(0.5, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if n_success > 1:
        print(f"3rd Block: ({box})")
        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.08])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

        print("Grasp Direction:", graspDirection)
        # M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

        if graspDirection == "x":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductXZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        elif graspDirection == "y":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductYZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        """
        else:
           M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])
        """

    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        # initial_pos= [0.020433060890705013, 0.08433819136314634]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2.0, box, table, initial_pos)
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    ways = M.solve()

    if not M.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
        )
        continue
    print("Submotion 0")
    M2 = M.sub_motion(0)

    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.13)
    M2.approach([0.8, 1.0], gripper)
    paths.append(M2.solve())

    if not M2.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :("
        )
        continue

    M3 = M.sub_motion(1)

    M3.keep_distance([], table, box)
    if n_success > 1:
        M3.retract([0.0, 0.2], gripper, dist=0.13)
        M3.approach([0.8, 1.0], gripper)

    paths.append(M3.solve())
    if not M3.ret.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :("
        )
        continue

    M_report = M.komo.report(True)

    # M_report = M.fetch_name_error_type(M_report)
    # M.print_name_error_type(M_report)

    M2_report = M2.komo.report(True)
    # M2_report = M.fetch_name_error_type(M2_report)
    # M.print_name_error_type(M2_report)

    M3_report = M3.komo.report(True)
    # M3_report = M.fetch_name_error_type(M3_report)
    # M.print_name_error_type(M3_report)

    if vis == 0:
        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)

    bot.execute_path_blocking(C, path=paths[-2])
    C.attach(gripper, box)
    bot.grasp(C)

    bot.execute_path_blocking(C, path=paths[-1])
    C.attach(table, box)
    bot.release(C)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1

del M
# Out:
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.0018653962896680865, 0.061389785509479114]
#   -- infeasible:placement 0: grasp x place z
#      { time: 0.037368, evals: 76, done: 1, feasible: 0, sos: 0.110786, f: 0, ineq: 0.355542, eq: 0.637972 }
# Failed placing block number 1 with grasp direction x at M :(
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.07412127515250598, 0.02719723582725946]
#   -- feasible:placement 0: grasp y place z
#      { time: 0.060259, evals: 110, done: 1, feasible: 1, sos: 0.0935443, f: 0, ineq: 0.00205773, eq: 0.0354692 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp y place z
#      { time: 0.114294, evals: 45, done: 1, feasible: 1, sos: 2.89664, f: 0, ineq: 4.00514e-07, eq: 0.0113155 }
#   -- infeasible:sub_motion_1--placement 0: grasp y place z
#      { time: 0.171734, evals: 54, done: 1, feasible: 0, sos: 0.0614107, f: 0, ineq: 0.00867853, eq: 0.510517 }
# Failed placing block number 1 with grasp direction y at M3 :(
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box1)
# Trying xy pos:  [0.02573945359204055, 0.0014434072392282673]
#   -- feasible:placement 0: grasp y place z
#      { time: 0.102089, evals: 200, done: 1, feasible: 1, sos: 0.272112, f: 0, ineq: 0.141927, eq: 0.294917 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp y place z
#      { time: 0.23674, evals: 94, done: 1, feasible: 1, sos: 4.64589, f: 0, ineq: 2.9932e-05, eq: 0.0142758 }
#   -- feasible:sub_motion_1--placement 0: grasp y place z
#      { time: 0.094406, evals: 28, done: 1, feasible: 1, sos: 0.378987, f: 0, ineq: 0.00141307, eq: 0.0202491 }
# -- kin_physx.cpp:addJoint:299(0) ADDING JOINT l_panda_joint7-box1 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:893(0) REMOVING JOINT 0x5042cf0-0x5c78ee0 of type rigid
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- feasible:placement 1: grasp x place z
#      { time: 0.048901, evals: 88, done: 1, feasible: 1, sos: 0.194748, f: 0, ineq: 0.416835, eq: 0.205124 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.096419, evals: 28, done: 1, feasible: 1, sos: 7.0394, f: 0, ineq: 8.77819e-07, eq: 0.00525315 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.148548, evals: 47, done: 1, feasible: 1, sos: 0.0795449, f: 0, ineq: 0.000926242, eq: 0.00959396 }
# -- kin_physx.cpp:addJoint:299(0) ADDING JOINT l_panda_joint7-box2 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:893(0) REMOVING JOINT 0x5042cf0-0x557a3d0 of type rigid
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093024, evals: 201, done: 1, feasible: 0, sos: 0.173722, f: 0, ineq: 0.0319956, eq: 0.818841 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.043319, evals: 92, done: 1, feasible: 0, sos: 0.23077, f: 0, ineq: 0.109419, eq: 2.4929 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090727, evals: 200, done: 1, feasible: 0, sos: 0.173771, f: 0, ineq: 0.0323517, eq: 0.819676 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091453, evals: 201, done: 1, feasible: 0, sos: 0.250276, f: 0, ineq: 0.254456, eq: 2.29826 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089354, evals: 201, done: 1, feasible: 0, sos: 0.263521, f: 0, ineq: 0.167364, eq: 2.25138 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.051292, evals: 98, done: 1, feasible: 0, sos: 0.228799, f: 0, ineq: 0.239995, eq: 3.19191 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.101072, evals: 200, done: 1, feasible: 0, sos: 0.173714, f: 0, ineq: 0.0322863, eq: 0.817106 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091688, evals: 200, done: 1, feasible: 0, sos: 0.19063, f: 0, ineq: 0.0337234, eq: 0.840963 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09558, evals: 201, done: 1, feasible: 0, sos: 0.199588, f: 0, ineq: 0.0811216, eq: 2.84312 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089961, evals: 200, done: 1, feasible: 0, sos: 0.190817, f: 0, ineq: 0.0335949, eq: 0.843749 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087823, evals: 200, done: 1, feasible: 0, sos: 0.17364, f: 0, ineq: 0.0320765, eq: 0.817509 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093624, evals: 200, done: 1, feasible: 0, sos: 0.173715, f: 0, ineq: 0.032454, eq: 0.820083 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090153, evals: 200, done: 1, feasible: 0, sos: 0.191016, f: 0, ineq: 0.033107, eq: 0.848428 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.099473, evals: 200, done: 1, feasible: 0, sos: 0.173145, f: 0, ineq: 0.0309005, eq: 0.813757 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092897, evals: 201, done: 1, feasible: 0, sos: 0.263677, f: 0, ineq: 0.161084, eq: 2.19435 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089482, evals: 200, done: 1, feasible: 0, sos: 0.190889, f: 0, ineq: 0.0334931, eq: 0.844764 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089388, evals: 201, done: 1, feasible: 0, sos: 0.235136, f: 0, ineq: 0.331425, eq: 2.44263 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090375, evals: 201, done: 1, feasible: 0, sos: 0.263209, f: 0, ineq: 0.161726, eq: 2.21794 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090407, evals: 201, done: 1, feasible: 0, sos: 0.267222, f: 0, ineq: 0.190242, eq: 2.24807 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090447, evals: 200, done: 1, feasible: 0, sos: 0.173155, f: 0, ineq: 0.0309805, eq: 0.812107 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093578, evals: 200, done: 1, feasible: 0, sos: 0.17382, f: 0, ineq: 0.0325153, eq: 0.818648 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089132, evals: 201, done: 1, feasible: 0, sos: 0.265394, f: 0, ineq: 0.198436, eq: 2.24477 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.066368, evals: 139, done: 1, feasible: 0, sos: 0.197442, f: 0, ineq: 0.0757862, eq: 3.18072 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090461, evals: 200, done: 1, feasible: 0, sos: 0.267948, f: 0, ineq: 0.177264, eq: 2.21758 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093353, evals: 188, done: 1, feasible: 0, sos: 0.199024, f: 0, ineq: 0.0902989, eq: 2.97368 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087429, evals: 200, done: 1, feasible: 0, sos: 0.248173, f: 0, ineq: 0.262647, eq: 2.28961 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091963, evals: 201, done: 1, feasible: 0, sos: 0.268001, f: 0, ineq: 0.164908, eq: 2.20285 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089052, evals: 200, done: 1, feasible: 0, sos: 0.250274, f: 0, ineq: 0.223253, eq: 2.27081 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091773, evals: 200, done: 1, feasible: 0, sos: 0.174674, f: 0, ineq: 0.0332285, eq: 0.830374 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090475, evals: 201, done: 1, feasible: 0, sos: 0.173729, f: 0, ineq: 0.0322774, eq: 0.81889 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08959, evals: 200, done: 1, feasible: 0, sos: 0.175978, f: 0, ineq: 0.0344657, eq: 0.844614 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089227, evals: 200, done: 1, feasible: 0, sos: 0.173748, f: 0, ineq: 0.0323822, eq: 0.820193 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091696, evals: 201, done: 1, feasible: 0, sos: 0.173076, f: 0, ineq: 0.0318294, eq: 0.814027 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091024, evals: 201, done: 1, feasible: 0, sos: 0.250182, f: 0, ineq: 0.250029, eq: 2.27692 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088741, evals: 200, done: 1, feasible: 0, sos: 0.173142, f: 0, ineq: 0.0319409, eq: 0.815429 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.096908, evals: 198, done: 1, feasible: 0, sos: 0.23112, f: 0, ineq: 0.102152, eq: 2.42708 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08879, evals: 200, done: 1, feasible: 0, sos: 0.264372, f: 0, ineq: 0.158293, eq: 2.26405 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08841, evals: 201, done: 1, feasible: 0, sos: 0.190922, f: 0, ineq: 0.033146, eq: 0.845299 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090281, evals: 200, done: 1, feasible: 0, sos: 0.173777, f: 0, ineq: 0.0327914, eq: 0.819771 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090668, evals: 201, done: 1, feasible: 0, sos: 0.176962, f: 0, ineq: 0.034069, eq: 0.8426 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08594, evals: 200, done: 1, feasible: 0, sos: 0.235425, f: 0, ineq: 0.332416, eq: 2.44733 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088811, evals: 200, done: 1, feasible: 0, sos: 0.190727, f: 0, ineq: 0.0328695, eq: 0.840311 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088869, evals: 200, done: 1, feasible: 0, sos: 0.173393, f: 0, ineq: 0.0319265, eq: 0.816302 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.074203, evals: 163, done: 1, feasible: 0, sos: 0.173451, f: 0, ineq: 0.0318391, eq: 0.816006 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088383, evals: 201, done: 1, feasible: 0, sos: 0.17393, f: 0, ineq: 0.0326149, eq: 0.819329 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089943, evals: 200, done: 1, feasible: 0, sos: 0.191039, f: 0, ineq: 0.0340157, eq: 0.848086 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.050907, evals: 103, done: 1, feasible: 0, sos: 0.222465, f: 0, ineq: 0.116921, eq: 3.88265 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088573, evals: 201, done: 1, feasible: 0, sos: 0.173473, f: 0, ineq: 0.032239, eq: 0.815986 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08913, evals: 201, done: 1, feasible: 0, sos: 0.173927, f: 0, ineq: 0.0324198, eq: 0.81915 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085845, evals: 200, done: 1, feasible: 0, sos: 0.243155, f: 0, ineq: 0.272168, eq: 2.34439 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089359, evals: 200, done: 1, feasible: 0, sos: 0.190567, f: 0, ineq: 0.0337127, eq: 0.838491 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090747, evals: 201, done: 1, feasible: 0, sos: 0.173534, f: 0, ineq: 0.0302416, eq: 0.818391 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.032089, evals: 70, done: 1, feasible: 0, sos: 0.191008, f: 0, ineq: 0.148718, eq: 2.45079 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090187, evals: 201, done: 1, feasible: 0, sos: 0.251352, f: 0, ineq: 0.239149, eq: 2.28362 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088098, evals: 201, done: 1, feasible: 0, sos: 0.173914, f: 0, ineq: 0.0323094, eq: 0.821676 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.053066, evals: 116, done: 1, feasible: 0, sos: 0.193497, f: 0, ineq: 0.184918, eq: 2.19908 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089186, evals: 200, done: 1, feasible: 0, sos: 0.176007, f: 0, ineq: 0.0337268, eq: 0.84274 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087909, evals: 200, done: 1, feasible: 0, sos: 0.173557, f: 0, ineq: 0.0315456, eq: 0.817573 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089505, evals: 200, done: 1, feasible: 0, sos: 0.190738, f: 0, ineq: 0.0330391, eq: 0.841986 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09084, evals: 200, done: 1, feasible: 0, sos: 0.174061, f: 0, ineq: 0.0324193, eq: 0.820318 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088938, evals: 201, done: 1, feasible: 0, sos: 0.190492, f: 0, ineq: 0.0334228, eq: 0.841237 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089458, evals: 200, done: 1, feasible: 0, sos: 0.253301, f: 0, ineq: 0.229098, eq: 2.31698 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089081, evals: 201, done: 1, feasible: 0, sos: 0.173497, f: 0, ineq: 0.0320386, eq: 0.815011 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090314, evals: 201, done: 1, feasible: 0, sos: 0.173918, f: 0, ineq: 0.0326696, eq: 0.820276 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087447, evals: 200, done: 1, feasible: 0, sos: 0.26308, f: 0, ineq: 0.195112, eq: 2.29939 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.038221, evals: 85, done: 1, feasible: 0, sos: 0.191456, f: 0, ineq: 0.0924858, eq: 2.16597 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090916, evals: 201, done: 1, feasible: 0, sos: 0.1911, f: 0, ineq: 0.034239, eq: 0.849793 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088881, evals: 200, done: 1, feasible: 0, sos: 0.173827, f: 0, ineq: 0.0320618, eq: 0.818484 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.094181, evals: 192, done: 1, feasible: 0, sos: 0.200613, f: 0, ineq: 0.0713876, eq: 3.07609 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086152, evals: 195, done: 1, feasible: 0, sos: 0.227802, f: 0, ineq: 0.372382, eq: 2.44096 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08974, evals: 201, done: 1, feasible: 0, sos: 0.190802, f: 0, ineq: 0.0340309, eq: 0.844713 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088803, evals: 200, done: 1, feasible: 0, sos: 0.173625, f: 0, ineq: 0.0318869, eq: 0.818055 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087169, evals: 200, done: 1, feasible: 0, sos: 0.173827, f: 0, ineq: 0.0325345, eq: 0.820545 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08952, evals: 201, done: 1, feasible: 0, sos: 0.173474, f: 0, ineq: 0.032001, eq: 0.815901 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.048876, evals: 103, done: 1, feasible: 0, sos: 0.197778, f: 0, ineq: 0.0702445, eq: 2.97815 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095886, evals: 197, done: 1, feasible: 0, sos: 0.201327, f: 0, ineq: 0.0896333, eq: 2.73501 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090814, evals: 200, done: 1, feasible: 0, sos: 0.190632, f: 0, ineq: 0.0336716, eq: 0.840946 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089552, evals: 200, done: 1, feasible: 0, sos: 0.231111, f: 0, ineq: 0.36676, eq: 2.45654 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091056, evals: 201, done: 1, feasible: 0, sos: 0.25921, f: 0, ineq: 0.235609, eq: 2.28356 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092232, evals: 200, done: 1, feasible: 0, sos: 0.251784, f: 0, ineq: 0.255284, eq: 2.27089 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087252, evals: 201, done: 1, feasible: 0, sos: 0.226343, f: 0, ineq: 0.38272, eq: 2.46315 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090072, evals: 192, done: 1, feasible: 0, sos: 0.198008, f: 0, ineq: 0.0980415, eq: 2.50875 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087471, evals: 200, done: 1, feasible: 0, sos: 0.190963, f: 0, ineq: 0.0344703, eq: 0.845491 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087177, evals: 201, done: 1, feasible: 0, sos: 0.190347, f: 0, ineq: 0.0326232, eq: 0.833722 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089239, evals: 201, done: 1, feasible: 0, sos: 0.263799, f: 0, ineq: 0.152713, eq: 2.26093 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086223, evals: 200, done: 1, feasible: 0, sos: 0.249042, f: 0, ineq: 0.264782, eq: 2.28293 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087808, evals: 201, done: 1, feasible: 0, sos: 0.1736, f: 0, ineq: 0.0322878, eq: 0.816964 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085503, evals: 200, done: 1, feasible: 0, sos: 0.173293, f: 0, ineq: 0.0317765, eq: 0.815011 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087905, evals: 201, done: 1, feasible: 0, sos: 0.266306, f: 0, ineq: 0.194787, eq: 2.25638 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.06129, evals: 133, done: 1, feasible: 0, sos: 0.199697, f: 0, ineq: 0.0747656, eq: 3.18223 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086495, evals: 200, done: 1, feasible: 0, sos: 0.173631, f: 0, ineq: 0.0321903, eq: 0.817028 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086016, evals: 201, done: 1, feasible: 0, sos: 0.173769, f: 0, ineq: 0.0319927, eq: 0.819255 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087668, evals: 201, done: 1, feasible: 0, sos: 0.173522, f: 0, ineq: 0.0320485, eq: 0.817204 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085611, evals: 200, done: 1, feasible: 0, sos: 0.189152, f: 0, ineq: 0.0327557, eq: 0.819594 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08599, evals: 200, done: 1, feasible: 0, sos: 0.227091, f: 0, ineq: 0.374476, eq: 2.4125 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085831, evals: 201, done: 1, feasible: 0, sos: 0.175869, f: 0, ineq: 0.0348543, eq: 0.843435 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087182, evals: 200, done: 1, feasible: 0, sos: 0.173764, f: 0, ineq: 0.0324861, eq: 0.819266 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085605, evals: 200, done: 1, feasible: 0, sos: 0.173571, f: 0, ineq: 0.0323533, eq: 0.817544 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089035, evals: 200, done: 1, feasible: 0, sos: 0.17457, f: 0, ineq: 0.033301, eq: 0.825767 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087254, evals: 201, done: 1, feasible: 0, sos: 0.173303, f: 0, ineq: 0.0316613, eq: 0.812922 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086689, evals: 200, done: 1, feasible: 0, sos: 0.190423, f: 0, ineq: 0.0339233, eq: 0.836367 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080854, evals: 190, done: 1, feasible: 0, sos: 0.252634, f: 0, ineq: 0.249125, eq: 2.28959 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087588, evals: 201, done: 1, feasible: 0, sos: 0.237819, f: 0, ineq: 0.32907, eq: 2.44601 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086817, evals: 201, done: 1, feasible: 0, sos: 0.270287, f: 0, ineq: 0.114142, eq: 2.16458 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085903, evals: 200, done: 1, feasible: 0, sos: 0.173811, f: 0, ineq: 0.0324975, eq: 0.819016 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08833, evals: 201, done: 1, feasible: 0, sos: 0.173453, f: 0, ineq: 0.0321887, eq: 0.816857 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085921, evals: 201, done: 1, feasible: 0, sos: 0.249639, f: 0, ineq: 0.253803, eq: 2.27993 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087131, evals: 201, done: 1, feasible: 0, sos: 0.254704, f: 0, ineq: 0.24255, eq: 2.36917 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083084, evals: 184, done: 1, feasible: 0, sos: 0.201015, f: 0, ineq: 0.117275, eq: 3.57582 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086402, evals: 185, done: 1, feasible: 0, sos: 0.199967, f: 0, ineq: 0.0843812, eq: 2.79973 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08507, evals: 201, done: 1, feasible: 0, sos: 0.174044, f: 0, ineq: 0.0327299, eq: 0.820913 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087787, evals: 200, done: 1, feasible: 0, sos: 0.25955, f: 0, ineq: 0.230982, eq: 2.26592 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086097, evals: 200, done: 1, feasible: 0, sos: 0.190351, f: 0, ineq: 0.0341854, eq: 0.836022 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088727, evals: 201, done: 1, feasible: 0, sos: 0.173884, f: 0, ineq: 0.0322688, eq: 0.819716 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085705, evals: 200, done: 1, feasible: 0, sos: 0.190831, f: 0, ineq: 0.0341096, eq: 0.844434 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086291, evals: 201, done: 1, feasible: 0, sos: 0.173521, f: 0, ineq: 0.0320551, eq: 0.815583 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087563, evals: 200, done: 1, feasible: 0, sos: 0.257176, f: 0, ineq: 0.197763, eq: 2.30439 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085456, evals: 200, done: 1, feasible: 0, sos: 0.174794, f: 0, ineq: 0.0333971, eq: 0.830067 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087755, evals: 201, done: 1, feasible: 0, sos: 0.254645, f: 0, ineq: 0.245495, eq: 2.28941 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085902, evals: 200, done: 1, feasible: 0, sos: 0.263288, f: 0, ineq: 0.213223, eq: 2.2997 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088301, evals: 201, done: 1, feasible: 0, sos: 0.173721, f: 0, ineq: 0.0325728, eq: 0.81978 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086875, evals: 201, done: 1, feasible: 0, sos: 0.173641, f: 0, ineq: 0.0326336, eq: 0.818097 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.049973, evals: 109, done: 1, feasible: 0, sos: 0.200845, f: 0, ineq: 0.0789782, eq: 3.29503 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086975, evals: 201, done: 1, feasible: 0, sos: 0.173067, f: 0, ineq: 0.0315756, eq: 0.813377 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086247, evals: 201, done: 1, feasible: 0, sos: 0.191022, f: 0, ineq: 0.0336138, eq: 0.846592 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088552, evals: 198, done: 1, feasible: 0, sos: 0.25772, f: 0, ineq: 0.230917, eq: 2.28212 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086776, evals: 201, done: 1, feasible: 0, sos: 0.252077, f: 0, ineq: 0.234796, eq: 2.31417 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.106368, evals: 200, done: 1, feasible: 0, sos: 0.261391, f: 0, ineq: 0.204029, eq: 2.28786 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.095679, evals: 200, done: 1, feasible: 0, sos: 0.251601, f: 0, ineq: 0.237572, eq: 2.2866 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.103225, evals: 201, done: 1, feasible: 0, sos: 0.249711, f: 0, ineq: 0.249739, eq: 2.27688 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.04519, evals: 96, done: 1, feasible: 0, sos: 0.198686, f: 0, ineq: 0.0998805, eq: 3.1556 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095832, evals: 201, done: 1, feasible: 0, sos: 0.173845, f: 0, ineq: 0.0299556, eq: 0.817678 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.096043, evals: 201, done: 1, feasible: 0, sos: 0.260932, f: 0, ineq: 0.221607, eq: 2.28391 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094172, evals: 201, done: 1, feasible: 0, sos: 0.190834, f: 0, ineq: 0.0329244, eq: 0.844836 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.099937, evals: 201, done: 1, feasible: 0, sos: 0.17371, f: 0, ineq: 0.0318964, eq: 0.818508 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.104267, evals: 201, done: 1, feasible: 0, sos: 0.190993, f: 0, ineq: 0.0337826, eq: 0.848922 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.106686, evals: 199, done: 1, feasible: 0, sos: 0.1992, f: 0, ineq: 0.0926768, eq: 3.06851 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.100072, evals: 201, done: 1, feasible: 0, sos: 0.263578, f: 0, ineq: 0.156775, eq: 2.24243 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.094498, evals: 200, done: 1, feasible: 0, sos: 0.173905, f: 0, ineq: 0.032504, eq: 0.822392 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.093213, evals: 200, done: 1, feasible: 0, sos: 0.251243, f: 0, ineq: 0.240686, eq: 2.27561 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090934, evals: 201, done: 1, feasible: 0, sos: 0.173946, f: 0, ineq: 0.0325097, eq: 0.820191 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091033, evals: 201, done: 1, feasible: 0, sos: 0.173708, f: 0, ineq: 0.0322951, eq: 0.817819 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091402, evals: 200, done: 1, feasible: 0, sos: 0.175561, f: 0, ineq: 0.0347029, eq: 0.841017 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090133, evals: 200, done: 1, feasible: 0, sos: 0.263042, f: 0, ineq: 0.21116, eq: 2.27111 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091718, evals: 201, done: 1, feasible: 0, sos: 0.174072, f: 0, ineq: 0.0324016, eq: 0.823885 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087989, evals: 200, done: 1, feasible: 0, sos: 0.173631, f: 0, ineq: 0.0308785, eq: 0.818025 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089201, evals: 201, done: 1, feasible: 0, sos: 0.26509, f: 0, ineq: 0.196175, eq: 2.2832 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.028899, evals: 66, done: 1, feasible: 0, sos: 0.178132, f: 0, ineq: 0.127162, eq: 3.07026 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088012, evals: 200, done: 1, feasible: 0, sos: 0.190733, f: 0, ineq: 0.0317693, eq: 0.840823 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
# ...
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092443, evals: 201, done: 1, feasible: 0, sos: 0.174086, f: 0, ineq: 0.0315458, eq: 0.822931 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.09366, evals: 200, done: 1, feasible: 0, sos: 0.256652, f: 0, ineq: 0.24617, eq: 2.3058 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090363, evals: 200, done: 1, feasible: 0, sos: 0.173986, f: 0, ineq: 0.0325859, eq: 0.820505 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09061, evals: 201, done: 1, feasible: 0, sos: 0.173571, f: 0, ineq: 0.0305587, eq: 0.816329 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092231, evals: 201, done: 1, feasible: 0, sos: 0.190974, f: 0, ineq: 0.0342239, eq: 0.847178 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089637, evals: 200, done: 1, feasible: 0, sos: 0.250226, f: 0, ineq: 0.238907, eq: 2.32919 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08984, evals: 200, done: 1, feasible: 0, sos: 0.190484, f: 0, ineq: 0.0329689, eq: 0.838953 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089362, evals: 200, done: 1, feasible: 0, sos: 0.190798, f: 0, ineq: 0.0334689, eq: 0.843757 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090304, evals: 201, done: 1, feasible: 0, sos: 0.249182, f: 0, ineq: 0.257518, eq: 2.28617 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.074744, evals: 160, done: 1, feasible: 0, sos: 0.20345, f: 0, ineq: 0.254744, eq: 4.2828 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089812, evals: 200, done: 1, feasible: 0, sos: 0.22754, f: 0, ineq: 0.378768, eq: 2.43563 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088925, evals: 200, done: 1, feasible: 0, sos: 0.173688, f: 0, ineq: 0.032304, eq: 0.817359 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091544, evals: 201, done: 1, feasible: 0, sos: 0.175892, f: 0, ineq: 0.0345457, eq: 0.841628 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090962, evals: 201, done: 1, feasible: 0, sos: 0.173626, f: 0, ineq: 0.0319714, eq: 0.816065 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088767, evals: 200, done: 1, feasible: 0, sos: 0.262909, f: 0, ineq: 0.2161, eq: 2.29613 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091219, evals: 200, done: 1, feasible: 0, sos: 0.258752, f: 0, ineq: 0.237463, eq: 2.30297 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088968, evals: 201, done: 1, feasible: 0, sos: 0.17357, f: 0, ineq: 0.032348, eq: 0.816481 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089326, evals: 188, done: 1, feasible: 0, sos: 0.201162, f: 0, ineq: 0.11873, eq: 4.36949 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090909, evals: 201, done: 1, feasible: 0, sos: 0.174067, f: 0, ineq: 0.0329106, eq: 0.820588 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.093572, evals: 201, done: 1, feasible: 0, sos: 0.251635, f: 0, ineq: 0.227217, eq: 2.29855 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094843, evals: 200, done: 1, feasible: 0, sos: 0.250174, f: 0, ineq: 0.2491, eq: 2.30078 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.09739, evals: 200, done: 1, feasible: 0, sos: 0.190583, f: 0, ineq: 0.0328687, eq: 0.839915 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092718, evals: 200, done: 1, feasible: 0, sos: 0.190163, f: 0, ineq: 0.0334618, eq: 0.834987 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.093178, evals: 200, done: 1, feasible: 0, sos: 0.190811, f: 0, ineq: 0.0330469, eq: 0.843247 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.098885, evals: 201, done: 1, feasible: 0, sos: 0.19123, f: 0, ineq: 0.0343365, eq: 0.851172 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093166, evals: 200, done: 1, feasible: 0, sos: 0.175981, f: 0, ineq: 0.0339712, eq: 0.846463 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09042, evals: 200, done: 1, feasible: 0, sos: 0.174431, f: 0, ineq: 0.0332494, eq: 0.827052 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093989, evals: 199, done: 1, feasible: 0, sos: 0.197441, f: 0, ineq: 0.0972431, eq: 2.72356 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090202, evals: 200, done: 1, feasible: 0, sos: 0.26103, f: 0, ineq: 0.219302, eq: 2.26811 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090046, evals: 201, done: 1, feasible: 0, sos: 0.17355, f: 0, ineq: 0.0323028, eq: 0.816656 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094975, evals: 201, done: 1, feasible: 0, sos: 0.267168, f: 0, ineq: 0.130245, eq: 2.19941 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093338, evals: 201, done: 1, feasible: 0, sos: 0.173474, f: 0, ineq: 0.0314786, eq: 0.817617 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089021, evals: 201, done: 1, feasible: 0, sos: 0.248639, f: 0, ineq: 0.262889, eq: 2.29354 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089811, evals: 200, done: 1, feasible: 0, sos: 0.17335, f: 0, ineq: 0.0319615, eq: 0.816799 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088711, evals: 200, done: 1, feasible: 0, sos: 0.236243, f: 0, ineq: 0.327526, eq: 2.41767 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087373, evals: 200, done: 1, feasible: 0, sos: 0.185591, f: 0, ineq: 0.538172, eq: 2.49903 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090206, evals: 200, done: 1, feasible: 0, sos: 0.173754, f: 0, ineq: 0.0324159, eq: 0.816993 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092766, evals: 201, done: 1, feasible: 0, sos: 0.173933, f: 0, ineq: 0.0324415, eq: 0.82094 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.093186, evals: 201, done: 1, feasible: 0, sos: 0.258378, f: 0, ineq: 0.209849, eq: 2.25857 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092131, evals: 200, done: 1, feasible: 0, sos: 0.261937, f: 0, ineq: 0.218874, eq: 2.27201 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090632, evals: 200, done: 1, feasible: 0, sos: 0.256233, f: 0, ineq: 0.248901, eq: 2.29518 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091907, evals: 201, done: 1, feasible: 0, sos: 0.17298, f: 0, ineq: 0.0281471, eq: 0.812005 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092924, evals: 201, done: 1, feasible: 0, sos: 0.173856, f: 0, ineq: 0.0325672, eq: 0.819169 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092011, evals: 200, done: 1, feasible: 0, sos: 0.262074, f: 0, ineq: 0.219349, eq: 2.26825 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092156, evals: 200, done: 1, feasible: 0, sos: 0.173393, f: 0, ineq: 0.0318399, eq: 0.817291 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087785, evals: 196, done: 1, feasible: 0, sos: 0.173233, f: 0, ineq: 0.0318729, eq: 0.814133 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092007, evals: 201, done: 1, feasible: 0, sos: 0.262351, f: 0, ineq: 0.215154, eq: 2.26411 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.057251, evals: 120, done: 1, feasible: 0, sos: 0.198608, f: 0, ineq: 0.0610408, eq: 3.39935 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089576, evals: 201, done: 1, feasible: 0, sos: 0.174105, f: 0, ineq: 0.0327564, eq: 0.821482 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090695, evals: 200, done: 1, feasible: 0, sos: 0.173904, f: 0, ineq: 0.032393, eq: 0.819044 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092111, evals: 200, done: 1, feasible: 0, sos: 0.250364, f: 0, ineq: 0.236389, eq: 2.29519 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091024, evals: 201, done: 1, feasible: 0, sos: 0.173957, f: 0, ineq: 0.032345, eq: 0.820294 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
