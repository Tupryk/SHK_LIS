# %%
import robotic as ry
import numpy as np
import random
from bridgebuild_env import create_n_boxes

# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robot_execution as robex

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
list = ["boxes1"]
list[-1]
# Out:
# 'boxes1'

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
for l in range(3):
    box = np.random.choice(boxes)
    qStart = C.getJointState()
    graspDirection = "x"  # random.choice(['y', 'z']) #'x' not possible: box too large
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {l}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1e-1, accumulated_collisions=True
    )
    M.grasp_box(1.0, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if l > 1:
        offset_xyz = [0.0, 0.0, 0.00]
        poses_from_memory = np.vstack(
            (
                C.getFrame(last_box_memory[-2]).getPosition(),
                C.getFrame(last_box_memory[-1]).getPosition(),
            )
        )
        middle_between_towers = np.mean(poses_from_memory, 0) + offset_xyz

        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.08])

        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e3], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

    if l == 1:
        M.place_box(2.0, box, table, palm, placeDirection)

        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.positionRel,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1.0],
            [0.0, 0.0, 0.1],
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if l == 0:
        M.place_box(2.0, box, table, palm, placeDirection)

        M.target_relative_xy_position(
            2.0, box, table, [np.random.uniform(0.0, 0.3), np.random.uniform(0.0, 0.3)]
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    ways = M.solve()

    if not M.feasible:
        print("True")
        continue

    M2 = M.sub_motion(0)
    # M = manip.ManipulationModelling(C, info, helpers=[gripper])
    # M.setup_point_to_point_motion(qStart, ways[0])
    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.13)
    M2.approach([0.8, 1.0], gripper)
    M2.solve()
    if not M2.feasible:
        continue

    M3 = M.sub_motion(1)
    # manip.ManipulationModelling(C, info)
    # M.setup_point_to_point_motion(ways[0], ways[1])
    M3.keep_distance([], table, box)

    M3.solve()
    if not M3.ret.feasible:
        continue

    M2.play(C)
    C.attach(gripper, box)
    M3.play(C)
    C.attach(table, box)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]


del M
# Out:
# === placement 0: grasp x place z
# place direction: z
#   -- feasible:placement 0: grasp x place z
#      { time: 0.040058, evals: 67, done: 1, feasible: 1, sos: 0.0951737, f: 0, ineq: 0.00620283, eq: 0.360138 }
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.120397, evals: 35, done: 1, feasible: 1, sos: 3.0043, f: 0, ineq: 1.3489e-07, eq: 0.320239 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.283716, evals: 128, done: 1, feasible: 1, sos: 0.187263, f: 0, ineq: 0.00589613, eq: 0.323675 }
# === placement 1: grasp x place z
# place direction: z
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.028481, evals: 64, done: 1, feasible: 0, sos: 0.0594516, f: 0, ineq: 0.225673, eq: 0.830157 }
# True
# === placement 2: grasp x place z
# place direction: z
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 29
#      25 if l > 1:
#      26     offset_xyz = [0.0, 0.0, 0.00]
#      27     poses_from_memory = np.vstack(
#      28         (
# ---> 29             C.getFrame(last_box_memory[-2]).getPosition(),
#      30             C.getFrame(last_box_memory[-1]).getPosition(),
#      31         )
#      32     )
#      33     middle_between_towers = np.mean(poses_from_memory, 0) + offset_xyz
#      35     dir_vec = (
#      36         C.getFrame(last_box_memory[-2]).getPosition()
#      37         - C.getFrame(last_box_memory[-1]).getPosition()
#      38     )
#
# IndexError: list index out of range

# %% [markdown]
# ### On real robot: BotOp

# %%
import robotic as ry
import numpy as np
from bridgebuild_env import create_n_boxes
import robot_execution as robex
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import random
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=True)
bot.goHome(C)
# Out:
# -- bot.cpp:BotOp:43(0) CONNECTING TO GRIPPERS
# -- FrankaGripper.cpp:FrankaGripper:14(0) launching FrankaGripper 0 at 172.16.0.2
# -- FrankaGripper.cpp:FrankaGripper:18(0) gripper max width:0.079961
# -- bot.cpp:BotOp:68(0) CONNECTING TO FRANKAS
# -- franka.cpp:init:34(0) FRANKA: Kp_freq:[20, 20, 20, 20, 10, 15, 10] Kd_ratio:[0.6, 0.6, 0.4, 0.4, 0.1, 0.5, 0.1] friction:[0, 0, 0, 0, 0, 0, 0]
# -- franka.cpp:init:46(0) launching Franka 0 at 172.16.0.2

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
paths = []
vis = 1
n_success = 0
boxz = [box1, box3, box2]
while n_success <= 2:
    box = np.random.choice(boxes)
    # box = boxz[n_success]
    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])  # z grasp removed
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1.8e-1, accumulated_collisions=True
    )
    M.grasp_box(0.5, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if n_success > 1:
        print(f"3rd Block: ({box})")
        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.08])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

        print("Grasp Direction:", graspDirection)
        # M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

        if graspDirection == "x":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductXZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        elif graspDirection == "y":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductYZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        
        else:
           M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        # initial_pos= [0.020433060890705013, 0.08433819136314634]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2.0, box, table, initial_pos)
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    ways = M.solve()

    if not M.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
        )
        continue
    print("Submotion 0")
    M2 = M.sub_motion(0)

    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.15)
    M2.approach([0.8, 1.0], gripper)
    paths.append(M2.solve())

    if not M2.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :("
        )
        continue

    M3 = M.sub_motion(1)

    M3.keep_distance([], table, box)
    if n_success > 1:
        M3.retract([0.0, 0.2], gripper, dist=0.15)
        M3.approach([0.8, 1.0], gripper)

    paths.append(M3.solve())
    if not M3.ret.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :("
        )
        continue

    M_report = M.komo.report(True)

    # M_report = M.fetch_name_error_type(M_report)
    # M.print_name_error_type(M_report)

    M2_report = M2.komo.report(True)
    # M2_report = M.fetch_name_error_type(M2_report)
    # M.print_name_error_type(M2_report)

    M3_report = M3.komo.report(True)
    # M3_report = M.fetch_name_error_type(M3_report)
    # M.print_name_error_type(M3_report)

    if vis == 0:
        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)

    bot.execute_path_blocking(C, path=paths[-2])
    C.attach(gripper, box)
    bot.grasp(C)

    bot.execute_path_blocking(C, path=paths[-1])
    C.attach(table, box)
    bot.release(C)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1

del M
# Out:
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box3)
# Trying xy pos:  [0.0961871700843938, 0.08307942079144075]
#   -- infeasible:placement 0: grasp y place z
#      { time: 0.081586, evals: 146, done: 1, feasible: 0, sos: 0.108742, f: 0, ineq: 0.0685904, eq: 0.665932 }
# Failed placing block number 1 with grasp direction y at M :(
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.06084033469032642, 0.05865613101615243]
#   -- infeasible:placement 0: grasp y place z
#      { time: 0.078799, evals: 179, done: 1, feasible: 0, sos: 0.123739, f: 0, ineq: 0.0329074, eq: 0.53431 }
# Failed placing block number 1 with grasp direction y at M :(
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box1)
# Trying xy pos:  [0.03564136423810813, 0.00035493311081238323]
#   -- feasible:placement 0: grasp x place z
#      { time: 0.060886, evals: 137, done: 1, feasible: 1, sos: 0.249257, f: 0, ineq: 0.0140702, eq: 0.412585 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.039947, evals: 21, done: 1, feasible: 1, sos: 3.78076, f: 0, ineq: 1.90308e-07, eq: 0.32032 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.549087, evals: 201, done: 1, feasible: 1, sos: 0.352024, f: 0, ineq: 0.000101377, eq: 0.334585 }
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.084459, evals: 170, done: 1, feasible: 0, sos: 0.117029, f: 0, ineq: 0.0414844, eq: 0.688845 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- feasible:placement 1: grasp x place z
#      { time: 0.05797, evals: 124, done: 1, feasible: 1, sos: 0.184249, f: 0, ineq: 0.00349191, eq: 0.298241 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.267996, evals: 108, done: 1, feasible: 1, sos: 2.23007, f: 0, ineq: 0.00354715, eq: 0.318292 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.535987, evals: 196, done: 1, feasible: 1, sos: 0.108264, f: 0, ineq: 0.00444706, eq: 0.324921 }
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08472, evals: 201, done: 1, feasible: 0, sos: 0.305463, f: 0, ineq: 0.0585345, eq: 1.28473 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.048275, evals: 112, done: 1, feasible: 0, sos: 0.32678, f: 0, ineq: 0.124424, eq: 2.45032 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08238, evals: 180, done: 1, feasible: 0, sos: 0.325363, f: 0, ineq: 0.10053, eq: 2.31189 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086744, evals: 200, done: 1, feasible: 0, sos: 0.305923, f: 0, ineq: 0.0591229, eq: 1.31265 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083559, evals: 201, done: 1, feasible: 0, sos: 0.308203, f: 0, ineq: 0.0410057, eq: 1.33673 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.057315, evals: 127, done: 1, feasible: 0, sos: 0.327204, f: 0, ineq: 0.112829, eq: 2.49909 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.045988, evals: 102, done: 1, feasible: 0, sos: 0.34115, f: 0, ineq: 0.11306, eq: 3.14357 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.074164, evals: 172, done: 1, feasible: 0, sos: 0.309982, f: 0, ineq: 0.0351179, eq: 1.32612 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.04868, evals: 89, done: 1, feasible: 0, sos: 0.360564, f: 0, ineq: 0.229652, eq: 2.86513 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091289, evals: 201, done: 1, feasible: 0, sos: 0.326655, f: 0, ineq: 0.112729, eq: 2.38017 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.0847, evals: 200, done: 1, feasible: 0, sos: 0.310475, f: 0, ineq: 0.0496281, eq: 1.23524 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.058618, evals: 132, done: 1, feasible: 0, sos: 0.335762, f: 0, ineq: 0.10712, eq: 2.8275 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086255, evals: 200, done: 1, feasible: 0, sos: 0.307766, f: 0, ineq: 0.0525936, eq: 1.28849 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.068117, evals: 158, done: 1, feasible: 0, sos: 0.311748, f: 0, ineq: 0.0491141, eq: 1.24469 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.05248, evals: 114, done: 1, feasible: 0, sos: 0.340634, f: 0, ineq: 0.109613, eq: 3.07319 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085204, evals: 194, done: 1, feasible: 0, sos: 0.329521, f: 0, ineq: 0.129371, eq: 2.4306 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.062394, evals: 146, done: 1, feasible: 0, sos: 0.310264, f: 0, ineq: 0.0418336, eq: 1.32301 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095678, evals: 198, done: 1, feasible: 0, sos: 0.309995, f: 0, ineq: 0.0529182, eq: 1.24998 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.062228, evals: 144, done: 1, feasible: 0, sos: 0.310332, f: 0, ineq: 0.0491056, eq: 1.24079 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087245, evals: 200, done: 1, feasible: 0, sos: 0.30999, f: 0, ineq: 0.0488219, eq: 1.25122 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.055909, evals: 125, done: 1, feasible: 0, sos: 0.309163, f: 0, ineq: 0.0456526, eq: 1.32953 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095791, evals: 201, done: 1, feasible: 0, sos: 0.326693, f: 0, ineq: 0.0433881, eq: 1.36095 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087259, evals: 201, done: 1, feasible: 0, sos: 0.306229, f: 0, ineq: 0.0567738, eq: 1.28284 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.077422, evals: 165, done: 1, feasible: 0, sos: 0.333288, f: 0, ineq: 0.106662, eq: 2.51728 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085837, evals: 200, done: 1, feasible: 0, sos: 0.308866, f: 0, ineq: 0.0525068, eq: 1.25306 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08419, evals: 201, done: 1, feasible: 0, sos: 0.311531, f: 0, ineq: 0.0485751, eq: 1.23082 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088337, evals: 201, done: 1, feasible: 0, sos: 0.309769, f: 0, ineq: 0.0531543, eq: 1.24314 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087187, evals: 200, done: 1, feasible: 0, sos: 0.308135, f: 0, ineq: 0.0565303, eq: 1.26878 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.074677, evals: 173, done: 1, feasible: 0, sos: 0.308249, f: 0, ineq: 0.052975, eq: 1.27709 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.053244, evals: 117, done: 1, feasible: 0, sos: 0.327543, f: 0, ineq: 0.117247, eq: 2.45222 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.097863, evals: 200, done: 1, feasible: 0, sos: 0.305096, f: 0, ineq: 0.0614636, eq: 1.33171 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079512, evals: 185, done: 1, feasible: 0, sos: 0.348833, f: 0, ineq: 0.644361, eq: 2.10922 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085544, evals: 200, done: 1, feasible: 0, sos: 0.310745, f: 0, ineq: 0.0481289, eq: 1.23946 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.058041, evals: 126, done: 1, feasible: 0, sos: 0.332459, f: 0, ineq: 0.120864, eq: 2.62094 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.049592, evals: 114, done: 1, feasible: 0, sos: 0.350989, f: 0, ineq: 0.209708, eq: 3.1106 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087298, evals: 200, done: 1, feasible: 0, sos: 0.30877, f: 0, ineq: 0.0530501, eq: 1.2568 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.047115, evals: 104, done: 1, feasible: 0, sos: 0.332768, f: 0, ineq: 0.137945, eq: 2.8212 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086007, evals: 201, done: 1, feasible: 0, sos: 0.308572, f: 0, ineq: 0.0542572, eq: 1.25199 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08562, evals: 201, done: 1, feasible: 0, sos: 0.309937, f: 0, ineq: 0.0497389, eq: 1.24814 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.052153, evals: 119, done: 1, feasible: 0, sos: 0.359433, f: 0, ineq: 0.225322, eq: 3.27815 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083077, evals: 182, done: 1, feasible: 0, sos: 0.319587, f: 0, ineq: 0.113963, eq: 2.19862 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095115, evals: 201, done: 1, feasible: 0, sos: 0.308191, f: 0, ineq: 0.060962, eq: 1.26529 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.059298, evals: 137, done: 1, feasible: 0, sos: 0.309429, f: 0, ineq: 0.0448577, eq: 1.33153 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086855, evals: 200, done: 1, feasible: 0, sos: 0.304877, f: 0, ineq: 0.0748726, eq: 1.34127 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08462, evals: 200, done: 1, feasible: 0, sos: 0.309788, f: 0, ineq: 0.052415, eq: 1.25081 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.070458, evals: 156, done: 1, feasible: 0, sos: 0.329738, f: 0, ineq: 0.0964623, eq: 2.35194 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083701, evals: 200, done: 1, feasible: 0, sos: 0.302888, f: 0, ineq: 0.0666486, eq: 1.3491 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.053333, evals: 129, done: 1, feasible: 0, sos: 0.307631, f: 0, ineq: 0.0452264, eq: 1.33518 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084416, evals: 201, done: 1, feasible: 0, sos: 0.308351, f: 0, ineq: 0.0528436, eq: 1.2561 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.065172, evals: 144, done: 1, feasible: 0, sos: 0.357678, f: 0, ineq: 0.20608, eq: 3.1533 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.052282, evals: 119, done: 1, feasible: 0, sos: 0.329476, f: 0, ineq: 0.118161, eq: 2.3503 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.060494, evals: 136, done: 1, feasible: 0, sos: 0.331588, f: 0, ineq: 0.107241, eq: 2.48173 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.094831, evals: 200, done: 1, feasible: 0, sos: 0.308853, f: 0, ineq: 0.0518243, eq: 1.25867 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082857, evals: 201, done: 1, feasible: 0, sos: 0.309655, f: 0, ineq: 0.0510569, eq: 1.24845 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084433, evals: 201, done: 1, feasible: 0, sos: 0.301307, f: 0, ineq: 0.0631872, eq: 1.41388 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085386, evals: 200, done: 1, feasible: 0, sos: 0.311196, f: 0, ineq: 0.0551064, eq: 1.21491 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.096431, evals: 201, done: 1, feasible: 0, sos: 0.310529, f: 0, ineq: 0.0490413, eq: 1.23915 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082576, evals: 200, done: 1, feasible: 0, sos: 0.303667, f: 0, ineq: 0.0837596, eq: 1.42334 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083729, evals: 200, done: 1, feasible: 0, sos: 0.309538, f: 0, ineq: 0.0503625, eq: 1.25064 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086377, evals: 201, done: 1, feasible: 0, sos: 0.308319, f: 0, ineq: 0.0574549, eq: 1.2512 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08472, evals: 200, done: 1, feasible: 0, sos: 0.30971, f: 0, ineq: 0.0504149, eq: 1.24823 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.071417, evals: 158, done: 1, feasible: 0, sos: 0.327089, f: 0, ineq: 0.116275, eq: 2.40336 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.080684, evals: 194, done: 1, feasible: 0, sos: 0.310667, f: 0, ineq: 0.0496704, eq: 1.23874 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086839, evals: 200, done: 1, feasible: 0, sos: 0.305143, f: 0, ineq: 0.0664794, eq: 1.33624 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084717, evals: 201, done: 1, feasible: 0, sos: 0.309871, f: 0, ineq: 0.0533854, eq: 1.24343 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086851, evals: 201, done: 1, feasible: 0, sos: 0.310022, f: 0, ineq: 0.0496473, eq: 1.24831 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.048585, evals: 97, done: 1, feasible: 0, sos: 0.277296, f: 0, ineq: 0.334175, eq: 3.19115 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.06133, evals: 144, done: 1, feasible: 0, sos: 0.31171, f: 0, ineq: 0.0491741, eq: 1.23531 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086718, evals: 200, done: 1, feasible: 0, sos: 0.305076, f: 0, ineq: 0.058803, eq: 1.2996 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090105, evals: 201, done: 1, feasible: 0, sos: 0.329124, f: 0, ineq: 0.125589, eq: 2.5302 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.061417, evals: 145, done: 1, feasible: 0, sos: 0.310169, f: 0, ineq: 0.040665, eq: 1.32133 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086349, evals: 201, done: 1, feasible: 0, sos: 0.305606, f: 0, ineq: 0.0660174, eq: 1.31189 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086709, evals: 200, done: 1, feasible: 0, sos: 0.303661, f: 0, ineq: 0.0642765, eq: 1.33444 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088355, evals: 200, done: 1, feasible: 0, sos: 0.304199, f: 0, ineq: 0.0764359, eq: 1.3431 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.048519, evals: 105, done: 1, feasible: 0, sos: 0.359496, f: 0, ineq: 0.232377, eq: 3.34696 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.061199, evals: 146, done: 1, feasible: 0, sos: 0.309408, f: 0, ineq: 0.0381553, eq: 1.31802 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087342, evals: 200, done: 1, feasible: 0, sos: 0.304277, f: 0, ineq: 0.0683894, eq: 1.3198 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.04316, evals: 92, done: 1, feasible: 0, sos: 0.340117, f: 0, ineq: 0.110458, eq: 3.1352 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.06282, evals: 129, done: 1, feasible: 0, sos: 0.309591, f: 0, ineq: 0.03485, eq: 1.32058 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.067901, evals: 148, done: 1, feasible: 0, sos: 0.337097, f: 0, ineq: 0.125269, eq: 2.73155 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.055552, evals: 127, done: 1, feasible: 0, sos: 0.307622, f: 0, ineq: 0.0334391, eq: 1.32855 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.064351, evals: 141, done: 1, feasible: 0, sos: 0.321833, f: 0, ineq: 0.107191, eq: 2.19477 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091518, evals: 200, done: 1, feasible: 0, sos: 0.306585, f: 0, ineq: 0.0584664, eq: 1.26792 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.09299, evals: 200, done: 1, feasible: 0, sos: 0.328959, f: 0, ineq: 0.118771, eq: 2.50065 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080372, evals: 179, done: 1, feasible: 0, sos: 0.333319, f: 0, ineq: 0.116108, eq: 2.83945 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035065, evals: 80, done: 1, feasible: 0, sos: 0.303703, f: 0, ineq: 0.0698742, eq: 1.34314 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08527, evals: 201, done: 1, feasible: 0, sos: 0.310219, f: 0, ineq: 0.0499126, eq: 1.25121 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.067862, evals: 150, done: 1, feasible: 0, sos: 0.316448, f: 0, ineq: 0.117882, eq: 2.10387 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.066512, evals: 156, done: 1, feasible: 0, sos: 0.309915, f: 0, ineq: 0.0528126, eq: 1.23901 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.096155, evals: 200, done: 1, feasible: 0, sos: 0.302791, f: 0, ineq: 0.0861676, eq: 1.37357 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086262, evals: 197, done: 1, feasible: 0, sos: 0.329669, f: 0, ineq: 0.122553, eq: 2.50965 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086468, evals: 200, done: 1, feasible: 0, sos: 0.308066, f: 0, ineq: 0.0535323, eq: 1.26127 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.059266, evals: 131, done: 1, feasible: 0, sos: 0.328298, f: 0, ineq: 0.120624, eq: 2.47967 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.055579, evals: 119, done: 1, feasible: 0, sos: 0.340409, f: 0, ineq: 0.132878, eq: 3.11709 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085915, evals: 200, done: 1, feasible: 0, sos: 0.302962, f: 0, ineq: 0.0696063, eq: 1.39288 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.031471, evals: 77, done: 1, feasible: 0, sos: 0.302298, f: 0, ineq: 0.0727857, eq: 1.3768 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.038795, evals: 91, done: 1, feasible: 0, sos: 0.334542, f: 0, ineq: 0.663056, eq: 2.09727 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085838, evals: 201, done: 1, feasible: 0, sos: 0.377175, f: 0, ineq: 0.624463, eq: 2.84096 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082493, evals: 201, done: 1, feasible: 0, sos: 0.395941, f: 0, ineq: 0.562093, eq: 2.87265 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.075759, evals: 146, done: 1, feasible: 0, sos: 0.334617, f: 0, ineq: 0.102273, eq: 2.5774 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09328, evals: 200, done: 1, feasible: 0, sos: 0.308874, f: 0, ineq: 0.0506783, eq: 1.26933 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083135, evals: 153, done: 1, feasible: 0, sos: 0.329487, f: 0, ineq: 0.124677, eq: 2.47626 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.072263, evals: 149, done: 1, feasible: 0, sos: 0.310308, f: 0, ineq: 0.0413697, eq: 1.31972 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.101889, evals: 195, done: 1, feasible: 0, sos: 0.317443, f: 0, ineq: 0.116112, eq: 2.21121 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.100158, evals: 200, done: 1, feasible: 0, sos: 0.307064, f: 0, ineq: 0.0651503, eq: 1.2795 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.039416, evals: 88, done: 1, feasible: 0, sos: 0.304255, f: 0, ineq: 0.0462913, eq: 1.38332 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.100183, evals: 200, done: 1, feasible: 0, sos: 0.304361, f: 0, ineq: 0.058501, eq: 1.31117 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.033891, evals: 77, done: 1, feasible: 0, sos: 0.343888, f: 0, ineq: 0.129049, eq: 3.64492 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092226, evals: 200, done: 1, feasible: 0, sos: 0.309859, f: 0, ineq: 0.0522505, eq: 1.24521 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086753, evals: 201, done: 1, feasible: 0, sos: 0.306196, f: 0, ineq: 0.0585158, eq: 1.28262 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.066506, evals: 138, done: 1, feasible: 0, sos: 0.325523, f: 0, ineq: 0.142549, eq: 2.52761 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089758, evals: 201, done: 1, feasible: 0, sos: 0.31142, f: 0, ineq: 0.0482968, eq: 1.23994 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.076344, evals: 179, done: 1, feasible: 0, sos: 0.310408, f: 0, ineq: 0.0498226, eq: 1.24679 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.146594, evals: 201, done: 1, feasible: 0, sos: 0.309341, f: 0, ineq: 0.0499357, eq: 1.25596 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.07075, evals: 152, done: 1, feasible: 0, sos: 0.309419, f: 0, ineq: 0.0395494, eq: 1.32745 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087556, evals: 200, done: 1, feasible: 0, sos: 0.307834, f: 0, ineq: 0.0567961, eq: 1.28091 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086954, evals: 174, done: 1, feasible: 0, sos: 0.33305, f: 0, ineq: 0.124528, eq: 2.76192 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.090681, evals: 201, done: 1, feasible: 0, sos: 0.326526, f: 0, ineq: 0.120667, eq: 2.44697 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.096237, evals: 201, done: 1, feasible: 0, sos: 0.305735, f: 0, ineq: 0.0583678, eq: 1.29086 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.104894, evals: 200, done: 1, feasible: 0, sos: 0.340024, f: 0, ineq: 0.668178, eq: 2.0413 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.112399, evals: 200, done: 1, feasible: 0, sos: 0.30811, f: 0, ineq: 0.0571999, eq: 1.271 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.100421, evals: 200, done: 1, feasible: 0, sos: 0.308735, f: 0, ineq: 0.0557337, eq: 1.25543 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.112742, evals: 201, done: 1, feasible: 0, sos: 0.306058, f: 0, ineq: 0.0514296, eq: 1.2936 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.104188, evals: 201, done: 1, feasible: 0, sos: 0.308518, f: 0, ineq: 0.0522134, eq: 1.26318 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.052115, evals: 97, done: 1, feasible: 0, sos: 0.330322, f: 0, ineq: 0.659519, eq: 2.18434 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.108288, evals: 200, done: 1, feasible: 0, sos: 0.309696, f: 0, ineq: 0.0535846, eq: 1.25174 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087177, evals: 152, done: 1, feasible: 0, sos: 0.330748, f: 0, ineq: 0.100607, eq: 2.36891 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.036153, evals: 64, done: 1, feasible: 0, sos: 0.325965, f: 0, ineq: 0.121121, eq: 2.59531 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.106582, evals: 200, done: 1, feasible: 0, sos: 0.30984, f: 0, ineq: 0.0502871, eq: 1.25928 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085901, evals: 157, done: 1, feasible: 0, sos: 0.331874, f: 0, ineq: 0.133499, eq: 2.56647 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.103197, evals: 201, done: 1, feasible: 0, sos: 0.309966, f: 0, ineq: 0.0491746, eq: 1.2538 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09702, evals: 201, done: 1, feasible: 0, sos: 0.310247, f: 0, ineq: 0.0496906, eq: 1.25644 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089964, evals: 201, done: 1, feasible: 0, sos: 0.335336, f: 0, ineq: 0.128144, eq: 2.67446 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084259, evals: 200, done: 1, feasible: 0, sos: 0.306892, f: 0, ineq: 0.0576762, eq: 1.28002 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.062323, evals: 138, done: 1, feasible: 0, sos: 0.341368, f: 0, ineq: 0.119459, eq: 3.20478 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086542, evals: 201, done: 1, feasible: 0, sos: 0.310598, f: 0, ineq: 0.0492604, eq: 1.23485 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.043215, evals: 98, done: 1, feasible: 0, sos: 0.323477, f: 0, ineq: 0.114097, eq: 2.24252 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085958, evals: 200, done: 1, feasible: 0, sos: 0.310133, f: 0, ineq: 0.0515079, eq: 1.24243 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.058419, evals: 139, done: 1, feasible: 0, sos: 0.309606, f: 0, ineq: 0.0347229, eq: 1.31297 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.04742, evals: 105, done: 1, feasible: 0, sos: 0.325359, f: 0, ineq: 0.117421, eq: 2.33037 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.071236, evals: 145, done: 1, feasible: 0, sos: 0.3099, f: 0, ineq: 0.0377319, eq: 1.32118 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090124, evals: 200, done: 1, feasible: 0, sos: 0.305753, f: 0, ineq: 0.0608662, eq: 1.28793 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087236, evals: 200, done: 1, feasible: 0, sos: 0.304927, f: 0, ineq: 0.0756684, eq: 1.36 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079571, evals: 171, done: 1, feasible: 0, sos: 0.32945, f: 0, ineq: 0.127542, eq: 2.56562 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.047562, evals: 104, done: 1, feasible: 0, sos: 0.340274, f: 0, ineq: 0.122771, eq: 3.15332 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.090823, evals: 200, done: 1, feasible: 0, sos: 0.307322, f: 0, ineq: 0.0547735, eq: 1.28223 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.102446, evals: 190, done: 1, feasible: 0, sos: 0.333295, f: 0, ineq: 0.115691, eq: 2.72705 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087396, evals: 193, done: 1, feasible: 0, sos: 0.331584, f: 0, ineq: 0.128738, eq: 2.69333 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085935, evals: 201, done: 1, feasible: 0, sos: 0.310635, f: 0, ineq: 0.0512994, eq: 1.2603 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.057421, evals: 133, done: 1, feasible: 0, sos: 0.331902, f: 0, ineq: 0.0883926, eq: 2.48972 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034015, evals: 81, done: 1, feasible: 0, sos: 0.301868, f: 0, ineq: 0.084675, eq: 1.36748 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# ...
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08542, evals: 200, done: 1, feasible: 0, sos: 0.305266, f: 0, ineq: 0.0677216, eq: 1.32251 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086911, evals: 200, done: 1, feasible: 0, sos: 0.306464, f: 0, ineq: 0.0648816, eq: 1.32257 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.061415, evals: 143, done: 1, feasible: 0, sos: 0.306954, f: 0, ineq: 0.0398301, eq: 1.33994 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087622, evals: 201, done: 1, feasible: 0, sos: 0.308054, f: 0, ineq: 0.0524153, eq: 1.26316 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.081559, evals: 193, done: 1, feasible: 0, sos: 0.307356, f: 0, ineq: 0.061176, eq: 1.25836 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084432, evals: 183, done: 1, feasible: 0, sos: 0.311316, f: 0, ineq: 0.0480987, eq: 1.23056 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085848, evals: 200, done: 1, feasible: 0, sos: 0.310783, f: 0, ineq: 0.0490184, eq: 1.23823 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.062731, evals: 136, done: 1, feasible: 0, sos: 0.333666, f: 0, ineq: 0.128345, eq: 2.64626 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.096562, evals: 201, done: 1, feasible: 0, sos: 0.310971, f: 0, ineq: 0.0496585, eq: 1.23563 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.047246, evals: 103, done: 1, feasible: 0, sos: 0.332962, f: 0, ineq: 0.139915, eq: 2.86719 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091902, evals: 200, done: 1, feasible: 0, sos: 0.307753, f: 0, ineq: 0.0512794, eq: 1.27523 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082896, evals: 200, done: 1, feasible: 0, sos: 0.420888, f: 0, ineq: 0.454335, eq: 2.79291 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087606, evals: 200, done: 1, feasible: 0, sos: 0.307768, f: 0, ineq: 0.0526749, eq: 1.28635 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084768, evals: 201, done: 1, feasible: 0, sos: 0.310689, f: 0, ineq: 0.051888, eq: 1.24139 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.056997, evals: 133, done: 1, feasible: 0, sos: 0.307961, f: 0, ineq: 0.0375416, eq: 1.33011 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.102284, evals: 201, done: 1, feasible: 0, sos: 0.328175, f: 0, ineq: 0.117084, eq: 2.47368 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088807, evals: 201, done: 1, feasible: 0, sos: 0.30728, f: 0, ineq: 0.0571502, eq: 1.28024 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.056404, evals: 135, done: 1, feasible: 0, sos: 0.311325, f: 0, ineq: 0.0484899, eq: 1.26298 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.064314, evals: 150, done: 1, feasible: 0, sos: 0.30515, f: 0, ineq: 0.0326105, eq: 1.3472 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084594, evals: 200, done: 1, feasible: 0, sos: 0.309099, f: 0, ineq: 0.0516477, eq: 1.25221 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084832, evals: 201, done: 1, feasible: 0, sos: 0.310018, f: 0, ineq: 0.0490949, eq: 1.2479 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.098976, evals: 200, done: 1, feasible: 0, sos: 0.309238, f: 0, ineq: 0.0507364, eq: 1.25173 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.06852, evals: 152, done: 1, feasible: 0, sos: 0.329152, f: 0, ineq: 0.112793, eq: 2.37127 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.056223, evals: 124, done: 1, feasible: 0, sos: 0.305268, f: 0, ineq: 0.04762, eq: 1.3631 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083718, evals: 201, done: 1, feasible: 0, sos: 0.309044, f: 0, ineq: 0.0676382, eq: 1.25209 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089336, evals: 181, done: 1, feasible: 0, sos: 0.332444, f: 0, ineq: 0.129615, eq: 2.71867 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.049605, evals: 114, done: 1, feasible: 0, sos: 0.337225, f: 0, ineq: 0.129769, eq: 2.95494 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.058959, evals: 140, done: 1, feasible: 0, sos: 0.302651, f: 0, ineq: 0.0955671, eq: 1.35159 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.097582, evals: 198, done: 1, feasible: 0, sos: 0.303063, f: 0, ineq: 0.0682862, eq: 1.36563 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.063889, evals: 143, done: 1, feasible: 0, sos: 0.3091, f: 0, ineq: 0.0412801, eq: 1.32335 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084633, evals: 200, done: 1, feasible: 0, sos: 0.307139, f: 0, ineq: 0.0576588, eq: 1.28146 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.070738, evals: 158, done: 1, feasible: 0, sos: 0.32543, f: 0, ineq: 0.109495, eq: 2.29185 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086003, evals: 200, done: 1, feasible: 0, sos: 0.305679, f: 0, ineq: 0.0659687, eq: 1.28953 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084689, evals: 200, done: 1, feasible: 0, sos: 0.310047, f: 0, ineq: 0.0506352, eq: 1.24496 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.099913, evals: 200, done: 1, feasible: 0, sos: 0.303305, f: 0, ineq: 0.0594969, eq: 1.33601 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.069904, evals: 168, done: 1, feasible: 0, sos: 0.310498, f: 0, ineq: 0.0514891, eq: 1.23817 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.056475, evals: 136, done: 1, feasible: 0, sos: 0.30968, f: 0, ineq: 0.039084, eq: 1.32519 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.065539, evals: 153, done: 1, feasible: 0, sos: 0.334379, f: 0, ineq: 0.143236, eq: 2.87541 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.074308, evals: 173, done: 1, feasible: 0, sos: 0.309312, f: 0, ineq: 0.0507053, eq: 1.24906 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035992, evals: 86, done: 1, feasible: 0, sos: 0.302682, f: 0, ineq: 0.0767513, eq: 1.35542 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087369, evals: 200, done: 1, feasible: 0, sos: 0.31072, f: 0, ineq: 0.0430593, eq: 1.32515 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087027, evals: 201, done: 1, feasible: 0, sos: 0.303308, f: 0, ineq: 0.0260052, eq: 1.33892 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.05307, evals: 117, done: 1, feasible: 0, sos: 0.341204, f: 0, ineq: 0.119083, eq: 3.12461 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085438, evals: 200, done: 1, feasible: 0, sos: 0.307922, f: 0, ineq: 0.0531852, eq: 1.27671 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084037, evals: 200, done: 1, feasible: 0, sos: 0.31073, f: 0, ineq: 0.0488964, eq: 1.24809 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.058585, evals: 119, done: 1, feasible: 0, sos: 0.341958, f: 0, ineq: 0.128769, eq: 3.1329 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087793, evals: 200, done: 1, feasible: 0, sos: 0.308595, f: 0, ineq: 0.0459525, eq: 1.33723 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088675, evals: 200, done: 1, feasible: 0, sos: 0.308208, f: 0, ineq: 0.0542984, eq: 1.2627 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087459, evals: 201, done: 1, feasible: 0, sos: 0.302599, f: 0, ineq: 0.0293614, eq: 1.35261 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.035687, evals: 77, done: 1, feasible: 0, sos: 0.325934, f: 0, ineq: 0.103192, eq: 2.44525 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.035714, evals: 85, done: 1, feasible: 0, sos: 0.33647, f: 0, ineq: 0.676922, eq: 2.05449 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.065832, evals: 116, done: 1, feasible: 0, sos: 0.3311, f: 0, ineq: 0.114394, eq: 2.4674 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
