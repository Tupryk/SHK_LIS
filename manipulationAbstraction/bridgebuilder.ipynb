# %%
import robotic as ry
import numpy as np
import random
from bridgebuild_env import create_n_boxes

# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robot_execution as robex
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=False)
bot.goHome(C)

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
boxes_all = [box1, box2, box3]
n_success = 0
last_box_memory = []
while n_success <= 2:
    print(f"n_success: {n_success}")
    box = np.random.choice(boxes)
    not_picked_boxes = [i for i in boxes_all if i != box]

    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])
    placeDirection = "z"
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, phases = 3., homing_scale=1e-1, accumulated_collisions=True
    )
    M.grasp_box(1.0, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if n_success > 1:
        offset_xyz = [0.0, 0.0, 0.00]
        print(f"3rd Block: ({box})")
        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.06])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)

        print("Grasp Direction:", graspDirection)

    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.positionRel,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1.0],
            [0.0, 0.0, 0.1],
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
        #M.keep_distance([], box, last_box_memory[-1], margin = 0.06)


    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]

        M.target_relative_xy_position(
            2.0, box, table, initial_pos
        )
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
        #M.keep_distance([], box, not_picked_boxes[0], margin = 0.06)
        #M.keep_distance([], box, not_picked_boxes[1], margin = 0.06)

    ways = M.solve()

    if not M.feasible:
        print("True")
        continue

    M2 = M.sub_motion(0)
    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.012)
    M2.approach([0.8, 1.0], gripper)
    M2.solve()
    if not M2.feasible:
        continue

    M3 = M.sub_motion(1)
    # manip.ManipulationModelling(C, info)
    # M.setup_point_to_point_motion(ways[0], ways[1])
    M3.keep_distance([], table, box)


    M3.retract([0.0, 0.2], gripper, dist=0.025)
    M3.approach([0.8, 1.0], gripper)

    M3.solve()
    if not M3.ret.feasible:
        continue

    M2.play(C)
    C.attach(gripper, box)
    M3.play(C)
    C.attach(table, box)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1


del M
# Out:
# n_success: 0
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box3)
#   -- feasible:placement 0: grasp x place z
#      { time: 0.271494, evals: 201, done: 1, feasible: 1, sos: 0.0834742, f: 0, ineq: 0.00628501, eq: 0.422923 }
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.093137, evals: 22, done: 1, feasible: 1, sos: 1.03642, f: 0, ineq: 9.52361e-07, eq: 0.320169 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.124189, evals: 18, done: 1, feasible: 1, sos: 0.412627, f: 0, ineq: 0.00137544, eq: 0.326364 }
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.124142, evals: 97, done: 1, feasible: 0, sos: 0.0648748, f: 0, ineq: 0.211929, eq: 0.872721 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.136215, evals: 121, done: 1, feasible: 0, sos: 0.0933597, f: 0, ineq: 0.206445, eq: 0.742669 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.129899, evals: 94, done: 1, feasible: 0, sos: 0.063292, f: 0, ineq: 0.207645, eq: 0.819469 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.109892, evals: 103, done: 1, feasible: 0, sos: 0.0916153, f: 0, ineq: 0.210395, eq: 0.775944 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.139533, evals: 111, done: 1, feasible: 0, sos: 0.0624341, f: 0, ineq: 0.211703, eq: 0.836266 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.063882, evals: 50, done: 1, feasible: 0, sos: 0.073274, f: 0, ineq: 0.21374, eq: 0.906568 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.11167, evals: 75, done: 1, feasible: 0, sos: 0.0676094, f: 0, ineq: 0.34741, eq: 2.6844 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.158031, evals: 129, done: 1, feasible: 0, sos: 0.0931094, f: 0, ineq: 0.20803, eq: 0.748719 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.057209, evals: 54, done: 1, feasible: 0, sos: 0.063311, f: 0, ineq: 0.213665, eq: 0.903367 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.151113, evals: 120, done: 1, feasible: 0, sos: 0.062014, f: 0, ineq: 0.213395, eq: 0.847039 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.106765, evals: 100, done: 1, feasible: 0, sos: 0.0650505, f: 0, ineq: 0.212354, eq: 0.869458 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.128243, evals: 108, done: 1, feasible: 0, sos: 0.0624679, f: 0, ineq: 0.211437, eq: 0.834916 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.137075, evals: 119, done: 1, feasible: 0, sos: 0.0914596, f: 0, ineq: 0.211246, eq: 0.781683 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.071776, evals: 63, done: 1, feasible: 0, sos: 0.0894402, f: 0, ineq: 0.214513, eq: 0.831071 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.204211, evals: 175, done: 1, feasible: 0, sos: 0.0623128, f: 0, ineq: 0.212847, eq: 0.841655 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.163435, evals: 135, done: 1, feasible: 0, sos: 0.0919206, f: 0, ineq: 0.213364, eq: 0.837899 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.123525, evals: 99, done: 1, feasible: 0, sos: 0.0653638, f: 0, ineq: 0.211296, eq: 0.869223 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.110673, evals: 103, done: 1, feasible: 0, sos: 0.0624207, f: 0, ineq: 0.211694, eq: 0.838336 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.222305, evals: 186, done: 1, feasible: 0, sos: 0.0634391, f: 0, ineq: 0.211244, eq: 0.829886 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.236358, evals: 177, done: 1, feasible: 0, sos: 0.0813083, f: 0, ineq: 0.176567, eq: 1.22788 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.135175, evals: 115, done: 1, feasible: 0, sos: 0.0626678, f: 0, ineq: 0.21179, eq: 0.838424 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.13766, evals: 107, done: 1, feasible: 0, sos: 0.0660932, f: 0, ineq: 0.209905, eq: 0.854368 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.129079, evals: 102, done: 1, feasible: 0, sos: 0.0625502, f: 0, ineq: 0.210206, eq: 0.832229 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.076132, evals: 53, done: 1, feasible: 0, sos: 0.0732412, f: 0, ineq: 0.213986, eq: 0.898915 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.143743, evals: 109, done: 1, feasible: 0, sos: 0.0915943, f: 0, ineq: 0.208358, eq: 0.784557 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.181735, evals: 153, done: 1, feasible: 0, sos: 0.0679297, f: 0, ineq: 0.355459, eq: 2.67713 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.169916, evals: 131, done: 1, feasible: 0, sos: 0.0643737, f: 0, ineq: 0.209097, eq: 0.818413 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.125195, evals: 100, done: 1, feasible: 0, sos: 0.0635254, f: 0, ineq: 0.213175, eq: 0.902024 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.092944, evals: 65, done: 1, feasible: 0, sos: 0.0674999, f: 0, ineq: 0.273066, eq: 2.83478 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.072585, evals: 65, done: 1, feasible: 0, sos: 0.0894112, f: 0, ineq: 0.21666, eq: 0.827536 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.126547, evals: 108, done: 1, feasible: 0, sos: 0.0806731, f: 0, ineq: 0.170697, eq: 1.23085 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.119847, evals: 108, done: 1, feasible: 0, sos: 0.0916038, f: 0, ineq: 0.208312, eq: 0.782243 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.124884, evals: 105, done: 1, feasible: 0, sos: 0.0628028, f: 0, ineq: 0.211804, eq: 0.837648 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.121728, evals: 106, done: 1, feasible: 0, sos: 0.091616, f: 0, ineq: 0.210248, eq: 0.776096 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.249739, evals: 200, done: 1, feasible: 0, sos: 0.0822875, f: 0, ineq: 0.178338, eq: 1.21744 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.11612, evals: 95, done: 1, feasible: 0, sos: 0.0646328, f: 0, ineq: 0.212012, eq: 0.877389 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.143849, evals: 118, done: 1, feasible: 0, sos: 0.0638011, f: 0, ineq: 0.207652, eq: 0.811127 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.137904, evals: 116, done: 1, feasible: 0, sos: 0.093096, f: 0, ineq: 0.208246, eq: 0.749386 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.121789, evals: 94, done: 1, feasible: 0, sos: 0.0640975, f: 0, ineq: 0.212502, eq: 0.893054 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.128071, evals: 108, done: 1, feasible: 0, sos: 0.0916124, f: 0, ineq: 0.20974, eq: 0.777566 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.09927, evals: 66, done: 1, feasible: 0, sos: 0.0633272, f: 0, ineq: 0.213626, eq: 0.903128 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.101382, evals: 68, done: 1, feasible: 0, sos: 0.0680692, f: 0, ineq: 0.32992, eq: 2.69822 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.087469, evals: 69, done: 1, feasible: 0, sos: 0.0675838, f: 0, ineq: 0.344165, eq: 2.68257 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.087622, evals: 71, done: 1, feasible: 0, sos: 0.0842421, f: 0, ineq: 0.240766, eq: 1.23825 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.136974, evals: 103, done: 1, feasible: 0, sos: 0.063026, f: 0, ineq: 0.211404, eq: 0.837105 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.072827, evals: 57, done: 1, feasible: 0, sos: 0.0894657, f: 0, ineq: 0.213687, eq: 0.834268 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.125205, evals: 95, done: 1, feasible: 0, sos: 0.0649158, f: 0, ineq: 0.211648, eq: 0.87294 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.10448, evals: 95, done: 1, feasible: 0, sos: 0.0640312, f: 0, ineq: 0.212841, eq: 0.888043 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.135676, evals: 102, done: 1, feasible: 0, sos: 0.062848, f: 0, ineq: 0.211574, eq: 0.838618 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.073116, evals: 58, done: 1, feasible: 0, sos: 0.075083, f: 0, ineq: 0.24372, eq: 2.74003 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.193942, evals: 143, done: 1, feasible: 0, sos: 0.0651953, f: 0, ineq: 0.211529, eq: 0.867858 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.258156, evals: 200, done: 1, feasible: 0, sos: 0.0852061, f: 0, ineq: 0.213805, eq: 1.23107 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.069583, evals: 60, done: 1, feasible: 0, sos: 0.072963, f: 0, ineq: 0.223763, eq: 2.72873 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.137866, evals: 104, done: 1, feasible: 0, sos: 0.0634846, f: 0, ineq: 0.213971, eq: 0.907569 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.092416, evals: 79, done: 1, feasible: 0, sos: 0.0686961, f: 0, ineq: 0.289728, eq: 2.7635 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.151583, evals: 123, done: 1, feasible: 0, sos: 0.0630916, f: 0, ineq: 0.211093, eq: 0.832437 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.129983, evals: 100, done: 1, feasible: 0, sos: 0.0916157, f: 0, ineq: 0.210633, eq: 0.775468 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.165555, evals: 117, done: 1, feasible: 0, sos: 0.0626169, f: 0, ineq: 0.211959, eq: 0.838929 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.104356, evals: 63, done: 1, feasible: 0, sos: 0.0673889, f: 0, ineq: 0.272987, eq: 2.83416 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.139316, evals: 115, done: 1, feasible: 0, sos: 0.062309, f: 0, ineq: 0.212807, eq: 0.843539 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.249718, evals: 200, done: 1, feasible: 0, sos: 0.0816702, f: 0, ineq: 0.169763, eq: 1.21819 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.066598, evals: 56, done: 1, feasible: 0, sos: 0.0894507, f: 0, ineq: 0.21358, eq: 0.83743 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.119564, evals: 87, done: 1, feasible: 0, sos: 0.0643842, f: 0, ineq: 0.212829, eq: 0.882388 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.14668, evals: 121, done: 1, feasible: 0, sos: 0.0626258, f: 0, ineq: 0.212254, eq: 0.838349 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.079755, evals: 74, done: 1, feasible: 0, sos: 0.0633397, f: 0, ineq: 0.213651, eq: 0.904958 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.078676, evals: 66, done: 1, feasible: 0, sos: 0.0633399, f: 0, ineq: 0.213816, eq: 0.900958 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.270761, evals: 180, done: 1, feasible: 0, sos: 0.0815434, f: 0, ineq: 0.171334, eq: 1.22072 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.153607, evals: 110, done: 1, feasible: 0, sos: 0.0647315, f: 0, ineq: 0.212469, eq: 0.87579 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.302837, evals: 200, done: 1, feasible: 0, sos: 0.0842577, f: 0, ineq: 0.185229, eq: 1.20246 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.147936, evals: 112, done: 1, feasible: 0, sos: 0.0640463, f: 0, ineq: 0.21308, eq: 0.891576 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.072459, evals: 55, done: 1, feasible: 0, sos: 0.0894645, f: 0, ineq: 0.212225, eq: 0.834188 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.142972, evals: 107, done: 1, feasible: 0, sos: 0.0630078, f: 0, ineq: 0.211729, eq: 0.836752 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.1489, evals: 110, done: 1, feasible: 0, sos: 0.0621508, f: 0, ineq: 0.21351, eq: 0.845577 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.139802, evals: 97, done: 1, feasible: 0, sos: 0.0639362, f: 0, ineq: 0.21396, eq: 0.894122 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.146775, evals: 114, done: 1, feasible: 0, sos: 0.0638093, f: 0, ineq: 0.21298, eq: 0.894304 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.136949, evals: 100, done: 1, feasible: 0, sos: 0.0650401, f: 0, ineq: 0.212931, eq: 0.870492 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.246476, evals: 200, done: 1, feasible: 0, sos: 0.0821397, f: 0, ineq: 0.181154, eq: 1.22157 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.283444, evals: 201, done: 1, feasible: 0, sos: 0.0807758, f: 0, ineq: 0.167949, eq: 1.22693 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.134414, evals: 107, done: 1, feasible: 0, sos: 0.0649474, f: 0, ineq: 0.214423, eq: 0.877233 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.147745, evals: 116, done: 1, feasible: 0, sos: 0.0921053, f: 0, ineq: 0.215081, eq: 0.84369 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.265429, evals: 201, done: 1, feasible: 0, sos: 0.0848743, f: 0, ineq: 0.182302, eq: 1.20129 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.284029, evals: 200, done: 1, feasible: 0, sos: 0.0853353, f: 0, ineq: 0.212212, eq: 1.23005 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.226795, evals: 166, done: 1, feasible: 0, sos: 0.0620213, f: 0, ineq: 0.212472, eq: 0.843612 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.272202, evals: 200, done: 1, feasible: 0, sos: 0.0843938, f: 0, ineq: 0.175154, eq: 1.19049 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.090681, evals: 66, done: 1, feasible: 0, sos: 0.0737134, f: 0, ineq: 0.20633, eq: 0.87998 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.091526, evals: 67, done: 1, feasible: 0, sos: 0.071921, f: 0, ineq: 0.222764, eq: 2.74952 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.255937, evals: 200, done: 1, feasible: 0, sos: 0.0817565, f: 0, ineq: 0.174044, eq: 1.2204 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.093941, evals: 84, done: 1, feasible: 0, sos: 0.0634124, f: 0, ineq: 0.21364, eq: 0.901853 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.255538, evals: 200, done: 1, feasible: 0, sos: 0.0843195, f: 0, ineq: 0.202965, eq: 1.22185 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.08358, evals: 68, done: 1, feasible: 0, sos: 0.0668237, f: 0, ineq: 0.263884, eq: 2.8277 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.109937, evals: 84, done: 1, feasible: 0, sos: 0.0638639, f: 0, ineq: 0.212911, eq: 0.89589 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.097426, evals: 94, done: 1, feasible: 0, sos: 0.0635937, f: 0, ineq: 0.213487, eq: 0.897261 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.064621, evals: 56, done: 1, feasible: 0, sos: 0.0633067, f: 0, ineq: 0.21367, eq: 0.903853 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.119089, evals: 94, done: 1, feasible: 0, sos: 0.0634369, f: 0, ineq: 0.213482, eq: 0.899305 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.250042, evals: 200, done: 1, feasible: 0, sos: 0.0853833, f: 0, ineq: 0.215307, eq: 1.23234 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.264134, evals: 201, done: 1, feasible: 0, sos: 0.0821418, f: 0, ineq: 0.178152, eq: 1.21914 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.239771, evals: 200, done: 1, feasible: 0, sos: 0.082177, f: 0, ineq: 0.180745, eq: 1.22079 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.130512, evals: 96, done: 1, feasible: 0, sos: 0.0922524, f: 0, ineq: 0.213522, eq: 0.844684 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.110732, evals: 101, done: 1, feasible: 0, sos: 0.0916123, f: 0, ineq: 0.210939, eq: 0.775418 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.064934, evals: 53, done: 1, feasible: 0, sos: 0.0737534, f: 0, ineq: 0.20097, eq: 0.889342 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.138122, evals: 119, done: 1, feasible: 0, sos: 0.0629624, f: 0, ineq: 0.211085, eq: 0.83728 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.141478, evals: 128, done: 1, feasible: 0, sos: 0.0915819, f: 0, ineq: 0.209704, eq: 0.789252 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.13266, evals: 91, done: 1, feasible: 0, sos: 0.0654756, f: 0, ineq: 0.210572, eq: 0.865894 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.071005, evals: 59, done: 1, feasible: 0, sos: 0.0735874, f: 0, ineq: 0.209458, eq: 0.889437 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.146595, evals: 120, done: 1, feasible: 0, sos: 0.0624919, f: 0, ineq: 0.211605, eq: 0.838508 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.062047, evals: 49, done: 1, feasible: 0, sos: 0.0634359, f: 0, ineq: 0.215799, eq: 0.914239 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.083405, evals: 69, done: 1, feasible: 0, sos: 0.0653778, f: 0, ineq: 0.346405, eq: 2.71822 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.086625, evals: 69, done: 1, feasible: 0, sos: 0.0673318, f: 0, ineq: 0.348061, eq: 2.68443 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.187284, evals: 142, done: 1, feasible: 0, sos: 0.0834601, f: 0, ineq: 0.221847, eq: 1.23172 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.137916, evals: 121, done: 1, feasible: 0, sos: 0.0933616, f: 0, ineq: 0.206463, eq: 0.742359 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.180179, evals: 140, done: 1, feasible: 0, sos: 0.0628168, f: 0, ineq: 0.211937, eq: 0.836668 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.242355, evals: 200, done: 1, feasible: 0, sos: 0.0817952, f: 0, ineq: 0.183781, eq: 1.22784 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.151015, evals: 119, done: 1, feasible: 0, sos: 0.0625316, f: 0, ineq: 0.212289, eq: 0.83851 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.153525, evals: 127, done: 1, feasible: 0, sos: 0.0928095, f: 0, ineq: 0.204253, eq: 0.767983 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.136014, evals: 92, done: 1, feasible: 0, sos: 0.0653118, f: 0, ineq: 0.212133, eq: 0.869171 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.077306, evals: 63, done: 1, feasible: 0, sos: 0.0461238, f: 0, ineq: 0.410051, eq: 3.51649 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.24683, evals: 201, done: 1, feasible: 0, sos: 0.0849111, f: 0, ineq: 0.222855, eq: 1.23515 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.086369, evals: 60, done: 1, feasible: 0, sos: 0.0664742, f: 0, ineq: 0.361445, eq: 2.67593 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.271475, evals: 201, done: 1, feasible: 0, sos: 0.0812493, f: 0, ineq: 0.17437, eq: 1.22672 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.088212, evals: 65, done: 1, feasible: 0, sos: 0.0671848, f: 0, ineq: 0.345061, eq: 2.68836 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.096039, evals: 75, done: 1, feasible: 0, sos: 0.067041, f: 0, ineq: 0.264636, eq: 2.80564 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.103664, evals: 58, done: 1, feasible: 0, sos: 0.08948, f: 0, ineq: 0.212215, eq: 0.831824 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.062689, evals: 59, done: 1, feasible: 0, sos: 0.0894844, f: 0, ineq: 0.21297, eq: 0.830054 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.104183, evals: 92, done: 1, feasible: 0, sos: 0.0660878, f: 0, ineq: 0.310055, eq: 2.79073 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.074194, evals: 60, done: 1, feasible: 0, sos: 0.0675984, f: 0, ineq: 0.219876, eq: 2.88116 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.139908, evals: 100, done: 1, feasible: 0, sos: 0.0647115, f: 0, ineq: 0.213274, eq: 0.875642 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.134042, evals: 108, done: 1, feasible: 0, sos: 0.091602, f: 0, ineq: 0.209509, eq: 0.780668 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.09142, evals: 67, done: 1, feasible: 0, sos: 0.0894856, f: 0, ineq: 0.213189, eq: 0.829056 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.148156, evals: 111, done: 1, feasible: 0, sos: 0.0625229, f: 0, ineq: 0.211511, eq: 0.839351 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.129953, evals: 90, done: 1, feasible: 0, sos: 0.0652444, f: 0, ineq: 0.211703, eq: 0.870647 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.1255, evals: 103, done: 1, feasible: 0, sos: 0.0624482, f: 0, ineq: 0.212163, eq: 0.838853 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.260031, evals: 201, done: 1, feasible: 0, sos: 0.0839128, f: 0, ineq: 0.174405, eq: 1.19265 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.094156, evals: 79, done: 1, feasible: 0, sos: 0.0735767, f: 0, ineq: 0.208557, eq: 0.904876 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.115902, evals: 83, done: 1, feasible: 0, sos: 0.0639298, f: 0, ineq: 0.212905, eq: 0.894957 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.14899, evals: 119, done: 1, feasible: 0, sos: 0.0633198, f: 0, ineq: 0.21079, eq: 0.834047 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.091913, evals: 82, done: 1, feasible: 0, sos: 0.0653933, f: 0, ineq: 0.210523, eq: 0.86814 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.142424, evals: 105, done: 1, feasible: 0, sos: 0.0916152, f: 0, ineq: 0.209687, eq: 0.777183 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.136967, evals: 108, done: 1, feasible: 0, sos: 0.0916006, f: 0, ineq: 0.211146, eq: 0.777708 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.077954, evals: 62, done: 1, feasible: 0, sos: 0.0677848, f: 0, ineq: 0.313696, eq: 2.73516 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.160888, evals: 108, done: 1, feasible: 0, sos: 0.0676662, f: 0, ineq: 0.358584, eq: 2.67566 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.078287, evals: 60, done: 1, feasible: 0, sos: 0.0894925, f: 0, ineq: 0.212415, eq: 0.831157 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.078227, evals: 58, done: 1, feasible: 0, sos: 0.0735678, f: 0, ineq: 0.209717, eq: 0.891586 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.081584, evals: 66, done: 1, feasible: 0, sos: 0.0894508, f: 0, ineq: 0.206751, eq: 0.84587 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.116513, evals: 94, done: 1, feasible: 0, sos: 0.0635648, f: 0, ineq: 0.213775, eq: 0.901727 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.09014, evals: 79, done: 1, feasible: 0, sos: 0.0668177, f: 0, ineq: 0.26393, eq: 2.82836 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.155112, evals: 131, done: 1, feasible: 0, sos: 0.0625045, f: 0, ineq: 0.212336, eq: 0.83862 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.111846, evals: 100, done: 1, feasible: 0, sos: 0.0627017, f: 0, ineq: 0.211746, eq: 0.838222 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.141703, evals: 126, done: 1, feasible: 0, sos: 0.0910599, f: 0, ineq: 0.211102, eq: 0.789807 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.130584, evals: 118, done: 1, feasible: 0, sos: 0.091582, f: 0, ineq: 0.209341, eq: 0.782693 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.118376, evals: 100, done: 1, feasible: 0, sos: 0.0658338, f: 0, ineq: 0.21059, eq: 0.861253 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.173417, evals: 151, done: 1, feasible: 0, sos: 0.0628872, f: 0, ineq: 0.212056, eq: 0.836131 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.131299, evals: 118, done: 1, feasible: 0, sos: 0.0910605, f: 0, ineq: 0.212262, eq: 0.790445 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.196146, evals: 161, done: 1, feasible: 0, sos: 0.0640833, f: 0, ineq: 0.210136, eq: 0.825206 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.137932, evals: 123, done: 1, feasible: 0, sos: 0.0934872, f: 0, ineq: 0.201246, eq: 0.758015 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.107827, evals: 92, done: 1, feasible: 0, sos: 0.0651171, f: 0, ineq: 0.211085, eq: 0.869621 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.119247, evals: 101, done: 1, feasible: 0, sos: 0.0603058, f: 0, ineq: 0.215639, eq: 0.86846 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.268177, evals: 200, done: 1, feasible: 0, sos: 0.0822625, f: 0, ineq: 0.178049, eq: 1.21748 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.24257, evals: 200, done: 1, feasible: 0, sos: 0.0855956, f: 0, ineq: 0.231943, eq: 1.23918 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.072354, evals: 64, done: 1, feasible: 0, sos: 0.0634457, f: 0, ineq: 0.213952, eq: 0.900724 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.131213, evals: 106, done: 1, feasible: 0, sos: 0.0626498, f: 0, ineq: 0.211325, eq: 0.838411 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.192003, evals: 138, done: 1, feasible: 0, sos: 0.0918781, f: 0, ineq: 0.210811, eq: 0.76931 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.156207, evals: 115, done: 1, feasible: 0, sos: 0.0625098, f: 0, ineq: 0.213017, eq: 0.841121 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.115856, evals: 99, done: 1, feasible: 0, sos: 0.0652429, f: 0, ineq: 0.211608, eq: 0.871085 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.146655, evals: 120, done: 1, feasible: 0, sos: 0.062527, f: 0, ineq: 0.210853, eq: 0.833702 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.160341, evals: 122, done: 1, feasible: 0, sos: 0.0637286, f: 0, ineq: 0.207207, eq: 0.813703 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.117522, evals: 112, done: 1, feasible: 0, sos: 0.0915984, f: 0, ineq: 0.209311, eq: 0.782609 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.252438, evals: 190, done: 1, feasible: 0, sos: 0.0850349, f: 0, ineq: 0.175832, eq: 1.19458 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.097643, evals: 86, done: 1, feasible: 0, sos: 0.0648777, f: 0, ineq: 0.212436, eq: 0.875729 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.25225, evals: 195, done: 1, feasible: 0, sos: 0.0644067, f: 0, ineq: 0.212491, eq: 0.884267 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.212873, evals: 165, done: 1, feasible: 0, sos: 0.0818908, f: 0, ineq: 0.175422, eq: 1.21993 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.13528, evals: 109, done: 1, feasible: 0, sos: 0.0625278, f: 0, ineq: 0.212281, eq: 0.838612 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.224562, evals: 165, done: 1, feasible: 0, sos: 0.0639032, f: 0, ineq: 0.210419, eq: 0.826838 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.145163, evals: 118, done: 1, feasible: 0, sos: 0.0910587, f: 0, ineq: 0.210994, eq: 0.790243 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.152572, evals: 126, done: 1, feasible: 0, sos: 0.0658753, f: 0, ineq: 0.210841, eq: 0.855214 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.130563, evals: 85, done: 1, feasible: 0, sos: 0.063494, f: 0, ineq: 0.215742, eq: 0.910033 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.104121, evals: 71, done: 1, feasible: 0, sos: 0.0736697, f: 0, ineq: 0.207331, eq: 0.880631 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.13633, evals: 99, done: 1, feasible: 0, sos: 0.0672747, f: 0, ineq: 0.215651, eq: 0.868286 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.279756, evals: 200, done: 1, feasible: 0, sos: 0.0977048, f: 0, ineq: 0.235641, eq: 0.84858 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.256439, evals: 201, done: 1, feasible: 0, sos: 0.0853418, f: 0, ineq: 0.21175, eq: 1.23068 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.144871, evals: 124, done: 1, feasible: 0, sos: 0.0916161, f: 0, ineq: 0.210411, eq: 0.775702 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.080645, evals: 66, done: 1, feasible: 0, sos: 0.0700912, f: 0, ineq: 0.254988, eq: 2.81002 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.145267, evals: 113, done: 1, feasible: 0, sos: 0.0624818, f: 0, ineq: 0.212154, eq: 0.838547 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.198944, evals: 160, done: 1, feasible: 0, sos: 0.0659249, f: 0, ineq: 0.211276, eq: 0.853365 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.244262, evals: 200, done: 1, feasible: 0, sos: 0.0852618, f: 0, ineq: 0.208682, eq: 1.22777 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.129981, evals: 93, done: 1, feasible: 0, sos: 0.0649946, f: 0, ineq: 0.211828, eq: 0.872034 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.080875, evals: 69, done: 1, feasible: 0, sos: 0.067459, f: 0, ineq: 0.342712, eq: 2.69065 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.119945, evals: 96, done: 1, feasible: 0, sos: 0.0735869, f: 0, ineq: 0.21926, eq: 0.967081 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.128089, evals: 117, done: 1, feasible: 0, sos: 0.0915989, f: 0, ineq: 0.209098, eq: 0.78298 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.143766, evals: 121, done: 1, feasible: 0, sos: 0.0644575, f: 0, ineq: 0.212291, eq: 0.880935 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.102877, evals: 93, done: 1, feasible: 0, sos: 0.0637257, f: 0, ineq: 0.21329, eq: 0.895562 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.068201, evals: 61, done: 1, feasible: 0, sos: 0.075017, f: 0, ineq: 0.220064, eq: 2.73278 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.256064, evals: 200, done: 1, feasible: 0, sos: 0.0839659, f: 0, ineq: 0.175636, eq: 1.19303 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.090848, evals: 83, done: 1, feasible: 0, sos: 0.0637243, f: 0, ineq: 0.213289, eq: 0.895484 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.135673, evals: 119, done: 1, feasible: 0, sos: 0.0915783, f: 0, ineq: 0.211497, eq: 0.777273 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.212414, evals: 165, done: 1, feasible: 0, sos: 0.0814996, f: 0, ineq: 0.180731, eq: 1.22885 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.126055, evals: 113, done: 1, feasible: 0, sos: 0.0916555, f: 0, ineq: 0.213784, eq: 0.775399 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.070043, evals: 58, done: 1, feasible: 0, sos: 0.0729814, f: 0, ineq: 0.243728, eq: 0.900536 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.09869, evals: 77, done: 1, feasible: 0, sos: 0.0633424, f: 0, ineq: 0.21381, eq: 0.901051 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.222873, evals: 171, done: 1, feasible: 0, sos: 0.0814631, f: 0, ineq: 0.172789, eq: 1.22314 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.064664, evals: 54, done: 1, feasible: 0, sos: 0.0731744, f: 0, ineq: 0.23341, eq: 0.929624 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.123579, evals: 85, done: 1, feasible: 0, sos: 0.0640157, f: 0, ineq: 0.213274, eq: 0.894236 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.147061, evals: 111, done: 1, feasible: 0, sos: 0.0915483, f: 0, ineq: 0.208998, eq: 0.789217 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.16185, evals: 120, done: 1, feasible: 0, sos: 0.0624169, f: 0, ineq: 0.211934, eq: 0.83786 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.111533, evals: 98, done: 1, feasible: 0, sos: 0.0626508, f: 0, ineq: 0.211949, eq: 0.847495 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.131777, evals: 95, done: 1, feasible: 0, sos: 0.0646995, f: 0, ineq: 0.214208, eq: 0.881074 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.141396, evals: 111, done: 1, feasible: 0, sos: 0.0915598, f: 0, ineq: 0.208854, eq: 0.789247 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.272278, evals: 193, done: 1, feasible: 0, sos: 0.0844322, f: 0, ineq: 0.174139, eq: 1.18939 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.14336, evals: 102, done: 1, feasible: 0, sos: 0.0630441, f: 0, ineq: 0.210902, eq: 0.836685 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.086666, evals: 68, done: 1, feasible: 0, sos: 0.0675676, f: 0, ineq: 0.284728, eq: 2.75869 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.162787, evals: 113, done: 1, feasible: 0, sos: 0.0626025, f: 0, ineq: 0.211678, eq: 0.840063 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.262358, evals: 200, done: 1, feasible: 0, sos: 0.0863314, f: 0, ineq: 0.2267, eq: 1.23743 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.145705, evals: 117, done: 1, feasible: 0, sos: 0.0916168, f: 0, ineq: 0.210407, eq: 0.775692 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.069423, evals: 54, done: 1, feasible: 0, sos: 0.0730343, f: 0, ineq: 0.192806, eq: 1.00129 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.119253, evals: 93, done: 1, feasible: 0, sos: 0.0649791, f: 0, ineq: 0.211675, eq: 0.872115 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.108175, evals: 84, done: 1, feasible: 0, sos: 0.0655223, f: 0, ineq: 0.278629, eq: 2.84815 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.122707, evals: 99, done: 1, feasible: 0, sos: 0.0635544, f: 0, ineq: 0.213361, eq: 0.89918 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.140616, evals: 111, done: 1, feasible: 0, sos: 0.0915946, f: 0, ineq: 0.208572, eq: 0.784076 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.14067, evals: 116, done: 1, feasible: 0, sos: 0.0915955, f: 0, ineq: 0.209527, eq: 0.781798 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.090561, evals: 88, done: 1, feasible: 0, sos: 0.0655746, f: 0, ineq: 0.210816, eq: 0.861612 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.267181, evals: 200, done: 1, feasible: 0, sos: 0.0830206, f: 0, ineq: 0.176925, eq: 1.20752 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.106252, evals: 93, done: 1, feasible: 0, sos: 0.0655727, f: 0, ineq: 0.210976, eq: 0.860311 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.155469, evals: 126, done: 1, feasible: 0, sos: 0.0644707, f: 0, ineq: 0.21101, eq: 0.88442 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.109643, evals: 92, done: 1, feasible: 0, sos: 0.0635863, f: 0, ineq: 0.213408, eq: 0.897014 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.064949, evals: 63, done: 1, feasible: 0, sos: 0.0894856, f: 0, ineq: 0.213188, eq: 0.829092 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.134169, evals: 95, done: 1, feasible: 0, sos: 0.0700039, f: 0, ineq: 0.220098, eq: 2.83216 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.071971, evals: 63, done: 1, feasible: 0, sos: 0.0792524, f: 0, ineq: 0.157365, eq: 1.23108 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.162962, evals: 135, done: 1, feasible: 0, sos: 0.0645269, f: 0, ineq: 0.209006, eq: 0.817396 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.129404, evals: 104, done: 1, feasible: 0, sos: 0.0648459, f: 0, ineq: 0.211768, eq: 0.873705 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.127812, evals: 105, done: 1, feasible: 0, sos: 0.0646121, f: 0, ineq: 0.212413, eq: 0.876092 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.146503, evals: 123, done: 1, feasible: 0, sos: 0.0624849, f: 0, ineq: 0.21169, eq: 0.839241 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.243997, evals: 200, done: 1, feasible: 0, sos: 0.0837285, f: 0, ineq: 0.210695, eq: 1.22603 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.160547, evals: 126, done: 1, feasible: 0, sos: 0.0632273, f: 0, ineq: 0.211135, eq: 0.830931 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.117566, evals: 91, done: 1, feasible: 0, sos: 0.0634958, f: 0, ineq: 0.213603, eq: 0.897808 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.14115, evals: 106, done: 1, feasible: 0, sos: 0.0916168, f: 0, ineq: 0.210414, eq: 0.775757 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.175813, evals: 143, done: 1, feasible: 0, sos: 0.0639885, f: 0, ineq: 0.21295, eq: 0.888518 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.118183, evals: 102, done: 1, feasible: 0, sos: 0.0915971, f: 0, ineq: 0.209445, eq: 0.781888 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.251174, evals: 201, done: 1, feasible: 0, sos: 0.0634549, f: 0, ineq: 0.211312, eq: 0.829814 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.127758, evals: 111, done: 1, feasible: 0, sos: 0.061425, f: 0, ineq: 0.213211, eq: 0.849952 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.252427, evals: 200, done: 1, feasible: 0, sos: 0.0819368, f: 0, ineq: 0.174394, eq: 1.21951 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.148486, evals: 110, done: 1, feasible: 0, sos: 0.0629593, f: 0, ineq: 0.210913, eq: 0.836984 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.129878, evals: 112, done: 1, feasible: 0, sos: 0.091604, f: 0, ineq: 0.210443, eq: 0.777538 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.23016, evals: 175, done: 1, feasible: 0, sos: 0.0807794, f: 0, ineq: 0.172445, eq: 1.23065 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.139991, evals: 106, done: 1, feasible: 0, sos: 0.0627599, f: 0, ineq: 0.211765, eq: 0.838386 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.083958, evals: 78, done: 1, feasible: 0, sos: 0.0634502, f: 0, ineq: 0.213867, eq: 0.899797 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.112361, evals: 98, done: 1, feasible: 0, sos: 0.0657762, f: 0, ineq: 0.21153, eq: 0.860059 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.081144, evals: 64, done: 1, feasible: 0, sos: 0.0894606, f: 0, ineq: 0.213476, eq: 0.829824 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.099573, evals: 90, done: 1, feasible: 0, sos: 0.0643463, f: 0, ineq: 0.213012, eq: 0.881325 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.078319, evals: 64, done: 1, feasible: 0, sos: 0.0674175, f: 0, ineq: 0.27274, eq: 2.8371 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.083811, evals: 67, done: 1, feasible: 0, sos: 0.0894144, f: 0, ineq: 0.216952, eq: 0.826168 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.149751, evals: 121, done: 1, feasible: 0, sos: 0.0628878, f: 0, ineq: 0.211516, eq: 0.837614 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.139232, evals: 104, done: 1, feasible: 0, sos: 0.0915972, f: 0, ineq: 0.209405, eq: 0.782698 }
# True
# n_success: 1
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.14678, evals: 105, done: 1, feasible: 0, sos: 0.0626528, f: 0, ineq: 0.212012, eq: 0.839831 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.079783, evals: 65, done: 1, feasible: 0, sos: 0.0690998, f: 0, ineq: 0.279117, eq: 2.79104 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.074283, evals: 58, done: 1, feasible: 0, sos: 0.0721567, f: 0, ineq: 0.224781, eq: 2.74872 }
# True
# n_success: 1
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box2)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 94
#      90     M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
#      91     #M.keep_distance([], box, not_picked_boxes[0], margin = 0.06)
#      92     #M.keep_distance([], box, not_picked_boxes[1], margin = 0.06)
# ---> 94 ways = M.solve()
#      96 if not M.feasible:
#      97     print("True")
#
# File ~/Desktop/SHK_LIS/manipulationAbstraction/manipulation.py:478, in ManipulationModelling.solve(self, verbose)
#     476 sol.setProblem(self.komo.nlp())
#     477 sol.setOptions(damping=1e-3, verbose=verbose-1, stopTolerance=1e-3, maxLambda=100., stopEvals=200)
# --> 478 self.ret = sol.solve()
#     479 if self.ret.feasible:
#     480     self.path = self.komo.getPath()
#
# KeyboardInterrupt:

# %% [markdown]
# ### On real robot: BotOp

# %%
import robotic as ry
import numpy as np
from bridgebuild_env import create_n_boxes
import robot_execution as robex
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import random

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed", shelf = True)

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=True)
bot.goHome(C)
# Out:
# -- bot.cpp:~BotOp:135(0) shutting down BotOp...
# -- simulation.cpp:~BotThreadedSim:57(0) shutting down SimThread
# -- simulation.cpp:~Simulation:148(0) shutting down Simulation

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
boxes_all = [box1, box2, box3]

last_box_memory = []
paths = []
vis = 1
n_success = 0
boxz = [box1, box3, box2]
while n_success <= 2:
    box = np.random.choice(boxes)
    not_picked_boxes = [i for i in boxes_all if i != box]
    # box = boxz[n_success]
    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])  # z grasp removed
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, phases = 3., homing_scale=1.5e-1, accumulated_collisions=True
    )
    M.grasp_box(1., gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    # 3rd block constraints
    if n_success > 1:
        print(f"3rd Block: ({box})")
        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.06])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)

        print("Grasp Direction:", graspDirection)
        """
        if graspDirection == "x":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductXZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        elif graspDirection == "y":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductYZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        
        else:
           M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])
        """
    # 2nd block constraints
    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
        M.keep_distance([], box, last_box_memory[-1], margin = 0.06)
        #M.keep_distance([], box, not_picked_boxes[1], margin = 0.08)

    M.keep_distance([], palm, table)
    
    # 1st block constraints
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        # place inital block as chosen by np.random.choice at a random location
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2.0, box, table, initial_pos)
        M.keep_distance([], box, not_picked_boxes[0], margin = 0.06)
        M.keep_distance([], box, not_picked_boxes[1], margin = 0.06)

    ways = M.solve()

    if not M.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
        )
        continue
    print("Submotion 0")
    M2 = M.sub_motion(0)
    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.012)
    M2.approach([0.8, 1.0], gripper)
    
    
    paths.append(M2.solve())

    if not M2.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :("
        )
        continue

    M3 = M.sub_motion(1)

    M3.keep_distance([], table, box)
    if n_success >= 0:
        M3.retract([0.0, 0.2], gripper, dist=0.025)
        M3.approach([0.8, 1.0], gripper)
    

    paths.append(M3.solve())
    if not M3.ret.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :("
        )
        continue

    M_report = M.komo.report(True)

    # M_report = M.fetch_name_error_type(M_report)
    # M.print_name_error_type(M_report)

    M2_report = M2.komo.report(True)
    # M2_report = M.fetch_name_error_type(M2_report)
    # M.print_name_error_type(M2_report)

    M3_report = M3.komo.report(True)
    # M3_report = M.fetch_name_error_type(M3_report)
    # M.print_name_error_type(M3_report)

    if vis == 0:
        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)

    bot.execute_path_blocking(C, path=paths[-2])
    C.attach(gripper, box)
    bot.grasp(C)

    bot.execute_path_blocking(C, path=paths[-1])
    C.attach(table, box)
    bot.release(C)

    M_retract = M.sub_motion(2)
    M_retract.retract([0.0, 0.2], gripper, dist=0.1)
    retract_path = M_retract.solve()
    print(f"Retract path:{retract_path}")
    bot.execute_path_blocking(C, path=retract_path)

    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1

bot.goHome
del M
# Out:
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.06780366254185077, 0.07565401266699041]
#   -- feasible:placement 0: grasp x place z
#      { time: 0.134147, evals: 73, done: 1, feasible: 1, sos: 0.176201, f: 0, ineq: 5.83119e-05, eq: 0.0537046 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.197795, evals: 17, done: 1, feasible: 1, sos: 1.25387, f: 0, ineq: 9.91421e-07, eq: 0.0504977 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.214083, evals: 21, done: 1, feasible: 1, sos: 0.514143, f: 0, ineq: 0.00141815, eq: 0.0562952 }
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-box2 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:891(0) REMOVING JOINT 0xa3c8bf0-0x91bd560 of type rigid
#   -- feasible:sub_motion_2--placement 0: grasp x place z
#      { time: 0.053659, evals: 9, done: 1, feasible: 1, sos: 0.912522, f: 0, ineq: 8.90189e-06, eq: 0.051969 }
# Retract path:[[ 0.05252928  0.16169319 -0.13909722 -2.55929943 -0.2321849   1.95180113
#    0.61766816]
#  [ 0.05592858  0.15283976 -0.13403509 -2.53153185 -0.22440859  1.91494321
#    0.61431636]
#  [ 0.05994202  0.14118266 -0.12795286 -2.49510073 -0.21550759  1.86658117
#    0.61012557]
#  [ 0.06394348  0.12776134 -0.12168634 -2.45358362 -0.20694778  1.81138636
#    0.60551322]
#  [ 0.06748291  0.11355716 -0.11581789 -2.41069024 -0.19966402  1.75408518
#    0.600822  ]
#  [ 0.07024684  0.09950141 -0.11072969 -2.37023069 -0.1941105   1.69944853
#    0.59628177]
#  [ 0.07214082  0.08411109 -0.10580707 -2.33399453 -0.1883263   1.6552512
#    0.58596459]
#  [ 0.07322609  0.06753736 -0.10105265 -2.30176895 -0.18234733  1.62082528
#    0.57034881]
#  [ 0.07356388  0.04993121 -0.09646901 -2.27334102 -0.17620945  1.59550296
#    0.54991245]
#  [ 0.07321539  0.03144347 -0.09205869 -2.24849773 -0.16994846  1.57861655
#    0.5251332 ]
#  [ 0.07224182  0.01222478 -0.08782421 -2.22702599 -0.16360011  1.56949848
#    0.49648841]
#  [ 0.07070431 -0.00757438 -0.08376806 -2.20871262 -0.1572001   1.56748132
#    0.46445515]
#  [ 0.06866401 -0.02780366 -0.0798927  -2.19334438 -0.15078406  1.57189775
#    0.42951018]
#  [ 0.06618204 -0.04831288 -0.07620058 -2.18070795 -0.1443876   1.58208059
#    0.39212994]
#  [ 0.06331948 -0.06895201 -0.0726941  -2.17058997 -0.13804627  1.59736278
#    0.3527906 ]
#  [ 0.06013741 -0.08957115 -0.06937567 -2.16277702 -0.13179558  1.61707741
#    0.31196809]
#  [ 0.05669689 -0.11002051 -0.06624764 -2.15705561 -0.125671    1.64055765
#    0.27013804]
#  [ 0.05305896 -0.13015046 -0.06331237 -2.15321221 -0.11970794  1.66713682
#    0.22777584]
#  [ 0.04928464 -0.14981146 -0.06057218 -2.15103325 -0.1139418   1.69614831
#    0.18535668]
#  [ 0.04543493 -0.16885408 -0.05802939 -2.15030509 -0.10840792  1.72692563
#    0.1433555 ]
#  [ 0.04157082 -0.18712902 -0.05568628 -2.15081405 -0.10314164  1.75880237
#    0.10224705]
#  [ 0.03775329 -0.20448706 -0.05354513 -2.15234641 -0.09817822  1.79111219
#    0.06250588]
#  [ 0.0340433  -0.22077908 -0.05160819 -2.15468839 -0.09355293  1.82318881
#    0.02460638]
#  [ 0.03050181 -0.23585603 -0.04987772 -2.15762617 -0.08930099  1.85436602
#   -0.01097726]
#  [ 0.02718976 -0.24956898 -0.04835592 -2.16094587 -0.08545759  1.88397763
#   -0.04377095]
#  [ 0.02416808 -0.26176903 -0.04704501 -2.16443357 -0.08205791  1.91135751
#   -0.0733008 ]
#  [ 0.02149771 -0.2723074  -0.04594719 -2.16787529 -0.07913709  1.93583955
#   -0.099093  ]
#  [ 0.01923957 -0.28103535 -0.04506463 -2.17105699 -0.07673025  1.95675762
#   -0.12067389]
#  [ 0.01745456 -0.28780422 -0.0443995  -2.17376459 -0.0748725   1.97344565
#   -0.13756993]
#  [ 0.0162036  -0.2924654  -0.04395396 -2.17578396 -0.0735989   1.98523753
#   -0.14930765]
#  [ 0.0155476  -0.29487037 -0.04373015 -2.17690088 -0.07294452  1.99146716
#   -0.15541372]
#  [ 0.01554746 -0.29487063 -0.04373019 -2.17690111 -0.07294437  1.99146844
#   -0.15541488]]
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box3)
#   -- feasible:placement 1: grasp x place z
#      { time: 0.155232, evals: 107, done: 1, feasible: 1, sos: 0.131745, f: 0, ineq: 0.103555, eq: 0.193421 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.116583, evals: 15, done: 1, feasible: 1, sos: 0.731312, f: 0, ineq: 1.03999e-06, eq: 0.047763 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.248482, evals: 25, done: 1, feasible: 1, sos: 0.502833, f: 0, ineq: 0.00111016, eq: 0.0529433 }
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-box3 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:891(0) REMOVING JOINT 0xa3c8bf0-0x5070190 of type rigid
#   -- feasible:sub_motion_2--placement 1: grasp x place z
#      { time: 0.146737, evals: 21, done: 1, feasible: 1, sos: 0.795738, f: 0, ineq: 6.67207e-06, eq: 0.0490895 }
# Retract path:[[-2.38775071e-02  2.64768029e-01 -2.26761000e-01 -2.36779153e+00
#   -2.57001507e-01  2.00399263e+00  4.47482460e-01]
#  [-2.06286034e-02  2.50676808e-01 -2.22753674e-01 -2.34563731e+00
#   -2.52445868e-01  1.96739211e+00  4.44638529e-01]
#  [-1.67426931e-02  2.32122719e-01 -2.18001315e-01 -2.31661666e+00
#   -2.47437426e-01  1.91946858e+00  4.40755078e-01]
#  [-1.28155195e-02  2.10787787e-01 -2.13216318e-01 -2.28361014e+00
#   -2.42976114e-01  1.86489162e+00  4.36033163e-01]
#  [-9.29979552e-03  1.88287635e-01 -2.08903205e-01 -2.24962144e+00
#   -2.39707207e-01  1.80834078e+00  4.30731459e-01]
#  [-6.52151769e-03  1.66167089e-01 -2.05377719e-01 -2.21776825e+00
#   -2.37892143e-01  1.75450141e+00  4.25152523e-01]
#  [-4.15965425e-03  1.43591978e-01 -2.01209615e-01 -2.18968071e+00
#   -2.34987791e-01  1.71065154e+00  4.14961577e-01]
#  [-2.18943998e-03  1.20667981e-01 -1.96461551e-01 -2.16515590e+00
#   -2.31087359e-01  1.67615689e+00  4.00546614e-01]
#  [-5.86108426e-04  9.75005812e-02 -1.91196128e-01 -2.14399078e+00
#   -2.26283984e-01  1.65038329e+00  3.82295346e-01]
#  [ 6.75107469e-04  7.41950705e-02 -1.85475883e-01 -2.12598232e+00
#   -2.20670732e-01  1.63269668e+00  3.60595211e-01]
#  [ 1.61897487e-03  5.08565607e-02 -1.79363297e-01 -2.11092739e+00
#   -2.14340599e-01  1.62246307e+00  3.35833376e-01]
#  [ 2.27026065e-03  2.75899885e-02 -1.72920795e-01 -2.09862287e+00
#   -2.07386516e-01  1.61904862e+00  3.08396746e-01]
#  [ 2.65373105e-03  4.50012312e-03 -1.66210746e-01 -2.08886557e+00
#   -1.99901346e-01  1.62181958e+00  2.78671973e-01]
#  [ 2.79415153e-03 -1.83084264e-02 -1.59295467e-01 -2.08145228e+00
#   -1.91977889e-01  1.63014233e+00  2.47045459e-01]
#  [ 2.71628660e-03 -4.07312043e-02 -1.52237225e-01 -2.07617977e+00
#   -1.83708885e-01  1.64338333e+00  2.13903374e-01]
#  [ 2.44489982e-03 -6.26639008e-02 -1.45098238e-01 -2.07284477e+00
#   -1.75187013e-01  1.66090919e+00  1.79631656e-01]
#  [ 2.00475382e-03 -8.40023452e-02 -1.37940679e-01 -2.07124399e+00
#   -1.66504901e-01  1.68208661e+00  1.44616032e-01]
#  [ 1.42061036e-03 -1.04642499e-01 -1.30826677e-01 -2.07117412e+00
#   -1.57755119e-01  1.70628238e+00  1.09242020e-01]
#  [ 7.17230557e-04 -1.24480451e-01 -1.23818320e-01 -2.07243183e+00
#   -1.49030190e-01  1.73286339e+00  7.38949452e-02]
#  [-8.06250024e-05 -1.43412406e-01 -1.16977655e-01 -2.07481375e+00
#   -1.40422587e-01  1.76119661e+00  3.89599514e-02]
#  [-9.48195973e-04 -1.61334685e-01 -1.10366694e-01 -2.07811649e+00
#   -1.32024742e-01  1.79064909e+00  4.82200952e-03]
#  [-1.86072201e-03 -1.78143715e-01 -1.04047413e-01 -2.08213665e+00
#   -1.23929042e-01  1.82058793e+00 -2.81340691e-02]
#  [-2.79344246e-03 -1.93736025e-01 -9.80817554e-02 -2.08667079e+00
#   -1.16227837e-01  1.85038031e+00 -5.95236224e-02]
#  [-3.72159610e-03 -2.08008240e-01 -9.25316349e-02 -2.09151545e+00
#   -1.09013439e-01  1.87939343e+00 -8.89621268e-02]
#  [-4.62042079e-03 -2.20857078e-01 -8.74589350e-02 -2.09646712e+00
#   -1.02378127e-01  1.90699455e+00 -1.16065187e-01]
#  [-5.46515317e-03 -2.32179342e-01 -8.29255126e-02 -2.10132230e+00
#   -9.64141489e-02  1.93255093e+00 -1.40448528e-01]
#  [-6.23102839e-03 -2.41871921e-01 -7.89931989e-02 -2.10587741e+00
#   -9.12137230e-02  1.95542987e+00 -1.61727984e-01]
#  [-6.89327983e-03 -2.49831781e-01 -7.57238012e-02 -2.10992886e+00
#   -8.68690400e-02  1.97499867e+00 -1.79519491e-01]
#  [-7.42713882e-03 -2.55955966e-01 -7.31791038e-02 -2.11327304e+00
#   -8.34722650e-02  1.99062464e+00 -1.93439084e-01]
#  [-7.80783444e-03 -2.60141595e-01 -7.14208692e-02 -2.11570627e+00
#   -8.11155386e-02  2.00167506e+00 -2.03102883e-01]
#  [-8.01059337e-03 -2.62285859e-01 -7.05108387e-02 -2.11702485e+00
#   -7.98909787e-02  2.00751723e+00 -2.08127099e-01]
#  [-8.01063974e-03 -2.62286018e-01 -7.05107334e-02 -2.11702505e+00
#   -7.98906803e-02  2.00751842e+00 -2.08128023e-01]]
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.104512, evals: 92, done: 1, feasible: 0, sos: 0.388139, f: 0, ineq: 0.0347914, eq: 1.20607 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.200886, evals: 166, done: 1, feasible: 0, sos: 0.388779, f: 0, ineq: 0.033326, eq: 1.17335 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086394, evals: 73, done: 1, feasible: 0, sos: 0.289757, f: 0, ineq: 0.208055, eq: 0.962076 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.105769, evals: 75, done: 1, feasible: 0, sos: 0.288943, f: 0, ineq: 0.233751, eq: 0.960881 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.154946, evals: 127, done: 1, feasible: 0, sos: 0.384737, f: 0, ineq: 0.0276136, eq: 1.00898 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.096482, evals: 85, done: 1, feasible: 0, sos: 0.290881, f: 0, ineq: 0.341305, eq: 1.44245 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.146831, evals: 114, done: 1, feasible: 0, sos: 0.389451, f: 0, ineq: 0.0335275, eq: 1.16612 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.101655, evals: 72, done: 1, feasible: 0, sos: 0.288569, f: 0, ineq: 0.212633, eq: 0.930722 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.21214, evals: 172, done: 1, feasible: 0, sos: 0.266303, f: 0, ineq: 0.133124, eq: 0.893416 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.212282, evals: 168, done: 1, feasible: 0, sos: 0.262981, f: 0, ineq: 0.130432, eq: 0.89673 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.097896, evals: 73, done: 1, feasible: 0, sos: 0.291636, f: 0, ineq: 0.188041, eq: 0.917782 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085605, evals: 73, done: 1, feasible: 0, sos: 0.384401, f: 0, ineq: 0.0570682, eq: 1.27003 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.245032, evals: 200, done: 1, feasible: 0, sos: 0.286477, f: 0, ineq: 0.146978, eq: 0.864558 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085496, evals: 68, done: 1, feasible: 0, sos: 0.388649, f: 0, ineq: 0.045956, eq: 1.30553 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.130037, evals: 114, done: 1, feasible: 0, sos: 0.388371, f: 0, ineq: 0.0406809, eq: 1.21063 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08867, evals: 74, done: 1, feasible: 0, sos: 0.283373, f: 0, ineq: 0.20678, eq: 0.982417 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082918, evals: 73, done: 1, feasible: 0, sos: 0.388682, f: 0, ineq: 0.0450331, eq: 1.30324 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.140613, evals: 114, done: 1, feasible: 0, sos: 0.389408, f: 0, ineq: 0.0337322, eq: 1.19602 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.126525, evals: 95, done: 1, feasible: 0, sos: 0.267568, f: 0, ineq: 0.157084, eq: 0.918298 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.095092, evals: 89, done: 1, feasible: 0, sos: 0.268602, f: 0, ineq: 0.171105, eq: 0.932962 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.148401, evals: 113, done: 1, feasible: 0, sos: 0.385853, f: 0, ineq: 0.025927, eq: 0.999267 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.111954, evals: 79, done: 1, feasible: 0, sos: 0.384525, f: 0, ineq: 0.0659476, eq: 1.28965 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.173796, evals: 133, done: 1, feasible: 0, sos: 0.387731, f: 0, ineq: 0.0361312, eq: 1.20232 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.081563, evals: 66, done: 1, feasible: 0, sos: 0.384712, f: 0, ineq: 0.0500433, eq: 1.30041 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.140409, evals: 107, done: 1, feasible: 0, sos: 0.386444, f: 0, ineq: 0.0332899, eq: 1.11147 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.106491, evals: 88, done: 1, feasible: 0, sos: 0.385454, f: 0, ineq: 0.0279193, eq: 1.08676 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.219272, evals: 179, done: 1, feasible: 0, sos: 0.268387, f: 0, ineq: 0.151784, eq: 0.916496 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.188514, evals: 147, done: 1, feasible: 0, sos: 0.388218, f: 0, ineq: 0.0347891, eq: 1.18741 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.120299, evals: 94, done: 1, feasible: 0, sos: 0.386432, f: 0, ineq: 0.0264237, eq: 0.958343 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.202, evals: 168, done: 1, feasible: 0, sos: 0.388602, f: 0, ineq: 0.0493248, eq: 1.1614 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.09848, evals: 77, done: 1, feasible: 0, sos: 0.292169, f: 0, ineq: 0.182906, eq: 0.924333 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.074676, evals: 63, done: 1, feasible: 0, sos: 0.294169, f: 0, ineq: 0.247372, eq: 0.98605 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081064, evals: 72, done: 1, feasible: 0, sos: 0.290433, f: 0, ineq: 0.21546, eq: 0.914464 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.147701, evals: 115, done: 1, feasible: 0, sos: 0.276015, f: 0, ineq: 0.180165, eq: 0.941588 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.145517, evals: 110, done: 1, feasible: 0, sos: 0.389183, f: 0, ineq: 0.0347614, eq: 1.1763 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091157, evals: 67, done: 1, feasible: 0, sos: 0.38411, f: 0, ineq: 0.0672718, eq: 1.31351 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.110863, evals: 74, done: 1, feasible: 0, sos: 0.293619, f: 0, ineq: 0.216516, eq: 0.906783 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08017, evals: 68, done: 1, feasible: 0, sos: 0.29058, f: 0, ineq: 0.310854, eq: 1.21161 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.161045, evals: 125, done: 1, feasible: 0, sos: 0.38934, f: 0, ineq: 0.0341244, eq: 1.16936 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.255115, evals: 201, done: 1, feasible: 0, sos: 0.280136, f: 0, ineq: 0.166574, eq: 0.890994 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.166212, evals: 139, done: 1, feasible: 0, sos: 0.260836, f: 0, ineq: 0.123293, eq: 0.899477 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08535, evals: 71, done: 1, feasible: 0, sos: 0.382498, f: 0, ineq: 0.0388139, eq: 1.2716 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.142508, evals: 115, done: 1, feasible: 0, sos: 0.389635, f: 0, ineq: 0.0333389, eq: 1.16499 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.073352, evals: 63, done: 1, feasible: 0, sos: 0.293599, f: 0, ineq: 0.288039, eq: 1.20784 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.131913, evals: 104, done: 1, feasible: 0, sos: 0.384106, f: 0, ineq: 0.0297967, eq: 0.954332 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080229, evals: 73, done: 1, feasible: 0, sos: 0.291593, f: 0, ineq: 0.187024, eq: 0.919982 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087131, evals: 69, done: 1, feasible: 0, sos: 0.389886, f: 0, ineq: 0.04227, eq: 1.30906 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.115447, evals: 84, done: 1, feasible: 0, sos: 0.386248, f: 0, ineq: 0.0567598, eq: 1.24413 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.121358, evals: 91, done: 1, feasible: 0, sos: 0.386855, f: 0, ineq: 0.0267832, eq: 1.02209 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088992, evals: 77, done: 1, feasible: 0, sos: 0.277413, f: 0, ineq: 0.206475, eq: 0.933967 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.088212, evals: 77, done: 1, feasible: 0, sos: 0.279542, f: 0, ineq: 0.196238, eq: 0.931933 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.220197, evals: 165, done: 1, feasible: 0, sos: 0.268802, f: 0, ineq: 0.127534, eq: 0.897228 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.136256, evals: 100, done: 1, feasible: 0, sos: 0.385402, f: 0, ineq: 0.0293948, eq: 1.02666 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.108162, evals: 91, done: 1, feasible: 0, sos: 0.267472, f: 0, ineq: 0.150457, eq: 0.902433 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.107252, evals: 84, done: 1, feasible: 0, sos: 0.291438, f: 0, ineq: 0.191982, eq: 0.924263 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.115006, evals: 99, done: 1, feasible: 0, sos: 0.29548, f: 0, ineq: 0.354009, eq: 1.41549 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082294, evals: 65, done: 1, feasible: 0, sos: 0.293372, f: 0, ineq: 0.304308, eq: 1.11637 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082094, evals: 73, done: 1, feasible: 0, sos: 0.384352, f: 0, ineq: 0.0882872, eq: 1.29989 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.140494, evals: 112, done: 1, feasible: 0, sos: 0.38804, f: 0, ineq: 0.0346408, eq: 1.1999 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.174846, evals: 147, done: 1, feasible: 0, sos: 0.275185, f: 0, ineq: 0.15891, eq: 0.906279 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.126679, evals: 97, done: 1, feasible: 0, sos: 0.38495, f: 0, ineq: 0.028921, eq: 0.963058 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.110085, evals: 95, done: 1, feasible: 0, sos: 0.268185, f: 0, ineq: 0.163408, eq: 0.916031 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.092948, evals: 75, done: 1, feasible: 0, sos: 0.291542, f: 0, ineq: 0.187995, eq: 0.922263 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083958, evals: 70, done: 1, feasible: 0, sos: 0.30379, f: 0, ineq: 0.413334, eq: 1.35626 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085622, evals: 74, done: 1, feasible: 0, sos: 0.387055, f: 0, ineq: 0.0430901, eq: 1.1853 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082814, evals: 72, done: 1, feasible: 0, sos: 0.383756, f: 0, ineq: 0.0670567, eq: 1.1723 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.101124, evals: 77, done: 1, feasible: 0, sos: 0.29155, f: 0, ineq: 0.238106, eq: 0.926645 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.077684, evals: 66, done: 1, feasible: 0, sos: 0.385839, f: 0, ineq: 0.0681801, eq: 1.44119 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083327, evals: 75, done: 1, feasible: 0, sos: 0.282035, f: 0, ineq: 0.217415, eq: 0.903969 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.14625, evals: 113, done: 1, feasible: 0, sos: 0.389758, f: 0, ineq: 0.032976, eq: 1.15782 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.169515, evals: 132, done: 1, feasible: 0, sos: 0.388653, f: 0, ineq: 0.0413732, eq: 1.16703 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.234338, evals: 176, done: 1, feasible: 0, sos: 0.389468, f: 0, ineq: 0.0367389, eq: 1.15713 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.103781, evals: 74, done: 1, feasible: 0, sos: 0.29069, f: 0, ineq: 0.234743, eq: 0.995134 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.164966, evals: 111, done: 1, feasible: 0, sos: 0.387814, f: 0, ineq: 0.03601, eq: 1.19854 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.122853, evals: 93, done: 1, feasible: 0, sos: 0.38741, f: 0, ineq: 0.0393324, eq: 1.17623 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.101785, evals: 88, done: 1, feasible: 0, sos: 0.38588, f: 0, ineq: 0.026107, eq: 0.997741 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092212, evals: 74, done: 1, feasible: 0, sos: 0.385279, f: 0, ineq: 0.0465457, eq: 1.22987 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.221389, evals: 181, done: 1, feasible: 0, sos: 0.264917, f: 0, ineq: 0.136682, eq: 0.898282 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.137416, evals: 112, done: 1, feasible: 0, sos: 0.28855, f: 0, ineq: 0.241172, eq: 1.03779 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.10242, evals: 92, done: 1, feasible: 0, sos: 0.384424, f: 0, ineq: 0.0302004, eq: 0.96851 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.239109, evals: 188, done: 1, feasible: 0, sos: 0.264564, f: 0, ineq: 0.125414, eq: 0.895429 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.135562, evals: 110, done: 1, feasible: 0, sos: 0.38798, f: 0, ineq: 0.0359228, eq: 1.20538 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.154669, evals: 118, done: 1, feasible: 0, sos: 0.386003, f: 0, ineq: 0.0524481, eq: 1.24054 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.129227, evals: 100, done: 1, feasible: 0, sos: 0.296104, f: 0, ineq: 0.31115, eq: 1.19899 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.149561, evals: 112, done: 1, feasible: 0, sos: 0.388467, f: 0, ineq: 0.0536105, eq: 1.19306 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.12046, evals: 96, done: 1, feasible: 0, sos: 0.299292, f: 0, ineq: 0.166323, eq: 0.851453 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.097901, evals: 75, done: 1, feasible: 0, sos: 0.383752, f: 0, ineq: 0.0670068, eq: 1.17095 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.137984, evals: 95, done: 1, feasible: 0, sos: 0.38622, f: 0, ineq: 0.0459753, eq: 1.2216 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.134769, evals: 98, done: 1, feasible: 0, sos: 0.385032, f: 0, ineq: 0.0346858, eq: 1.11089 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.11915, evals: 89, done: 1, feasible: 0, sos: 0.384275, f: 0, ineq: 0.030861, eq: 1.00166 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.112864, evals: 74, done: 1, feasible: 0, sos: 0.385966, f: 0, ineq: 0.0361298, eq: 1.35411 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08048, evals: 67, done: 1, feasible: 0, sos: 0.384802, f: 0, ineq: 0.137714, eq: 1.54906 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085666, evals: 67, done: 1, feasible: 0, sos: 0.38502, f: 0, ineq: 0.0558021, eq: 1.28238 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.118287, evals: 71, done: 1, feasible: 0, sos: 0.385995, f: 0, ineq: 0.0484896, eq: 1.23493 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087675, evals: 73, done: 1, feasible: 0, sos: 0.291603, f: 0, ineq: 0.224001, eq: 0.979388 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.146443, evals: 124, done: 1, feasible: 0, sos: 0.295559, f: 0, ineq: 0.308099, eq: 1.16181 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.112079, evals: 83, done: 1, feasible: 0, sos: 0.385879, f: 0, ineq: 0.0257467, eq: 1.04429 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.093885, evals: 81, done: 1, feasible: 0, sos: 0.389641, f: 0, ineq: 0.0387166, eq: 1.24149 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083682, evals: 73, done: 1, feasible: 0, sos: 0.29172, f: 0, ineq: 0.187425, eq: 0.917596 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.121431, evals: 99, done: 1, feasible: 0, sos: 0.386159, f: 0, ineq: 0.0499382, eq: 1.2348 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083795, evals: 71, done: 1, feasible: 0, sos: 0.28829, f: 0, ineq: 0.217392, eq: 0.938343 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.113043, evals: 75, done: 1, feasible: 0, sos: 0.385178, f: 0, ineq: 0.0376653, eq: 1.22302 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.149909, evals: 117, done: 1, feasible: 0, sos: 0.263015, f: 0, ineq: 0.131809, eq: 0.893641 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.152388, evals: 118, done: 1, feasible: 0, sos: 0.384553, f: 0, ineq: 0.0273235, eq: 1.01773 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.155801, evals: 120, done: 1, feasible: 0, sos: 0.387389, f: 0, ineq: 0.0406932, eq: 1.13355 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.223749, evals: 170, done: 1, feasible: 0, sos: 0.38889, f: 0, ineq: 0.0339655, eq: 1.16951 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.140933, evals: 107, done: 1, feasible: 0, sos: 0.38502, f: 0, ineq: 0.0291002, eq: 0.963112 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.22533, evals: 188, done: 1, feasible: 0, sos: 0.279581, f: 0, ineq: 0.148943, eq: 0.825872 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.089507, evals: 77, done: 1, feasible: 0, sos: 0.27744, f: 0, ineq: 0.202605, eq: 0.94034 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.145725, evals: 106, done: 1, feasible: 0, sos: 0.262111, f: 0, ineq: 0.135762, eq: 0.911546 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.079309, evals: 69, done: 1, feasible: 0, sos: 0.387322, f: 0, ineq: 0.0553723, eq: 1.19764 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.12179, evals: 93, done: 1, feasible: 0, sos: 0.269271, f: 0, ineq: 0.160251, eq: 0.93562 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.152604, evals: 128, done: 1, feasible: 0, sos: 0.292501, f: 0, ineq: 0.212174, eq: 0.931355 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.14815, evals: 112, done: 1, feasible: 0, sos: 0.384577, f: 0, ineq: 0.0300714, eq: 0.985453 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089003, evals: 72, done: 1, feasible: 0, sos: 0.388783, f: 0, ineq: 0.0447219, eq: 1.30113 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.126759, evals: 97, done: 1, feasible: 0, sos: 0.267697, f: 0, ineq: 0.141163, eq: 0.915455 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.1457, evals: 109, done: 1, feasible: 0, sos: 0.38452, f: 0, ineq: 0.0276617, eq: 1.02441 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.157116, evals: 128, done: 1, feasible: 0, sos: 0.386463, f: 0, ineq: 0.0362633, eq: 1.1622 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.101048, evals: 76, done: 1, feasible: 0, sos: 0.385629, f: 0, ineq: 0.052971, eq: 1.36012 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.145366, evals: 120, done: 1, feasible: 0, sos: 0.386812, f: 0, ineq: 0.0431379, eq: 1.22765 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.141244, evals: 116, done: 1, feasible: 0, sos: 0.387769, f: 0, ineq: 0.036426, eq: 1.19893 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.110257, evals: 90, done: 1, feasible: 0, sos: 0.269749, f: 0, ineq: 0.168036, eq: 0.938676 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.152498, evals: 125, done: 1, feasible: 0, sos: 0.387804, f: 0, ineq: 0.0361196, eq: 1.19907 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.141725, evals: 122, done: 1, feasible: 0, sos: 0.263527, f: 0, ineq: 0.130529, eq: 0.896221 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088663, evals: 75, done: 1, feasible: 0, sos: 0.385266, f: 0, ineq: 0.0546417, eq: 1.22472 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091223, evals: 69, done: 1, feasible: 0, sos: 0.290485, f: 0, ineq: 0.279385, eq: 0.99542 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085901, evals: 70, done: 1, feasible: 0, sos: 0.385289, f: 0, ineq: 0.107235, eq: 1.33913 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.122377, evals: 83, done: 1, feasible: 0, sos: 0.383387, f: 0, ineq: 0.04494, eq: 1.25404 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.07998, evals: 63, done: 1, feasible: 0, sos: 0.293088, f: 0, ineq: 0.276596, eq: 1.03247 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.1676, evals: 148, done: 1, feasible: 0, sos: 0.388167, f: 0, ineq: 0.0349609, eq: 1.18907 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
# ...
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.291572, evals: 200, done: 1, feasible: 0, sos: 0.296037, f: 0, ineq: 0.151063, eq: 0.872279 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.092984, evals: 70, done: 1, feasible: 0, sos: 0.384866, f: 0, ineq: 0.141077, eq: 1.54843 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094639, evals: 77, done: 1, feasible: 0, sos: 0.290787, f: 0, ineq: 0.258341, eq: 1.08127 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.153715, evals: 118, done: 1, feasible: 0, sos: 0.389131, f: 0, ineq: 0.0394443, eq: 1.20151 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.220749, evals: 151, done: 1, feasible: 0, sos: 0.282713, f: 0, ineq: 0.158164, eq: 0.873845 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.18014, evals: 112, done: 1, feasible: 0, sos: 0.262123, f: 0, ineq: 0.131158, eq: 0.888744 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.079797, evals: 69, done: 1, feasible: 0, sos: 0.385572, f: 0, ineq: 0.0451429, eq: 1.26969 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.242999, evals: 182, done: 1, feasible: 0, sos: 0.388267, f: 0, ineq: 0.0353026, eq: 1.18244 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.091123, evals: 72, done: 1, feasible: 0, sos: 0.291635, f: 0, ineq: 0.187091, eq: 0.92068 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.171458, evals: 118, done: 1, feasible: 0, sos: 0.384776, f: 0, ineq: 0.0272926, eq: 0.991632 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.186385, evals: 142, done: 1, feasible: 0, sos: 0.388141, f: 0, ineq: 0.0354586, eq: 1.18758 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.1228, evals: 91, done: 1, feasible: 0, sos: 0.383824, f: 0, ineq: 0.06084, eq: 1.26249 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.13061, evals: 82, done: 1, feasible: 0, sos: 0.38494, f: 0, ineq: 0.0362205, eq: 1.20276 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.142787, evals: 107, done: 1, feasible: 0, sos: 0.387932, f: 0, ineq: 0.034847, eq: 1.20819 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095667, evals: 72, done: 1, feasible: 0, sos: 0.385171, f: 0, ineq: 0.0375397, eq: 1.22295 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095764, evals: 76, done: 1, feasible: 0, sos: 0.386185, f: 0, ineq: 0.0304141, eq: 1.12705 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.112826, evals: 78, done: 1, feasible: 0, sos: 0.280742, f: 0, ineq: 0.204647, eq: 0.969872 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087891, evals: 76, done: 1, feasible: 0, sos: 0.389786, f: 0, ineq: 0.0349978, eq: 1.23124 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.12868, evals: 98, done: 1, feasible: 0, sos: 0.268676, f: 0, ineq: 0.170048, eq: 0.923179 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083337, evals: 68, done: 1, feasible: 0, sos: 0.294176, f: 0, ineq: 0.296066, eq: 1.18013 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.141733, evals: 104, done: 1, feasible: 0, sos: 0.386312, f: 0, ineq: 0.0724702, eq: 1.23061 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.17683, evals: 123, done: 1, feasible: 0, sos: 0.388275, f: 0, ineq: 0.0385688, eq: 1.17486 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.114518, evals: 76, done: 1, feasible: 0, sos: 0.295017, f: 0, ineq: 0.211237, eq: 0.915313 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094636, evals: 80, done: 1, feasible: 0, sos: 0.286848, f: 0, ineq: 0.212661, eq: 0.939203 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08291, evals: 67, done: 1, feasible: 0, sos: 0.384695, f: 0, ineq: 0.0499207, eq: 1.29982 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.113373, evals: 79, done: 1, feasible: 0, sos: 0.389548, f: 0, ineq: 0.034863, eq: 1.22361 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.128992, evals: 100, done: 1, feasible: 0, sos: 0.385045, f: 0, ineq: 0.0300597, eq: 1.04133 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.16199, evals: 118, done: 1, feasible: 0, sos: 0.389617, f: 0, ineq: 0.0332615, eq: 1.16496 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087548, evals: 69, done: 1, feasible: 0, sos: 0.291582, f: 0, ineq: 0.224822, eq: 0.978054 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.145816, evals: 104, done: 1, feasible: 0, sos: 0.268113, f: 0, ineq: 0.15609, eq: 0.918741 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.180539, evals: 135, done: 1, feasible: 0, sos: 0.294825, f: 0, ineq: 0.187602, eq: 0.93482 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.13627, evals: 100, done: 1, feasible: 0, sos: 0.389603, f: 0, ineq: 0.0329961, eq: 1.16914 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.112267, evals: 82, done: 1, feasible: 0, sos: 0.383809, f: 0, ineq: 0.080626, eq: 1.29186 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.272773, evals: 169, done: 1, feasible: 0, sos: 0.387761, f: 0, ineq: 0.0358467, eq: 1.19484 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.169515, evals: 109, done: 1, feasible: 0, sos: 0.293076, f: 0, ineq: 0.302026, eq: 1.13503 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.097583, evals: 68, done: 1, feasible: 0, sos: 0.291442, f: 0, ineq: 0.286623, eq: 1.10288 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.204393, evals: 137, done: 1, feasible: 0, sos: 0.389897, f: 0, ineq: 0.0330409, eq: 1.18894 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.14201, evals: 97, done: 1, feasible: 0, sos: 0.267867, f: 0, ineq: 0.160656, eq: 0.917308 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.151374, evals: 94, done: 1, feasible: 0, sos: 0.384537, f: 0, ineq: 0.0291048, eq: 1.03479 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.177291, evals: 125, done: 1, feasible: 0, sos: 0.389359, f: 0, ineq: 0.0338724, eq: 1.16831 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.157618, evals: 108, done: 1, feasible: 0, sos: 0.38714, f: 0, ineq: 0.0427323, eq: 1.19252 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.142414, evals: 106, done: 1, feasible: 0, sos: 0.296569, f: 0, ineq: 0.185248, eq: 0.893701 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.219577, evals: 153, done: 1, feasible: 0, sos: 0.387565, f: 0, ineq: 0.0368001, eq: 1.20974 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.1552, evals: 108, done: 1, feasible: 0, sos: 0.267988, f: 0, ineq: 0.162301, eq: 0.922671 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.143425, evals: 100, done: 1, feasible: 0, sos: 0.29177, f: 0, ineq: 0.306637, eq: 1.2267 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.281546, evals: 201, done: 1, feasible: 0, sos: 0.387788, f: 0, ineq: 0.0434577, eq: 1.21021 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.245817, evals: 144, done: 1, feasible: 0, sos: 0.388743, f: 0, ineq: 0.034095, eq: 1.17523 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.184628, evals: 126, done: 1, feasible: 0, sos: 0.385239, f: 0, ineq: 0.0274181, eq: 1.03862 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.154063, evals: 110, done: 1, feasible: 0, sos: 0.387871, f: 0, ineq: 0.0346423, eq: 1.17331 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.130886, evals: 105, done: 1, feasible: 0, sos: 0.334539, f: 0, ineq: 0.18292, eq: 0.867318 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.133508, evals: 87, done: 1, feasible: 0, sos: 0.38619, f: 0, ineq: 0.0500374, eq: 1.23756 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085558, evals: 65, done: 1, feasible: 0, sos: 0.290928, f: 0, ineq: 0.268873, eq: 1.00887 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
