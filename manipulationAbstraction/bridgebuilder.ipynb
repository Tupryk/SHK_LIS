# %%
import robotic as ry
import numpy as np
import random
import time
from bridgebuild_env import create_n_boxes
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robotic_execution as robex

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath('scenarios/pandaSingle.g'))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C = C, N = n_boxes, position = 'fixed')

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper";
palm = "l_palm";
box1 = "box1";
box2 = "box2";
box3 = "box3";
table = "table";
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [C.frame(box1).getPosition(), C.frame(box2).getPosition(), C.frame(box3).getPosition()]
boxes = [box1, box2, box3]
last_box_memory = []
for l in range(3):
        box = np.random.choice(boxes)
        qStart = C.getJointState()
        graspDirection = 'x' #random.choice(['y', 'z']) #'x' not possible: box too large
        placeDirection = 'z' #random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
        info = f'placement {l}: grasp {graspDirection} place {placeDirection}'
        print('===', info)

        M = manip.ManipulationModelling(C, info, helpers=[gripper])
        M.setup_pick_and_place_waypoints(gripper, box, homing_scale=1e-1, accumulated_collisions=True)
        M.grasp_box(1., gripper, box, palm, graspDirection)
        print('place direction:', placeDirection)

        if l > 1:

            offset_xyz = [0.0, 0.0, 0.00]
            poses_from_memory = np.vstack( (C.getFrame(last_box_memory[-2]).getPosition(), C.getFrame(last_box_memory[-1]).getPosition()) )
            middle_between_towers = np.mean(poses_from_memory, 0) + offset_xyz

            dir_vec = C.getFrame(last_box_memory[-2]).getPosition() - C.getFrame(last_box_memory[-1]).getPosition()
            pos2 = C.getFrame(last_box_memory[-2]).getPosition()
            pos1 = C.getFrame(last_box_memory[-1]).getPosition()
            rel_pos =  (pos1 + pos2) / 2 + np.array([0, 0, 0.08])
            
            dir_vec /= np.linalg.norm(dir_vec)

            M.komo.addObjective([2.], ry.FS.position, [box], ry.OT.eq, [1e3], rel_pos)
            M.komo.addObjective([2.], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
            M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])


            
        if l == 1:
            M.place_box(2., box, table, palm, placeDirection)

            M.komo.addObjective([2.], ry.FS.negDistance, [box, last_box_memory[-1]], ry.OT.eq, [1e1], [-.04])
            M.komo.addObjective([2.], ry.FS.scalarProductXY, [box, last_box_memory[-1]], ry.OT.eq, [1e1], [0])
            M.komo.addObjective([2.], ry.FS.positionRel, [box, last_box_memory[-1]], ry.OT.eq, [1.], [.0, .0, .1])
            M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.08)

        M.no_collision([], palm, table)
        # keep distance between boxes when placed defined by margin
        # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
        # place inital block as chosen by np.random.choice at a random location
        if l == 0:
            M.place_box(2., box, table, palm, placeDirection)

            M.target_relative_xy_position(2., box, table, [np.random.uniform(0.0, 0.3), np.random.uniform(0.0, 0.3)])
            M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.08)


        ways = M.solve()
        
        if not M.feasible:
            continue
        M2 = M.sub_motion(0)
        # M = manip.ManipulationModelling(C, info, helpers=[gripper])
        # M.setup_point_to_point_motion(qStart, ways[0])
        M2.no_collision([.3,.7], palm, box)
        
        M2.retract([.0, .2], gripper, dist = .13)
        M2.approach([.8, 1.], gripper)
        M2.solve()
        if not M2.feasible:
            continue

        M3 = M.sub_motion(1)
        #manip.ManipulationModelling(C, info)
        # M.setup_point_to_point_motion(ways[0], ways[1])
        M3.no_collision([], table, box)

        M3.solve()
        if not M3.ret.feasible:
            continue

        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)
        # update memory
        last_box_memory.append(box)
        # remove box that was previously used
        boxes.remove(box)
        # update positions
        boxes_pos = [C.frame(box1).getPosition(), C.frame(box2).getPosition(), C.frame(box3).getPosition()]


del M
# Out:
# === placement 0: grasp x place z
# place direction: z
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 46
#      43     M.komo.addObjective([2.], ry.FS.positionRel, [box, last_box_memory[-1]], ry.OT.eq, [1.], [.0, .0, .1])
#      44     M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.08)
# ---> 46 M.no_collision([], palm, table)
#      47 # keep distance between boxes when placed defined by margin
#      48 # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
#      49 # place inital block as chosen by np.random.choice at a random location
#      50 if l == 0:
#
# AttributeError: 'ManipulationModelling' object has no attribute 'no_collision'

# %% [markdown]
# ### On real robot: BotOp

# %%
import robotic as ry
import numpy as np
import random
import time
from bridgebuild_env import create_n_boxes
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robotic_execution as robex

# %%
def fetch_name_error_type(data):
    name_error_type_list = []
    for key, value in data.items():
        if isinstance(value, dict) and 'name' in value and 'err' in value and 'type' in value:
            name_error_type_list.append((value['name'], value['err'], value['type']))
    return name_error_type_list

# %%
def print_name_error_type(data):
    for name, error,  obj_type in data:
        print("Name:", name, "Type:", obj_type, "Error:", error)

# %%
C = ry.Config()
C.addFile(ry.raiPath('scenarios/pandaSingle.g'))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C = C, N = n_boxes, position = 'fixed')

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper";
palm = "l_palm";
box1 = "box1";
box2 = "box2";
box3 = "box3";
table = "table";
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=False)
bot.goHome(C)

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [C.frame(box1).getPosition(), C.frame(box2).getPosition(), C.frame(box3).getPosition()]
boxes = [box1, box2, box3]
last_box_memory = []
paths = []
vis = 1
n_success = 0
boxz = [box1, box3, box2]
while n_success <= 2:
    box = np.random.choice(boxes)
    # box = boxz[n_success]
    qStart = C.getJointState()
    graspDirection = random.choice(['x', 'y', 'z'])
    placeDirection = 'z' #random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f'placement {n_success}: grasp {graspDirection} place {placeDirection}'
    print('===', info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(gripper, box, homing_scale=1e0, accumulated_collisions=True)
    M.grasp_box(0.5, gripper, box, palm, graspDirection)
    print('place direction:', placeDirection)

    if n_success > 1:
        print(f"3rd Block: ({box})")
        dir_vec = C.getFrame(last_box_memory[-2]).getPosition() - C.getFrame(last_box_memory[-1]).getPosition()
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos =  (pos1 + pos2) / 2 + np.array([0, 0, 0.08])
        dir_vec /= np.linalg.norm(dir_vec)

        #M.komo.addObjective([.3, .7], ry.FS.negDistance, [gripper, table], ry.OT.ineq, [1e1], [-0.15])
        M.komo.addObjective([2.], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        #M.komo.addObjective([1.0], ry.FS.vectorY, [box], ry.OT.eq, [1e1], dir_vec)
        M.komo.addObjective([2.], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])
        #M.komo.addObjective([0.3, 1.5], ry.FS.negDistance, [gripper, last_box_memory[-2]], ry.OT.ineq, [1e1], [-0.001])
        #M.komo.addObjective([0.3, 1.5], ry.FS.negDistance, [gripper, last_box_memory[-1]], ry.OT.ineq, [1e1], [-0.001])
        
    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2., box, table, palm, placeDirection)
        M.komo.addObjective([2.], ry.FS.negDistance, [box, last_box_memory[-1]], ry.OT.eq, [1e1], [-.04])
        M.komo.addObjective([2.], ry.FS.scalarProductXY, [box, last_box_memory[-1]], ry.OT.eq, [1e1], [0])
        #M.komo.addObjective([2.], ry.FS.positionRel, [box, last_box_memory[-1]], ry.OT.eq, [1.], [.0, .0, .1])
        M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2., box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        # initial_pos= [0.020433060890705013, 0.08433819136314634]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2., box, table, initial_pos)
        M.auto_pairwise_keep_dist([], keep_dist_between, margin = 0.08)

    ways = M.solve()

    if not M.feasible:
        print(f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :(")
        continue
    print("Submotion 0")
    M2 = M.sub_motion(0)
    # M = manip.ManipulationModelling(C, info, helpers=[gripper])
    # M.setup_point_to_point_motion(qStart, ways[0])
    M2.keep_distance([.3,.7], palm, box)
    
    M2.retract([.0, .2], gripper, dist = .13)
    M2.approach([.8, 1.], gripper)
    paths.append(M2.solve())
    
    if not M2.feasible:
        print(f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :(")
        continue

    M3 = M.sub_motion(1)
    #manip.ManipulationModelling(C, info)
    # M.setup_point_to_point_motion(ways[0], ways[1])
    M3.keep_distance([], table, box)
    if n_success > 1:
        M3.retract([.0, .2], gripper, dist = .13)
        M3.approach([.8, 1.], gripper)

    paths.append(M3.solve())
    if not M3.ret.feasible:
        print(f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :(")
        continue
    
    M_report = M.komo.report(True)
    M_report = fetch_name_error_type(M_report)
    print_name_error_type(M_report)

    M2_report = M2.komo.report(True)
    M2_report = fetch_name_error_type(M2_report)
    print_name_error_type(M2_report)

    M3_report = M3.komo.report(True)
    M3_report = fetch_name_error_type(M3_report)
    print_name_error_type(M3_report)

    if vis == 0:
        M2.play(C)
        C.attach(gripper, box)
        M3.play(C)
        C.attach(table, box)

    bot.execute_path_blocking(C, path = paths[-2])
    C.attach(gripper, box)
    bot.grasp(C)

    bot.execute_path_blocking(C, path = paths[-1])
    C.attach(table, box)
    bot.release(C)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [C.frame(box1).getPosition(), C.frame(box2).getPosition(), C.frame(box3).getPosition()]
    n_success += 1
        
del M
# Out:
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.04130301085160684, 0.04408252892441109]
#   -- feasible:placement 0: grasp x place z
#      { time: 0.134746, evals: 200, done: 1, feasible: 1, sos: 5.09983, f: 0, ineq: 0.139115, eq: 0.359091 }
# Submotion 0
#   -- infeasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.107807, evals: 40, done: 1, feasible: 0, sos: 2.95359, f: 0, ineq: 1.24732e-07, eq: 0.673886 }
# Failed placing block number 1 with grasp direction x at M2 :(
# === placement 0: grasp z place z
# place direction: z
# 1st Block: (box1)
# Trying xy pos:  [0.03514775774073544, 0.03352417143788172]
#   -- infeasible:placement 0: grasp z place z
#      { time: 0.127945, evals: 201, done: 1, feasible: 0, sos: 2.95627, f: 0, ineq: 0.362882, eq: 1.22616 }
# Failed placing block number 1 with grasp direction z at M :(
# === placement 0: grasp z place z
# place direction: z
# 1st Block: (box1)
# Trying xy pos:  [0.04964673330414428, 0.05548623548527157]
#   -- infeasible:placement 0: grasp z place z
#      { time: 0.126007, evals: 200, done: 1, feasible: 0, sos: 2.97854, f: 0, ineq: 0.229222, eq: 1.27492 }
# Failed placing block number 1 with grasp direction z at M :(
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box3)
# Trying xy pos:  [0.012909426392820878, 0.0077233363690729865]
#   -- feasible:placement 0: grasp y place z
#      { time: 0.115356, evals: 185, done: 1, feasible: 1, sos: 5.02557, f: 0, ineq: 1.06864e-08, eq: 6.72108e-05 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp y place z
#      { time: 0.222838, evals: 48, done: 1, feasible: 1, sos: 3.1628, f: 0, ineq: 1.14208e-06, eq: 0.0436968 }
#   -- feasible:sub_motion_1--placement 0: grasp y place z
#      { time: 0.058855, evals: 9, done: 1, feasible: 1, sos: 0.0520495, f: 0, ineq: 0.00438386, eq: 0.0275725 }
# Name: F_qItself Type: sos Error: 4.995702758082096
# Name: F_qItself Type: sos Error: 0.029863357509781023
# Name: F_AccumulatedCollisions Type: eq Error: 2.000170644824925e-05
# Name: F_qLimits Type: ineq Error: 0.0
# Name: F_Pose Type: eq Error: 4.2057886578267256e-05
# Name: F_PositionRel Type: eq Error: 1.535021182592977e-08
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_PositionRel Type: ineq Error: 1.0686360855367992e-08
# Name: F_ScalarProduct Type: eq Error: 8.126717510259579e-10
# Name: F_ScalarProduct Type: eq Error: 6.890341112123417e-08
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PositionDiff Type: eq Error: 5.806028301191812e-07
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_Vector Type: eq Error: 6.188613213943128e-08
# Name: F_ScalarProduct Type: eq Error: 6.32901557963012e-08
# Name: F_ScalarProduct Type: eq Error: 6.048210470780306e-08
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PositionRel Type: eq Error: 4.299920100536703e-06
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_qItself Type: sos Error: 0.003252179590689863
# Name: F_qItself Type: sos Error: 3.159546285663776
# Name: F_AccumulatedCollisions Type: eq Error: 0.043450177084924935
# Name: F_qItself Type: eq Error: 6.3074075846714095e-06
# Name: F_qItself Type: eq Error: 4.626428007090122e-05
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PositionRel Type: eq Error: 1.4132978341449554e-06
# Name: F_QuaternionDiff Type: eq Error: 1.9328997874490383e-06
# Name: F_PositionRel Type: ineq Error: 1.3279051469528014e-07
# Name: F_PositionRel Type: eq Error: 8.13159029187817e-05
# Name: F_QuaternionDiff Type: eq Error: 0.00010934982581367603
# Name: F_PositionRel Type: ineq Error: 1.0092845482978507e-06
# Name: F_qItself Type: sos Error: 0.007788097281341152
# Name: F_qItself Type: sos Error: 0.04426140685828479
# Name: F_AccumulatedCollisions Type: eq Error: 0.02055528335478396
# Name: F_qItself Type: eq Error: 0.00013334581635104925
# Name: F_qItself Type: eq Error: 0.006883897918191068
# Name: F_PairCollision Type: ineq Error: 0.004383858946583816
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-box3 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:891(0) REMOVING JOINT 0x3ae74d0-0x3af9430 of type rigid
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box2)
#   -- feasible:placement 1: grasp y place z
#      { time: 0.159961, evals: 176, done: 1, feasible: 1, sos: 4.17645, f: 0, ineq: 0.199972, eq: 0.200068 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp y place z
#      { time: 0.150543, evals: 33, done: 1, feasible: 1, sos: 2.29512, f: 0, ineq: 1.68501e-06, eq: 0.0426422 }
#   -- feasible:sub_motion_1--placement 1: grasp y place z
#      { time: 0.051617, evals: 11, done: 1, feasible: 1, sos: 0.0518264, f: 0, ineq: 0.000698798, eq: 0.0263423 }
# Name: F_qItself Type: sos Error: 4.168540054804938
# Name: F_qItself Type: sos Error: 0.007907573826251232
# Name: F_AccumulatedCollisions Type: eq Error: 2.023153871298991e-05
# Name: F_qLimits Type: ineq Error: 0.0
# Name: F_Pose Type: eq Error: 2.5865741505592954e-06
# Name: F_PositionRel Type: eq Error: 2.9136125725718275e-07
# Name: F_PositionRel Type: ineq Error: 4.39733669616027e-07
# Name: F_PositionRel Type: ineq Error: 2.5287458182925686e-07
# Name: F_ScalarProduct Type: eq Error: 2.0459057578344424e-06
# Name: F_ScalarProduct Type: eq Error: 1.4086911857643594e-06
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PositionDiff Type: eq Error: 8.476288303194135e-07
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_Vector Type: eq Error: 3.966831121555623e-06
# Name: F_ScalarProduct Type: eq Error: 2.3804854174020178e-06
# Name: F_ScalarProduct Type: eq Error: 5.553158573531681e-06
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: eq Error: 0.2000284260363061
# Name: F_ScalarProduct Type: eq Error: 2.2126094956220754e-07
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PairCollision Type: ineq Error: 0.19997157396369392
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_qItself Type: sos Error: 0.005580175660889712
# Name: F_qItself Type: sos Error: 2.2895368906731264
# Name: F_AccumulatedCollisions Type: eq Error: 0.041943344687400685
# Name: F_qItself Type: eq Error: 1.125614727648383e-05
# Name: F_qItself Type: eq Error: 8.222707556293507e-05
# Name: F_PairCollision Type: ineq Error: 0.0
# Name: F_PositionRel Type: eq Error: 9.591125952353633e-07
# Name: F_QuaternionDiff Type: eq Error: 7.632602036511393e-07
# Name: F_PositionRel Type: ineq Error: 0.0
# Name: F_PositionRel Type: eq Error: 0.00025413499183622474
# Name: F_QuaternionDiff Type: eq Error: 0.0003495008902079655
# Name: F_PositionRel Type: ineq Error: 1.685010962010347e-06
# Name: F_qItself Type: sos Error: 0.006452681074623198
# Name: F_qItself Type: sos Error: 0.04537373749123288
# Name: F_AccumulatedCollisions Type: eq Error: 0.02257509325847007
# Name: F_qItself Type: eq Error: 5.7090887478628005e-05
# Name: F_qItself Type: eq Error: 0.0037100813869462047
# Name: F_PairCollision Type: ineq Error: 0.0006987979548041603
# -- kin_physx.cpp:addJoint:298(0) ADDING JOINT l_panda_joint7-box2 of type rigid with rel [0, 0, 0]
# -- kin_physx.cpp:removeJoint:891(0) REMOVING JOINT 0x3ae74d0-0x3af9060 of type rigid
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.154682, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227001, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.187747, evals: 52, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.274894, evals: 63, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.85409e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.091126, evals: 163, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.09009, evals: 200, done: 1, feasible: 1, sos: 8.54726, f: 0, ineq: 0.00249941, eq: 0.215647 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.07731, evals: 174, done: 1, feasible: 0, sos: 14.4591, f: 0, ineq: 0.0125077, eq: 0.928105 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.11239, evals: 200, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226989, eq: 0.140955 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.201683, evals: 52, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.274974, evals: 63, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.85477e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.108732, evals: 200, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304028 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.03644, evals: 200, done: 1, feasible: 1, sos: 8.73167, f: 0, ineq: 0.00209842, eq: 0.195095 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.851558, evals: 141, done: 1, feasible: 0, sos: 14.88, f: 0, ineq: 0.00655697, eq: 0.889682 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.11055, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227002, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.229643, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.341243, evals: 69, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87277e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.116742, evals: 200, done: 1, feasible: 0, sos: 6.88518, f: 0, ineq: 0.348803, eq: 1.12271 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.109284, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.220564, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.296658, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.84739e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.111156, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.166501, evals: 46, done: 1, feasible: 1, sos: 2.81219, f: 0, ineq: 0.000170237, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.278432, evals: 69, done: 1, feasible: 0, sos: 7.61596, f: 0, ineq: 4.87896e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.105281, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227002, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.195606, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.269897, evals: 65, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.871e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.105276, evals: 201, done: 1, feasible: 1, sos: 11.0347, f: 0, ineq: 0.0223702, eq: 0.140751 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.175445, evals: 50, done: 1, feasible: 1, sos: 2.80929, f: 0, ineq: 0.000210109, eq: 0.0465548 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.264388, evals: 66, done: 1, feasible: 0, sos: 7.61963, f: 0, ineq: 4.87321e-06, eq: 0.775839 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.11379, evals: 200, done: 1, feasible: 0, sos: 6.88506, f: 0, ineq: 0.348815, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.105701, evals: 201, done: 1, feasible: 1, sos: 11.0347, f: 0, ineq: 0.0223726, eq: 0.140764 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.214201, evals: 60, done: 1, feasible: 1, sos: 2.80949, f: 0, ineq: 0.000207935, eq: 0.0464419 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.276593, evals: 66, done: 1, feasible: 0, sos: 7.61967, f: 0, ineq: 4.87908e-06, eq: 0.775843 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.09427, evals: 162, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.929417, evals: 200, done: 1, feasible: 1, sos: 8.50746, f: 0, ineq: 0.00260687, eq: 0.223727 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.85837, evals: 153, done: 1, feasible: 0, sos: 14.4588, f: 0, ineq: 0.0124627, eq: 0.928579 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.111439, evals: 201, done: 1, feasible: 0, sos: 6.88513, f: 0, ineq: 0.348787, eq: 1.12248 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.114859, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227013, eq: 0.140957 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.212425, evals: 57, done: 1, feasible: 1, sos: 2.81214, f: 0, ineq: 0.000170386, eq: 0.0419278 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.261336, evals: 64, done: 1, feasible: 0, sos: 7.61572, f: 0, ineq: 4.8887e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.110506, evals: 201, done: 1, feasible: 1, sos: 11.0349, f: 0, ineq: 0.0223686, eq: 0.140756 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.209787, evals: 58, done: 1, feasible: 1, sos: 2.8093, f: 0, ineq: 0.000210182, eq: 0.0465594 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.27239, evals: 64, done: 1, feasible: 0, sos: 7.61975, f: 0, ineq: 4.84672e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.113615, evals: 201, done: 1, feasible: 0, sos: 6.88491, f: 0, ineq: 0.348827, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.112699, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.227024, evals: 59, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170387, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.268948, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87989e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.117707, evals: 200, done: 1, feasible: 0, sos: 6.88491, f: 0, ineq: 0.348827, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.111171, evals: 201, done: 1, feasible: 1, sos: 13.857, f: 0, ineq: 0.0998006, eq: 0.303417 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.17415, evals: 200, done: 1, feasible: 1, sos: 8.72075, f: 0, ineq: 0.00235613, eq: 0.210767 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.46847, evals: 200, done: 1, feasible: 0, sos: 14.834, f: 0, ineq: 0.00886961, eq: 0.894501 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.097836, evals: 166, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.09395, evals: 193, done: 1, feasible: 1, sos: 8.63463, f: 0, ineq: 0.00211897, eq: 0.194739 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.06709, evals: 151, done: 1, feasible: 0, sos: 14.454, f: 0, ineq: 0.0127636, eq: 0.932054 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.119219, evals: 201, done: 1, feasible: 1, sos: 11.0348, f: 0, ineq: 0.0223651, eq: 0.140753 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.277774, evals: 54, done: 1, feasible: 1, sos: 2.8093, f: 0, ineq: 0.000210141, eq: 0.0465568 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.344313, evals: 67, done: 1, feasible: 0, sos: 7.61967, f: 0, ineq: 4.87452e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.126025, evals: 200, done: 1, feasible: 1, sos: 13.8595, f: 0, ineq: 0.0997118, eq: 0.302655 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.09623, evals: 185, done: 1, feasible: 1, sos: 8.73004, f: 0, ineq: 0.00245201, eq: 0.195764 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.997226, evals: 148, done: 1, feasible: 0, sos: 14.8964, f: 0, ineq: 0.00654934, eq: 0.889849 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.12752, evals: 201, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304028 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.12093, evals: 201, done: 1, feasible: 1, sos: 8.68723, f: 0, ineq: 0.002504, eq: 0.215154 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.02584, evals: 145, done: 1, feasible: 0, sos: 14.88, f: 0, ineq: 0.00655638, eq: 0.88968 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.109747, evals: 162, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.37612, evals: 201, done: 1, feasible: 1, sos: 8.63336, f: 0, ineq: 0.00211745, eq: 0.223309 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.16985, evals: 157, done: 1, feasible: 0, sos: 14.4591, f: 0, ineq: 0.0125198, eq: 0.928463 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.111629, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.206106, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.288099, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.8816e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.109056, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227007, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.220098, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170386, eq: 0.0419275 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.302473, evals: 64, done: 1, feasible: 0, sos: 7.6157, f: 0, ineq: 4.84786e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.107241, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.186233, evals: 52, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.284876, evals: 66, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87421e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.11504, evals: 201, done: 1, feasible: 0, sos: 6.88514, f: 0, ineq: 0.348839, eq: 1.12268 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.109755, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227003, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.222619, evals: 59, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170387, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.298878, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.88049e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.113223, evals: 200, done: 1, feasible: 1, sos: 13.8595, f: 0, ineq: 0.0997117, eq: 0.302655 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.840623, evals: 168, done: 1, feasible: 1, sos: 8.73003, f: 0, ineq: 0.00245201, eq: 0.195765 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.37353, evals: 201, done: 1, feasible: 0, sos: 14.8891, f: 0, ineq: 0.0068348, eq: 0.870516 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.110229, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227002, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.230962, evals: 59, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170388, eq: 0.0419274 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.44664, evals: 69, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87229e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.137549, evals: 200, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226989, eq: 0.140955 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.230024, evals: 52, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170388, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.300593, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87963e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.105168, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.211528, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.388621, evals: 66, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87398e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.148244, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.278757, evals: 53, done: 1, feasible: 1, sos: 2.80926, f: 0, ineq: 0.000209452, eq: 0.0466837 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.325855, evals: 66, done: 1, feasible: 0, sos: 7.61596, f: 0, ineq: 4.88017e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.119152, evals: 201, done: 1, feasible: 1, sos: 13.8554, f: 0, ineq: 0.100083, eq: 0.303591 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.23938, evals: 201, done: 1, feasible: 1, sos: 8.81893, f: 0, ineq: 0.00182636, eq: 0.356435 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.44609, evals: 169, done: 1, feasible: 0, sos: 14.8139, f: 0, ineq: 0.00987206, eq: 0.905042 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.106529, evals: 200, done: 1, feasible: 1, sos: 13.8519, f: 0, ineq: 0.10017, eq: 0.304874 }
# Submotion 0
#   -- infeasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.05268, evals: 200, done: 1, feasible: 0, sos: 7.02897, f: 0, ineq: 0.00852218, eq: 0.503078 }
# Failed placing block number 3 with grasp direction y at M2 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.105734, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.209405, evals: 59, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170388, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.334027, evals: 66, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87493e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.12576, evals: 201, done: 1, feasible: 0, sos: 6.88513, f: 0, ineq: 0.348788, eq: 1.12248 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.131743, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.214126, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.273605, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.84934e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.114462, evals: 201, done: 1, feasible: 1, sos: 13.8491, f: 0, ineq: 0.100244, eq: 0.304916 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.09455, evals: 201, done: 1, feasible: 1, sos: 8.668, f: 0, ineq: 0.00248979, eq: 0.216875 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.21083, evals: 194, done: 1, feasible: 0, sos: 14.8254, f: 0, ineq: 0.00717772, eq: 0.867145 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.090513, evals: 162, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.10086, evals: 200, done: 1, feasible: 1, sos: 8.60917, f: 0, ineq: 0.00233743, eq: 0.204393 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.14328, evals: 180, done: 1, feasible: 0, sos: 14.5195, f: 0, ineq: 0.00903081, eq: 0.889573 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.115921, evals: 201, done: 1, feasible: 1, sos: 13.8728, f: 0, ineq: 0.0989868, eq: 0.301042 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.00812, evals: 201, done: 1, feasible: 1, sos: 8.82615, f: 0, ineq: 0.0020193, eq: 0.192592 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.38328, evals: 193, done: 1, feasible: 0, sos: 14.8659, f: 0, ineq: 0.0114956, eq: 0.952665 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.117963, evals: 201, done: 1, feasible: 1, sos: 11.0277, f: 0, ineq: 0.0227056, eq: 0.140962 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.178687, evals: 47, done: 1, feasible: 1, sos: 2.81216, f: 0, ineq: 0.000170233, eq: 0.0419246 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.305706, evals: 64, done: 1, feasible: 0, sos: 7.61582, f: 0, ineq: 4.84825e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.12399, evals: 201, done: 1, feasible: 0, sos: 6.88521, f: 0, ineq: 0.3488, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.100747, evals: 161, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.01402, evals: 200, done: 1, feasible: 1, sos: 8.50169, f: 0, ineq: 0.00262232, eq: 0.224907 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.00818, evals: 157, done: 1, feasible: 0, sos: 14.4591, f: 0, ineq: 0.0125203, eq: 0.928468 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.119082, evals: 200, done: 1, feasible: 1, sos: 13.852, f: 0, ineq: 0.100301, eq: 0.304091 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.07728, evals: 200, done: 1, feasible: 1, sos: 8.70553, f: 0, ineq: 0.00241957, eq: 0.205954 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.14687, evals: 171, done: 1, feasible: 0, sos: 14.7953, f: 0, ineq: 0.00991487, eq: 0.904317 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.122961, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226999, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.244362, evals: 57, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170395, eq: 0.0419274 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.333416, evals: 67, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87687e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.133574, evals: 200, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304028 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.10726, evals: 200, done: 1, feasible: 1, sos: 8.7418, f: 0, ineq: 0.00194131, eq: 0.18649 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.19773, evals: 183, done: 1, feasible: 0, sos: 14.8487, f: 0, ineq: 0.00809127, eq: 0.887408 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.111016, evals: 161, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.0882, evals: 200, done: 1, feasible: 1, sos: 8.50169, f: 0, ineq: 0.00262232, eq: 0.224907 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.999685, evals: 155, done: 1, feasible: 0, sos: 14.4635, f: 0, ineq: 0.0123054, eq: 0.925062 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.126139, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227007, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.278756, evals: 60, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170388, eq: 0.0419276 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.311954, evals: 64, done: 1, feasible: 0, sos: 7.6157, f: 0, ineq: 4.88075e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.129193, evals: 200, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304028 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.00072, evals: 201, done: 1, feasible: 1, sos: 8.74325, f: 0, ineq: 0.00192672, eq: 0.211752 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.885984, evals: 145, done: 1, feasible: 0, sos: 14.88, f: 0, ineq: 0.00655641, eq: 0.88968 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.120786, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227014, eq: 0.140957 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.230341, evals: 57, done: 1, feasible: 1, sos: 2.81214, f: 0, ineq: 0.000170386, eq: 0.0419278 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.313789, evals: 63, done: 1, feasible: 0, sos: 7.61572, f: 0, ineq: 4.88891e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.175968, evals: 201, done: 1, feasible: 1, sos: 11.0349, f: 0, ineq: 0.0223686, eq: 0.140756 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.296277, evals: 57, done: 1, feasible: 1, sos: 2.80931, f: 0, ineq: 0.000210167, eq: 0.0465591 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.40938, evals: 69, done: 1, feasible: 0, sos: 7.61975, f: 0, ineq: 4.87135e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.129785, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227007, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.279472, evals: 57, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170386, eq: 0.0419275 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.393669, evals: 68, done: 1, feasible: 0, sos: 7.6157, f: 0, ineq: 4.87249e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.139015, evals: 200, done: 1, feasible: 1, sos: 13.857, f: 0, ineq: 0.0998005, eq: 0.303415 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.19691, evals: 201, done: 1, feasible: 1, sos: 8.68753, f: 0, ineq: 0.00250518, eq: 0.214144 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.12531, evals: 185, done: 1, feasible: 0, sos: 14.8321, f: 0, ineq: 0.00906637, eq: 0.898653 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.120596, evals: 201, done: 1, feasible: 0, sos: 6.88513, f: 0, ineq: 0.348788, eq: 1.12248 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.112301, evals: 200, done: 1, feasible: 1, sos: 13.8496, f: 0, ineq: 0.100436, eq: 0.30549 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.03168, evals: 200, done: 1, feasible: 1, sos: 8.69162, f: 0, ineq: 0.00243838, eq: 0.200726 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.18756, evals: 197, done: 1, feasible: 0, sos: 14.8272, f: 0, ineq: 0.00717414, eq: 0.867201 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.113305, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226991, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.222146, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.443518, evals: 66, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87902e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.13282, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227002, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.242027, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.325859, evals: 64, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.84798e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.121363, evals: 200, done: 1, feasible: 1, sos: 11.0348, f: 0, ineq: 0.022366, eq: 0.140752 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.213266, evals: 48, done: 1, feasible: 1, sos: 2.80931, f: 0, ineq: 0.000209934, eq: 0.0465462 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.323235, evals: 66, done: 1, feasible: 0, sos: 7.61966, f: 0, ineq: 4.87369e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.116239, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.237823, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.331469, evals: 69, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87213e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.115404, evals: 200, done: 1, feasible: 1, sos: 13.852, f: 0, ineq: 0.100301, eq: 0.304091 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.95348, evals: 201, done: 1, feasible: 1, sos: 8.6864, f: 0, ineq: 0.00246895, eq: 0.210628 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.925887, evals: 169, done: 1, feasible: 0, sos: 14.8073, f: 0, ineq: 0.00945263, eq: 0.899495 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.123125, evals: 200, done: 1, feasible: 0, sos: 6.8848, f: 0, ineq: 0.348803, eq: 1.12282 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.118581, evals: 200, done: 1, feasible: 1, sos: 13.8514, f: 0, ineq: 0.100161, eq: 0.304241 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.983831, evals: 200, done: 1, feasible: 1, sos: 8.69464, f: 0, ineq: 0.00244324, eq: 0.201005 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.3824, evals: 171, done: 1, feasible: 0, sos: 14.7628, f: 0, ineq: 0.010898, eq: 0.924913 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.125536, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227007, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.247744, evals: 57, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.0001704, eq: 0.0419279 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.404252, evals: 63, done: 1, feasible: 0, sos: 7.6157, f: 0, ineq: 4.87456e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.15595, evals: 201, done: 1, feasible: 0, sos: 6.8848, f: 0, ineq: 0.348803, eq: 1.12282 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.160502, evals: 201, done: 1, feasible: 0, sos: 6.88517, f: 0, ineq: 0.348801, eq: 1.12268 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.107608, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227002, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.21973, evals: 56, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.285286, evals: 66, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87066e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.168317, evals: 200, done: 1, feasible: 0, sos: 6.88438, f: 0, ineq: 0.348835, eq: 1.12298 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.14364, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.356096, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.401214, evals: 68, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.8724e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.122857, evals: 201, done: 1, feasible: 0, sos: 6.88492, f: 0, ineq: 0.348832, eq: 1.12281 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.119359, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
# ...
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.126509, evals: 201, done: 1, feasible: 0, sos: 6.88521, f: 0, ineq: 0.3488, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.136049, evals: 200, done: 1, feasible: 0, sos: 6.88461, f: 0, ineq: 0.348816, eq: 1.12289 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.120561, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.231786, evals: 51, done: 1, feasible: 1, sos: 2.80931, f: 0, ineq: 0.000208839, eq: 0.0466513 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.369079, evals: 66, done: 1, feasible: 0, sos: 7.61596, f: 0, ineq: 4.87218e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.120472, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0227, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.273157, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419272 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.352986, evals: 69, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87236e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.119135, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226999, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.252852, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.368237, evals: 69, done: 1, feasible: 0, sos: 7.61569, f: 0, ineq: 4.87216e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.127705, evals: 201, done: 1, feasible: 1, sos: 13.8491, f: 0, ineq: 0.100244, eq: 0.304914 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.17473, evals: 200, done: 1, feasible: 1, sos: 8.67821, f: 0, ineq: 0.00246412, eq: 0.20968 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.1923, evals: 165, done: 1, feasible: 0, sos: 14.75, f: 0, ineq: 0.0108837, eq: 0.926243 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.117587, evals: 201, done: 1, feasible: 1, sos: 13.8709, f: 0, ineq: 0.0991897, eq: 0.301569 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.17186, evals: 201, done: 1, feasible: 1, sos: 8.84699, f: 0, ineq: 0.00189774, eq: 0.221382 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.43676, evals: 201, done: 1, feasible: 0, sos: 14.8745, f: 0, ineq: 0.00871811, eq: 0.942539 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.130217, evals: 201, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304026 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.29944, evals: 200, done: 1, feasible: 1, sos: 8.74192, f: 0, ineq: 0.00194048, eq: 0.186453 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.14431, evals: 180, done: 1, feasible: 0, sos: 14.8392, f: 0, ineq: 0.00863828, eq: 0.889479 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.142711, evals: 200, done: 1, feasible: 0, sos: 6.88506, f: 0, ineq: 0.348815, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.122582, evals: 200, done: 1, feasible: 0, sos: 6.8848, f: 0, ineq: 0.348803, eq: 1.12282 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.119888, evals: 201, done: 1, feasible: 1, sos: 13.8558, f: 0, ineq: 0.100227, eq: 0.304028 }
# Submotion 0
#   -- infeasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.06506, evals: 201, done: 1, feasible: 0, sos: 8.72856, f: 0, ineq: 0.00188332, eq: 0.932944 }
# Failed placing block number 3 with grasp direction y at M2 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.121402, evals: 200, done: 1, feasible: 0, sos: 6.88463, f: 0, ineq: 0.348817, eq: 1.12289 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.123604, evals: 201, done: 1, feasible: 0, sos: 6.88491, f: 0, ineq: 0.348827, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.124682, evals: 201, done: 1, feasible: 0, sos: 6.88518, f: 0, ineq: 0.348802, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.120495, evals: 201, done: 1, feasible: 0, sos: 6.8849, f: 0, ineq: 0.348826, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.117575, evals: 200, done: 1, feasible: 1, sos: 13.8728, f: 0, ineq: 0.0989874, eq: 0.301037 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.03347, evals: 201, done: 1, feasible: 1, sos: 8.82613, f: 0, ineq: 0.00201931, eq: 0.19257 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.18824, evals: 201, done: 1, feasible: 0, sos: 14.9099, f: 0, ineq: 0.00570437, eq: 0.928703 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.097519, evals: 167, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.03274, evals: 200, done: 1, feasible: 1, sos: 8.50746, f: 0, ineq: 0.00260687, eq: 0.223728 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.921246, evals: 156, done: 1, feasible: 0, sos: 14.4591, f: 0, ineq: 0.0125201, eq: 0.928468 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.115571, evals: 200, done: 1, feasible: 1, sos: 11.0348, f: 0, ineq: 0.0223649, eq: 0.140753 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.249309, evals: 57, done: 1, feasible: 1, sos: 2.80929, f: 0, ineq: 0.000210155, eq: 0.0465571 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.291322, evals: 66, done: 1, feasible: 0, sos: 7.61967, f: 0, ineq: 4.87859e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.125574, evals: 201, done: 1, feasible: 0, sos: 6.88517, f: 0, ineq: 0.348801, eq: 1.12268 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.110435, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.17664, evals: 51, done: 1, feasible: 1, sos: 2.80931, f: 0, ineq: 0.000208839, eq: 0.0466516 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.278412, evals: 63, done: 1, feasible: 0, sos: 7.61596, f: 0, ineq: 4.86587e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.109056, evals: 201, done: 1, feasible: 1, sos: 13.8554, f: 0, ineq: 0.100083, eq: 0.303596 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.935859, evals: 201, done: 1, feasible: 1, sos: 8.81897, f: 0, ineq: 0.00182638, eq: 0.35643 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.827139, evals: 143, done: 1, feasible: 0, sos: 14.8787, f: 0, ineq: 0.00655244, eq: 0.890109 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.117261, evals: 200, done: 1, feasible: 0, sos: 6.8848, f: 0, ineq: 0.348803, eq: 1.12282 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.113238, evals: 201, done: 1, feasible: 1, sos: 11.0349, f: 0, ineq: 0.0223686, eq: 0.140756 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.210284, evals: 57, done: 1, feasible: 1, sos: 2.8093, f: 0, ineq: 0.000210178, eq: 0.0465593 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.279987, evals: 64, done: 1, feasible: 0, sos: 7.61975, f: 0, ineq: 4.84801e-06, eq: 0.77584 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.118092, evals: 201, done: 1, feasible: 0, sos: 6.88493, f: 0, ineq: 0.348832, eq: 1.12281 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.114346, evals: 201, done: 1, feasible: 0, sos: 6.88491, f: 0, ineq: 0.348827, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.124688, evals: 201, done: 1, feasible: 0, sos: 6.88491, f: 0, ineq: 0.348827, eq: 1.12274 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.091617, evals: 166, done: 1, feasible: 1, sos: 13.8022, f: 0, ineq: 0.103132, eq: 0.313516 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 0.97149, evals: 200, done: 1, feasible: 1, sos: 8.50168, f: 0, ineq: 0.00262231, eq: 0.224906 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 0.95811, evals: 162, done: 1, feasible: 0, sos: 14.4591, f: 0, ineq: 0.0125123, eq: 0.92846 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.121518, evals: 201, done: 1, feasible: 0, sos: 6.88493, f: 0, ineq: 0.348832, eq: 1.12281 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.117505, evals: 200, done: 1, feasible: 0, sos: 6.88518, f: 0, ineq: 0.348802, eq: 1.1227 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.127268, evals: 200, done: 1, feasible: 0, sos: 6.88439, f: 0, ineq: 0.348836, eq: 1.12298 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp y place z
#      { time: 0.11514, evals: 200, done: 1, feasible: 1, sos: 13.8028, f: 0, ineq: 0.103053, eq: 0.313426 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp y place z
#      { time: 1.01337, evals: 201, done: 1, feasible: 1, sos: 8.6559, f: 0, ineq: 0.00158516, eq: 0.229067 }
#   -- infeasible:sub_motion_1--placement 2: grasp y place z
#      { time: 1.03699, evals: 158, done: 1, feasible: 0, sos: 14.4804, f: 0, ineq: 0.0113633, eq: 0.915718 }
# Failed placing block number 3 with grasp direction y at M3 :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.113944, evals: 201, done: 1, feasible: 1, sos: 11.0279, f: 0, ineq: 0.0227113, eq: 0.140969 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.182698, evals: 48, done: 1, feasible: 1, sos: 2.81219, f: 0, ineq: 0.000170237, eq: 0.0419273 }
#   -- infeasible:sub_motion_1--placement 2: grasp x place z
#      { time: 0.30645, evals: 64, done: 1, feasible: 0, sos: 7.61596, f: 0, ineq: 4.87975e-06, eq: 0.776128 }
# Failed placing block number 3 with grasp direction x at M3 :(
# === placement 2: grasp z place z
# place direction: z
# 3rd Block: (box1)
#   -- infeasible:placement 2: grasp z place z
#      { time: 0.188378, evals: 200, done: 1, feasible: 0, sos: 6.88506, f: 0, ineq: 0.348815, eq: 1.12269 }
# Failed placing block number 3 with grasp direction z at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
#   -- feasible:placement 2: grasp x place z
#      { time: 0.168635, evals: 201, done: 1, feasible: 1, sos: 11.0276, f: 0, ineq: 0.0226998, eq: 0.140956 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 2: grasp x place z
#      { time: 0.307916, evals: 55, done: 1, feasible: 1, sos: 2.81213, f: 0, ineq: 0.000170385, eq: 0.0419271 }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 88
#      85     M3.retract([.0, .2], gripper, dist = .13)
#      86     M3.approach([.8, 1.], gripper)
# ---> 88 paths.append(M3.solve())
#      89 if not M3.ret.feasible:
#      90     print(f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :(")
#
# File ~/panda-robot/manipulation/bridge_build/manipulation.py:357, in ManipulationModelling.solve(self, verbose)
#     355 sol.setProblem(self.komo.nlp())
#     356 sol.setOptions(damping=1e-3, verbose=verbose-1, stopTolerance=1e-3, maxLambda=100., stopEvals=200)
# --> 357 self.ret = sol.solve()
#     358 if self.ret.feasible:
#     359     self.path = self.komo.getPath()
#
# KeyboardInterrupt:
