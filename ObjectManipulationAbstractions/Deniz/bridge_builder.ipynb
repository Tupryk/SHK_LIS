# %% [markdown]
# ### Libaries

# %%
import robotic as ry
import numpy as np
import time
from scipy.interpolate import Rbf
from scipy.interpolate import CubicSpline
print('version:', ry.__version__, ry.compiled())
# Out:
# version: 0.1.3 compile time: Dec 15 2023 11:21:37

# %% [markdown]
# ### Initalise configuration

# %%
C = ry.Config()
C.addFile(ry.raiPath('scenarios/pandaSingle.g'))
C.view()
print(C.getFrameNames())
# Out:
# ['world', 'table', 'l_panda_base', 'l_panda_link0', 'l_panda_link0_0', 'l_panda_joint1_origin', 'l_panda_joint1', 'l_panda_link1', 'l_panda_link1_0', 'l_panda_joint2_origin', 'l_panda_joint2', 'l_panda_link2', 'l_panda_link2_0', 'l_panda_joint3_origin', 'l_panda_joint3', 'l_panda_link3', 'l_panda_link3_0', 'l_panda_joint4_origin', 'l_panda_joint4', 'l_panda_link4', 'l_panda_link4_0', 'l_panda_joint5_origin', 'l_panda_joint5', 'l_panda_link5', 'l_panda_link5_0', 'l_panda_joint6_origin', 'l_panda_joint6', 'l_panda_link6', 'l_panda_link6_0', 'l_panda_joint7_origin', 'l_panda_joint7', 'l_panda_link7', 'l_panda_link7_0', 'l_panda_joint8_origin', 'l_panda_joint8', 'l_panda_link8', 'l_panda_hand_joint_origin', 'l_panda_hand_joint', 'l_panda_hand', 'l_panda_hand_0', 'l_panda_finger_joint1_origin', 'l_panda_finger_joint2_origin', 'l_panda_finger_joint1', 'l_panda_finger_joint2', 'l_panda_leftfinger', 'l_panda_rightfinger', 'l_panda_leftfinger_0', 'l_panda_rightfinger_0', 'l_panda_coll0', 'l_panda_coll0b', 'l_panda_coll1', 'l_panda_coll3', 'l_panda_coll5', 'l_panda_coll2', 'l_panda_coll4', 'l_panda_coll6', 'l_panda_coll7', 'l_gripper', 'l_palm', 'l_finger1', 'l_finger2', 'cameraTop', 'cameraWrist', 'panda_collCameraWrist', 'bellybutton']

# %% [markdown]
# ### Define color map

# %%
color_map = [[1,0,.5], # pink
             [0.5,1,0], # lime green
             [.5,1,1], # light turqois
             [0.5,0,1], # violet
             [1,0,0], # red
             [0,1,0], # green
             [0,0,1], # blue
             [1,.5,0], # orange
             [1,1,.5], # lime yellow
             [1,.5,1], # light pink                            
]

# %% [markdown]
# ### Gripper functions

# %%
def gripper_open(C, bot: ry.BotOp, widht = 0.75, speed = 0.2):
    bot.gripperMove(ry._left, widht, speed)

    while not bot.gripperDone(ry._left):
        bot.sync(C, .1)

def gripper_close(bot, widht = 0.01, speed = 0.2):
    bot.gripperMove(ry._left, widht, speed)

    while not bot.gripperDone(ry._left):
        bot.sync(C, .1)

def gripper_close_grasp(bot, target_obj = '', force=5.00, widht = 0.01, speed = 0.2):
    bot.gripperCloseGrasp(ry._left, target_obj, force, widht, speed)
    while not bot.gripperDone(ry._left):
        bot.sync(C, .1)

# %% [markdown]
# ### Create N number of building cuboids

# %%
def create_n_boxes(C, N, position='fixed'):

    for i in range(N):
        box_name = 'box{}'.format(i + 1)

        if position == 'fixed':
            position_val1 = 0.1 * (i - 1)
            C.addFrame(box_name) \
                .setPosition([position_val1, 0.35, 0.70]) \
                .setShape(ry.ST.ssBox, size=[0.05, 0.05, 0.10, 0.005]) \
                .setColor(color_map[i % len(color_map)]) \
                .setContact(True) \
                .setMass(1e-2)


        elif position == 'random':
            C.addFrame(box_name) \
                .setPosition([np.random.uniform(-0.5, 0.5), np.random.uniform(-0.5, 0.5), 0.70]) \
                .setShape(ry.ST.ssBox, size=[0.05, 0.05, 0.10, 0.005]) \
                .setColor(color_map[i % len(color_map)]) \
                .setContact(True) \
                .setMass(1e-2)
    
    return C

# %% [markdown]
# ### Define construction site

# %%
def create_construction_site(C, position = 'fixed'):
    
    if position == 'fixed':
        target_location = C.addFrame('construction_site', 'table')
        target_location.setShape(ry.ST.box, size = [.275, .275, .090])
        target_location.setRelativePosition([-.5, -.225, .0])
        target_location.setColor([1., 0.75, 0.])
        return target_location
    
    elif position == 'random':
        target_location = C.addFrame('construction_site', 'table')
        target_location.setShape(ry.ST.box, size = [.3, .3, .1])
        target_location.setRelativePosition([np.random.uniform(-0.5, 0.5), np.random.uniform(-0.5, 0.5), .0])
        target_location.setColor([1, 0.75, 0])
        return target_location

# %%
def create_pillar_target_postion(C, position = 'fixed', n_pillars = 2):
    
    if position == 'fixed':
        for i in range(0, n_pillars):
            target_pillar = C.addFrame('pillar_target_pos' + str(i+1), 'table')
            target_pillar.setShape(ry.ST.box, size=[.065, .065, .090])
            target_pillar.setRelativePosition([-.45 - (i / 10) , -.225, .0])
            target_pillar.setColor([0,1,0])
    
    elif position == 'random':
        for i in range(0, n_pillars):
            C = C.addFrame('pillar_target_pos' + str(i+1), 'table')
            target_pillar.setShape(ry.ST.box, size=[.065, .065, .090])
            target_pillar.setRelativePosition([np.random.uniform(-0.5, 0.5), np.random.uniform(-0.5, 0.5), .0])
            target_pillar.setColor([0,1,0])
        return C

# %% [markdown]
# ### Define Komo problem

# %%
C = ry.Config()
C.addFile(ry.raiPath('scenarios/pandaSingle.g'))
C = create_n_boxes(C = C, N = 3, position = 'fixed')
goal = create_construction_site(C, position = 'fixed')
pillar_goal = create_pillar_target_postion(C, position = 'fixed')
C.view()
# Out:
# 0

# %%
def gripper_to_block(C, bot, block = 'box1', prints = False):
    qHome = C.getJointState()

    komo = ry.KOMO(C, 1, 1, 0, False)

    komo.addObjective(
        times=[], 
        feature=ry.FS.jointState, 
        frames=[],
        type=ry.OT.sos, 
        scale=[1e-1], 
        target=qHome
    )
    komo.addObjective([], ry.FS.jointState, [], ry.OT.sos, [1e-1], qHome)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
    komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq)
    komo.addObjective([], ry.FS.positionDiff, ['l_gripper', block], ry.OT.eq, [1e1])
    komo.addObjective([], ry.FS.scalarProductXZ, ['l_gripper', block], ry.OT.eq, [1e1], [0])
    komo.addObjective([], ry.FS.scalarProductXY, ['l_gripper', block], ry.OT.eq, [1e1], [1])

    komo.addObjective([], ry.FS.distance, ['l_palm', block], ry.OT.ineq, [1e1])
    komo.addObjective([1], ry.FS.vectorZ, ['l_gripper'], ry.OT.eq, [1e1], [0, 0 , 1])
    # no table collision
    komo.addObjective([], ry.FS.distance, ['l_palm', 'table'], ry.OT.ineq, [1e1], [-0.001])

    ret = ry.NLP_Solver(komo.nlp(), verbose=4) .solve()
    if prints == True:
        print(ret)
    
    q = komo.getPath()

    bot.moveTo(q[-1], 5)
    while bot.getTimeToEnd() > 0:
        bot.sync(C, .5)

# %%
def move_gripper_to(C, bot, add_frame_obj_str = 'target', carry_item = 'box1', orientation = 'vertical', prints=False):
    komo = ry.KOMO(C, 1, 1, 1, True)
    komo.addControlObjective([], 0, 0.1e1)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
    komo.addObjective([1], ry.FS.positionDiff, ['l_gripper', add_frame_obj_str], ry.OT.eq, [1e1])
    
    if orientation == 'vertical':
        komo.addObjective([1], ry.FS.vectorZ, ['l_gripper'], ry.OT.eq, [1e1], [0, 0 , 1])    
        komo.addObjective([1], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1], [0, 1, 0])     

    if orientation == 'horizontal':
        komo.addObjective([1], ry.FS.vectorZ, ['l_gripper'], ry.OT.eq, [1e1], [1, 0, 0])
        komo.addObjective([1], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1], [0, 1, 0])     

    # no table collision
    komo.addObjective([], ry.FS.negDistance, ['l_palm', 'table'], ry.OT.ineq, [1e1], [-0.175])
    
    # avoid palm collision with box
    komo.addObjective([], ry.FS.distance, ['l_gripper', carry_item], ry.OT.ineq, [1e1], [-.001])
    

    # avoid box collision during transport of box
    boxes = [f"box{i}" for i in range(1, 4)]
    boxes.remove(carry_item)
    for box in boxes:
        komo.addObjective([], ry.FS.distance, [carry_item, box], ry.OT.ineq, [1e1], [-.001])


    ret = ry.NLP_Solver(komo.nlp(), verbose=4) .solve()
    if prints == True:
        print(ret)
    
    q = komo.getPath()
    
    bot.moveTo(q[-1], 2)
    while bot.getTimeToEnd() > 0:
        bot.sync(C, .1)

# %%
def retract_gripper(C, bot, distance = 0.25, prints = False):
    gripper_pos = C.getFrame("l_gripper").getPosition()
    retract_to_pos = gripper_pos + [0.0, 0.0, distance]
    C.addFrame('retract_to_pos').setShape(ry.ST.marker, [.1, .1, .1]).setPosition(retract_to_pos).setColor([1, .5, 1])

    komo = ry.KOMO(C, 1, 1, 1, True)
    komo.addControlObjective([], 0, 0.1e1)
    komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq)
    komo.addObjective([1], ry.FS.positionDiff, ['l_gripper', 'retract_to_pos'], ry.OT.eq, [1e1])

    # orient block horizontally
    komo.addObjective([1], ry.FS.vectorZ, ['l_gripper'], ry.OT.eq, [1e1], [0, 0 , 1])    
    komo.addObjective([1], ry.FS.vectorX, ['l_gripper'], ry.OT.eq, [1e1], [0, 1, 0])     

    ret = ry.NLP_Solver(komo.nlp(), verbose=4) .solve()
    if prints == True:
        print(ret)
    
    q = komo.getPath()
    
    bot.moveTo(q[-1], 2)
    while bot.getTimeToEnd() > 0:
        bot.sync(C, .1)

# %%
bot = ry.BotOp(C, useRealRobot = False)

# %% [markdown]
# ## First block

# %%
gripper_open(C, bot)
gripper_to_block(C, bot, block='box1')
gripper_close_grasp(bot, target_obj = 'box1', force = 5.0,  widht = 0.045)
move_gripper_to(C, bot, add_frame_obj_str = 'pillar_target_pos1', carry_item = 'box1', orientation = 'vertical')
gripper_open(C, bot)
retract_gripper(C, bot, distance = 0.15)
bot.home(C)
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):79.6575 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    54.4448  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):      27.91  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):       12.4  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    5.44637  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    1.73578  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):   0.176322  ACCEPT
# --newton-- it:   7  |Delta|:   0.080895  alpha:          1  evals:   8  f(y):  0.0426954  ACCEPT
# --newton-- it:   8  |Delta|:  0.0314055  alpha:          1  evals:   9  f(y):  0.0383359  ACCEPT
# --newton-- it:   9  |Delta|:  0.0190444  alpha:          1  evals:  10  f(y):  0.0378521  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  10  A(x):  0.0378521  f:  0.0297169  g:  0.0322245  h:   0.158022  |x-x'|:   0.996576 	stop:DeltaConverge
# ==nlp== it:   1  evals:  10  A(x):  0.0866635  mu:5
# --newton-- it:  10  |Delta|:  0.0428292  alpha:          1  evals:  11  f(y):  0.0825595  ACCEPT
# --newton-- it:  11  |Delta|:  0.0590372  alpha:          1  evals:  12  f(y):  0.0823826  ACCEPT
# --newton-- it:  12  |Delta|:  0.0182505  alpha:          1  evals:  13  f(y):  0.0804436  ACCEPT
# --newton-- it:  13  |Delta|: 0.00311403  alpha:          1  evals:  14  f(y):   0.080402  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  14  A(x):   0.080402  f:  0.0298662  g:  0.0354663  h:   0.146737  |x-x'|:  0.0842975 	stop:DeltaConverge
# ==nlp== it:   2  evals:  14  A(x):   0.293457  mu:25
# --newton-- it:  14  |Delta|: 0.00311596  alpha:          1  evals:  15  f(y):   0.293362  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  15  A(x):   0.293362  f:  0.0298378  g:  0.0355038  h:    0.14518  |x-x'|: 0.00311596 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.293362
# -- kin_physx.cpp:addJoint:299(0) ADDING JOINT l_panda_joint7-box1 of type rigid with rel [0, 0, 0]
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):48.8643 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    40.8443  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):     30.829  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    21.6177  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):     15.552  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    11.1831  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    8.30355  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    7.07057  ACCEPT
# --newton-- it:   8  |Delta|:   0.107257  alpha:          1  evals:   9  f(y):    6.90921  ACCEPT
# --newton-- it:   9  |Delta|:  0.0482965  alpha:          1  evals:  10  f(y):    6.87046  ACCEPT
# --newton-- it:  10  |Delta|:  0.0468967  alpha:          1  evals:  11  f(y):    6.84488  ACCEPT
# --newton-- it:  11  |Delta|:  0.0369835  alpha:          1  evals:  12  f(y):    6.82875  ACCEPT
# --newton-- it:  12  |Delta|:  0.0281714  alpha:          1  evals:  13  f(y):    6.81953  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  13  A(x):    6.81953  f:    4.30539  g:   0.442071  h:    2.67958  |x-x'|:    1.37147 	stop:DeltaConverge
# ==nlp== it:   1  evals:  13  A(x):    21.9044  mu:5
# --newton-- it:  13  |Delta|:        0.2  alpha:          1  evals:  14  f(y):    18.5438  ACCEPT
# --newton-- it:  14  |Delta|:        0.2  alpha:          1  evals:  15  f(y):    17.8675  ACCEPT
# --newton-- it:  15  |Delta|:  0.0754579  alpha:          1  evals:  16  f(y):    17.5977  ACCEPT
# --newton-- it:  16  |Delta|:  0.0501679  alpha:          1  evals:  17  f(y):    17.5821  ACCEPT
# --newton-- it:  17  |Delta|:  0.0210876  alpha:          1  evals:  18  f(y):     17.598  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  19  f(y):    17.5621  ACCEPT
# --newton-- it:  18  |Delta|:    0.01711  alpha:       0.75  evals:  20  f(y):     17.567  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  21  f(y):    17.5546  ACCEPT
# --newton-- it:  19  |Delta|:  0.0119036  alpha:     0.5625  evals:  22  f(y):    17.5659  reject (lineSearch:0)
#                     (line search)        alpha:    0.28125  evals:  23  f(y):    17.5591  reject (lineSearch:1)
#                     (line search)        alpha:   0.140625  evals:  24  f(y):     17.556  reject (lineSearch:2)
#                     (line search)        alpha:  0.0703125  evals:  25  f(y):    17.5545  ACCEPT
# --newton-- it:  20  |Delta|:    0.01461  alpha:   0.105469  evals:  26  f(y):    17.5562  reject (lineSearch:0)
#                     (line search)        alpha:  0.0527344  evals:  27  f(y):     17.555  reject (lineSearch:1)
#                     (line search)        alpha:  0.0263672  evals:  28  f(y):    17.5544  ACCEPT
# --newton-- it:  21  |Delta|:  0.0114182  alpha:  0.0395508  evals:  29  f(y):    17.5541  ACCEPT
# --newton-- it:  22  |Delta|:  0.0110631  alpha:  0.0593262  evals:  30  f(y):    17.5551  reject (lineSearch:0)
#                     (line search)        alpha:  0.0296631  evals:  31  f(y):    17.5546  reject (lineSearch:1)
#                     (line search)        alpha:  0.0148315  evals:  32  f(y):    17.5543  reject (lineSearch:2)
#                     (line search)        alpha: 0.00741577  evals:  33  f(y):    17.5541  reject (lineSearch:3)
#                     (line search)        alpha: 0.00370789  evals:  34  f(y):     17.554  ACCEPT
# --newton-- it:  23  |Delta|: 0.00819632  alpha: 0.00556183  evals:  35  f(y):    17.5541  reject (lineSearch:0)
#                     (line search)        alpha: 0.00278091  evals:  36  f(y):     17.554  reject (lineSearch:1)
#                     (line search)        alpha: 0.00139046  evals:  37  f(y):     17.554  reject (lineSearch:2)
#                     (line search)        alpha:0.000695229  evals:  38  f(y):     17.554  reject (lineSearch:3)
#                     (line search)        alpha:0.000347614  evals:  39  f(y):     17.554  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  39  A(x):     17.554  f:    5.92764  g:   0.922521  h:    1.03008  |x-x'|:   0.420047 	stop:DeltaConverge
# ==nlp== it:   2  evals:  39  A(x):      67.45  mu:25
# --newton-- it:  24  |Delta|:  0.0261343  alpha:       0.01  evals:  40  f(y):    67.4467  ACCEPT
# --newton-- it:  25  |Delta|:  0.0262271  alpha:      0.015  evals:  41  f(y):    67.4438  ACCEPT
# --newton-- it:  26  |Delta|:  0.0250683  alpha:     0.0225  evals:  42  f(y):    67.4353  ACCEPT
# --newton-- it:  27  |Delta|:   0.025265  alpha:    0.03375  evals:  43  f(y):    67.4285  ACCEPT
# --newton-- it:  28  |Delta|:  0.0236482  alpha:   0.050625  evals:  44  f(y):    67.4127  ACCEPT
# --newton-- it:  29  |Delta|:  0.0232059  alpha:  0.0759375  evals:  45  f(y):    67.4003  ACCEPT
# --newton-- it:  30  |Delta|:  0.0206846  alpha:   0.113906  evals:  46  f(y):    67.3745  ACCEPT
# --newton-- it:  31  |Delta|:  0.0190726  alpha:   0.170859  evals:  47  f(y):    67.3613  ACCEPT
# --newton-- it:  32  |Delta|:  0.0150731  alpha:   0.256289  evals:  48  f(y):    67.3341  ACCEPT
# --newton-- it:  33  |Delta|:  0.0119339  alpha:   0.384434  evals:  49  f(y):    67.3467  reject (lineSearch:0)
#                     (line search)        alpha:   0.192217  evals:  50  f(y):    67.3163  ACCEPT
# --newton-- it:  34  |Delta|:  0.0105352  alpha:   0.288325  evals:  51  f(y):    67.3233  reject (lineSearch:0)
#                     (line search)        alpha:   0.144163  evals:  52  f(y):    67.3017  ACCEPT
# --newton-- it:  35  |Delta|: 0.00924595  alpha:   0.216244  evals:  53  f(y):    67.3197  reject (lineSearch:0)
#                     (line search)        alpha:   0.108122  evals:  54  f(y):    67.3032  reject (lineSearch:1)
#                     (line search)        alpha:   0.054061  evals:  55  f(y):    67.2959  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  55  A(x):    67.2959  f:    5.96281  g:   0.914802  h:   0.950672  |x-x'|:  0.0185392 	stop:DeltaConverge
# ==nlp== it:   3  evals:  55  A(x):    315.842  mu:125
# --newton-- it:  36  |Delta|: 0.00988536  alpha:  0.0810915  evals:  56  f(y):     315.86  reject (lineSearch:0)
#                     (line search)        alpha:  0.0405457  evals:  57  f(y):    315.835  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  57  A(x):    315.835  f:    5.96508  g:   0.914631  h:   0.949176  |x-x'|:0.000400809 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):315.835
# -- kin_physx.cpp:removeJoint:893(0) REMOVING JOINT 0x26f9580-0x30781b0 of type rigid
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):8.24094 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    5.18073  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    3.63092  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    3.16141  ACCEPT
# --newton-- it:   4  |Delta|:    0.12033  alpha:          1  evals:   5  f(y):    3.02816  ACCEPT
# --newton-- it:   5  |Delta|:  0.0658777  alpha:          1  evals:   6  f(y):    2.98674  ACCEPT
# --newton-- it:   6  |Delta|:   0.039928  alpha:          1  evals:   7  f(y):    2.97171  ACCEPT
# --newton-- it:   7  |Delta|:  0.0251151  alpha:          1  evals:   8  f(y):    2.96573  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   8  A(x):    2.96573  f:    2.68941  g:          0  h:    1.07247  |x-x'|:   0.778275 	stop:DeltaConverge
# ==nlp== it:   1  evals:   8  A(x):    4.62368  mu:5
# --newton-- it:   8  |Delta|:   0.136454  alpha:          1  evals:   9  f(y):    3.55086  ACCEPT
# --newton-- it:   9  |Delta|:  0.0339835  alpha:          1  evals:  10  f(y):     3.3686  ACCEPT
# --newton-- it:  10  |Delta|:  0.0113807  alpha:          1  evals:  11  f(y):    3.36752  ACCEPT
# --newton-- it:  11  |Delta|: 0.00920093  alpha:          1  evals:  12  f(y):    3.36683  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  12  A(x):    3.36683  f:     3.2842  g:          0  h:   0.132714  |x-x'|:   0.150627 	stop:DeltaConverge
# ==nlp== it:   2  evals:  12  A(x):      3.521  mu:25
# --newton-- it:  12  |Delta|:   0.043082  alpha:          1  evals:  13  f(y):    3.40778  ACCEPT
# --newton-- it:  13  |Delta|:   0.026745  alpha:          1  evals:  14  f(y):    3.39646  ACCEPT
# --newton-- it:  14  |Delta|:  0.0207787  alpha:          1  evals:  15  f(y):    3.39373  ACCEPT
# --newton-- it:  15  |Delta|:   0.015155  alpha:          1  evals:  16  f(y):    3.39233  ACCEPT
# --newton-- it:  16  |Delta|:  0.0106228  alpha:          1  evals:  17  f(y):    3.39165  ACCEPT
# --newton-- it:  17  |Delta|: 0.00725476  alpha:          1  evals:  18  f(y):    3.39134  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  18  A(x):    3.39134  f:     3.3869  g:          0  h:  0.0109487  |x-x'|:  0.0799808 	stop:DeltaConverge
# ==nlp== it:   3  evals:  18  A(x):    3.39994  mu:125
# --newton-- it:  18  |Delta|: 0.00469167  alpha:          1  evals:  19  f(y):    3.39949  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  19  A(x):    3.39949  f:    3.38931  g:          0  h:  0.0075855  |x-x'|: 0.00469167 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):3.39949

# %% [markdown]
# ### Second Block

# %%
gripper_open(C, bot)
gripper_to_block(C, bot, block='box2')
gripper_close_grasp(bot, target_obj = 'box2', force = 5.0,  widht = 0.045)
move_gripper_to(C, bot, add_frame_obj_str = 'pillar_target_pos2', carry_item = 'box2', orientation = 'vertical')
gripper_open(C, bot)
retract_gripper(C, bot, distance = 0.15)
bot.home(C)
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):74.2649 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     49.948  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    24.6529  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):     10.724  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    4.44636  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    1.21202  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):  0.0677392  ACCEPT
# --newton-- it:   7  |Delta|:  0.0463289  alpha:          1  evals:   8  f(y):  0.0389781  ACCEPT
# --newton-- it:   8  |Delta|:  0.0208179  alpha:          1  evals:   9  f(y):  0.0379502  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   9  A(x):  0.0379502  f:  0.0297522  g:  0.0318662  h:    0.16997  |x-x'|:   0.957535 	stop:DeltaConverge
# ==nlp== it:   1  evals:   9  A(x):  0.0871382  mu:5
# --newton-- it:   9  |Delta|:  0.0331363  alpha:          1  evals:  10  f(y):   0.083303  ACCEPT
# --newton-- it:  10  |Delta|:  0.0390261  alpha:          1  evals:  11  f(y):  0.0811603  ACCEPT
# --newton-- it:  11  |Delta|:  0.0146067  alpha:          1  evals:  12  f(y):  0.0808695  ACCEPT
# --newton-- it:  12  |Delta|: 0.00268197  alpha:          1  evals:  13  f(y):  0.0808517  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  13  A(x):  0.0808517  f:  0.0307512  g:  0.0355258  h:   0.141978  |x-x'|:  0.0840872 	stop:DeltaConverge
# ==nlp== it:   2  evals:  13  A(x):   0.291592  mu:25
# --newton-- it:  13  |Delta|: 0.00611381  alpha:          1  evals:  14  f(y):   0.291439  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  14  A(x):   0.291439  f:  0.0308355  g:  0.0354867  h:   0.143363  |x-x'|: 0.00611381 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.291439
# -- kin_physx.cpp:addJoint:299(0) ADDING JOINT l_panda_joint7-box2 of type rigid with rel [0, 0, 0]
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):64.8514 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    49.2514  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    36.3655  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):     27.312  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    20.6035  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    15.4771  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    11.6976  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    9.14364  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    7.61559  ACCEPT
# --newton-- it:   9  |Delta|:   0.164123  alpha:          1  evals:  10  f(y):    7.07139  ACCEPT
# --newton-- it:  10  |Delta|:  0.0717287  alpha:          1  evals:  11  f(y):    6.97306  ACCEPT
# --newton-- it:  11  |Delta|:  0.0386018  alpha:          1  evals:  12  f(y):    6.95617  ACCEPT
# --newton-- it:  12  |Delta|:   0.017471  alpha:          1  evals:  13  f(y):    6.95319  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  13  A(x):    6.95319  f:    4.82951  g:   0.640163  h:    2.27452  |x-x'|:    1.66455 	stop:DeltaConverge
# ==nlp== it:   1  evals:  13  A(x):    19.6952  mu:5
# --newton-- it:  13  |Delta|:   0.145829  alpha:          1  evals:  14  f(y):    17.4197  ACCEPT
# --newton-- it:  14  |Delta|:  0.0527122  alpha:          1  evals:  15  f(y):    17.4185  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  16  f(y):    17.3933  ACCEPT
# --newton-- it:  15  |Delta|:  0.0350096  alpha:       0.75  evals:  17  f(y):    17.3899  ACCEPT
# --newton-- it:  16  |Delta|:  0.0197618  alpha:          1  evals:  18  f(y):    17.4143  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  19  f(y):      17.38  ACCEPT
# --newton-- it:  17  |Delta|:  0.0146857  alpha:       0.75  evals:  20  f(y):    17.3889  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  21  f(y):    17.3721  ACCEPT
# --newton-- it:  18  |Delta|:  0.0118725  alpha:     0.5625  evals:  22  f(y):    17.3892  reject (lineSearch:0)
#                     (line search)        alpha:    0.28125  evals:  23  f(y):    17.3774  reject (lineSearch:1)
#                     (line search)        alpha:   0.140625  evals:  24  f(y):    17.3728  reject (lineSearch:2)
#                     (line search)        alpha:  0.0703125  evals:  25  f(y):    17.3708  ACCEPT
# --newton-- it:  19  |Delta|:  0.0100165  alpha:   0.105469  evals:  26  f(y):    17.3719  reject (lineSearch:0)
#                     (line search)        alpha:  0.0527344  evals:  27  f(y):    17.3705  ACCEPT
# --newton-- it:  20  |Delta|:  0.0112033  alpha:  0.0791016  evals:  28  f(y):    17.3719  reject (lineSearch:0)
#                     (line search)        alpha:  0.0395508  evals:  29  f(y):    17.3709  reject (lineSearch:1)
#                     (line search)        alpha:  0.0197754  evals:  30  f(y):    17.3704  ACCEPT
# --newton-- it:  21  |Delta|: 0.00959846  alpha:  0.0296631  evals:  31  f(y):    17.3704  reject (lineSearch:0)
#                     (line search)        alpha:  0.0148315  evals:  32  f(y):    17.3701  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  32  A(x):    17.3701  f:     5.7506  g:   0.911314  h:   0.956667  |x-x'|:   0.175008 	stop:DeltaConverge
# ==nlp== it:   2  evals:  32  A(x):    67.0742  mu:25
# --newton-- it:  22  |Delta|:  0.0117875  alpha:  0.0222473  evals:  33  f(y):    67.0766  reject (lineSearch:0)
#                     (line search)        alpha:  0.0111237  evals:  34  f(y):    67.0752  reject (lineSearch:1)
#                     (line search)        alpha: 0.00556183  evals:  35  f(y):    67.0745  reject (lineSearch:2)
#                     (line search)        alpha: 0.00278091  evals:  36  f(y):    67.0741  ACCEPT
# --newton-- it:  23  |Delta|:  0.0101884  alpha: 0.00417137  evals:  37  f(y):    67.0743  reject (lineSearch:0)
#                     (line search)        alpha: 0.00208569  evals:  38  f(y):     67.074  ACCEPT
# --newton-- it:  24  |Delta|:  0.0117581  alpha: 0.00312853  evals:  39  f(y):    67.0741  reject (lineSearch:0)
#                     (line search)        alpha: 0.00156426  evals:  40  f(y):    67.0739  ACCEPT
# --newton-- it:  25  |Delta|:  0.0101732  alpha:  0.0023464  evals:  41  f(y):     67.074  reject (lineSearch:0)
#                     (line search)        alpha:  0.0011732  evals:  42  f(y):    67.0739  ACCEPT
# --newton-- it:  26  |Delta|:  0.0117416  alpha:  0.0017598  evals:  43  f(y):    67.0739  reject (lineSearch:0)
#                     (line search)        alpha:0.000879899  evals:  44  f(y):    67.0738  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   2  evals:  44  A(x):    67.0738  f:    5.75075  g:   0.911312  h:   0.956253  |x-x'|:7.04936e-05 	stop:TinyXSteps (bad:1)
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):67.0738
# -- kin_physx.cpp:removeJoint:893(0) REMOVING JOINT 0x26f9580-0x30784d0 of type rigid
# -- WARNING:kin.cpp:addFrame:192(-1) frame already exists! returning existing without modifications!
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):8.13168 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):     5.0891  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    3.90998  ACCEPT
# --newton-- it:   3  |Delta|:   0.165673  alpha:          1  evals:   4  f(y):    3.67965  ACCEPT
# --newton-- it:   4  |Delta|:   0.066804  alpha:          1  evals:   5  f(y):    3.63932  ACCEPT
# --newton-- it:   5  |Delta|:  0.0390969  alpha:          1  evals:   6  f(y):    3.62585  ACCEPT
# --newton-- it:   6  |Delta|:  0.0242332  alpha:          1  evals:   7  f(y):    3.62077  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   7  A(x):    3.62077  f:    3.17847  g:          0  h:    1.43046  |x-x'|:   0.573339 	stop:DeltaConverge
# ==nlp== it:   1  evals:   7  A(x):    6.27453  mu:5
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    4.50037  ACCEPT
# --newton-- it:   8  |Delta|:   0.160446  alpha:          1  evals:   9  f(y):    4.15578  ACCEPT
# --newton-- it:   9  |Delta|:  0.0224698  alpha:          1  evals:  10  f(y):    4.14035  ACCEPT
# --newton-- it:  10  |Delta|:  0.0116166  alpha:          1  evals:  11  f(y):    4.13957  ACCEPT
# --newton-- it:  11  |Delta|: 0.00262168  alpha:          1  evals:  12  f(y):    4.13952  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  12  A(x):    4.13952  f:    4.11904  g:          0  h:  0.0538716  |x-x'|:   0.229848 	stop:DeltaConverge
# ==nlp== it:   2  evals:  12  A(x):    4.15366  mu:25
# --newton-- it:  12  |Delta|: 0.00427904  alpha:          1  evals:  13  f(y):    4.14362  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  13  A(x):    4.14362  f:    4.14103  g:          0  h: 0.00856835  |x-x'|: 0.00427904 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):4.14362

# %% [markdown]
# ### 3rd Block

# %%
box_1 = C.getFrame('box1')
box_2 = C.getFrame('box2')
box_pos1 = box_1.getPosition()
box_pos2 = box_2.getPosition()
offset = 0.025
middle_between_towers = np.mean([box_pos1, box_pos2], 0) + [0, 0, offset]
C.addFrame('block3_target').setShape(ry.ST.marker, [.1, .1, .1]).setPosition(middle_between_towers).setColor([1, .5, 1])
C.view()
# Out:
# 0

# %%
gripper_to_block(C, bot, block='box3')
gripper_close_grasp(bot, target_obj = 'box3', force = 5.0,  widht = 0.045)
move_gripper_to(C, bot, add_frame_obj_str = 'block3_target', carry_item = 'box3', orientation = 'horizontal')
gripper_open(C, bot)
bot.home(C)
# Out:
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):78.0887 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    53.0683  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    26.7652  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    11.8903  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):     5.1757  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    1.59482  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):   0.141598  ACCEPT
# --newton-- it:   7  |Delta|:  0.0677051  alpha:          1  evals:   8  f(y):  0.0472195  ACCEPT
# --newton-- it:   8  |Delta|:     0.0226  alpha:          1  evals:   9  f(y):  0.0436298  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:   9  A(x):  0.0436298  f:  0.0334094  g:    0.03198  h:   0.195139  |x-x'|:   0.981578 	stop:DeltaConverge
# ==nlp== it:   1  evals:   9  A(x):   0.104953  mu:5
# --newton-- it:   9  |Delta|:  0.0356649  alpha:          1  evals:  10  f(y):   0.099053  ACCEPT
# --newton-- it:  10  |Delta|:  0.0448157  alpha:          1  evals:  11  f(y):  0.0958505  ACCEPT
# --newton-- it:  11  |Delta|: 0.00824462  alpha:          1  evals:  12  f(y):  0.0955357  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  12  A(x):  0.0955357  f:  0.0352402  g:  0.0355108  h:   0.157886  |x-x'|:  0.0887252 	stop:DeltaConverge
# ==nlp== it:   2  evals:  12  A(x):   0.347886  mu:25
# --newton-- it:  12  |Delta|: 0.00485682  alpha:          1  evals:  13  f(y):   0.347735  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  13  A(x):   0.347735  f:  0.0353233  g:  0.0355499  h:   0.159503  |x-x'|: 0.00485682 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):0.347735
# -- kin_physx.cpp:addJoint:299(0) ADDING JOINT l_panda_joint7-box3 of type rigid with rel [0, 0, 0]
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):271.592 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    227.529  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    199.799  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    179.508  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):    161.035  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    142.577  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    123.515  ACCEPT
# --newton-- it:   7  |Delta|:        0.2  alpha:          1  evals:   8  f(y):    103.766  ACCEPT
# --newton-- it:   8  |Delta|:        0.2  alpha:          1  evals:   9  f(y):    83.7043  ACCEPT
# --newton-- it:   9  |Delta|:        0.2  alpha:          1  evals:  10  f(y):     64.262  ACCEPT
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    46.8345  ACCEPT
# --newton-- it:  11  |Delta|:        0.2  alpha:          1  evals:  12  f(y):    32.7845  ACCEPT
# --newton-- it:  12  |Delta|:        0.2  alpha:          1  evals:  13  f(y):     22.873  ACCEPT
# --newton-- it:  13  |Delta|:        0.2  alpha:          1  evals:  14  f(y):    17.2228  ACCEPT
# --newton-- it:  14  |Delta|:   0.172105  alpha:          1  evals:  15  f(y):    15.8532  ACCEPT
# --newton-- it:  15  |Delta|:    0.10099  alpha:          1  evals:  16  f(y):    15.6544  ACCEPT
# --newton-- it:  16  |Delta|:  0.0340732  alpha:          1  evals:  17  f(y):    15.6272  ACCEPT
# --newton-- it:  17  |Delta|:  0.0150337  alpha:          1  evals:  18  f(y):    15.6231  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  18  A(x):    15.6231  f:    12.2806  g:   0.645321  h:    3.49041  |x-x'|:    2.62038 	stop:DeltaConverge
# ==nlp== it:   1  evals:  18  A(x):    35.6781  mu:5
# --newton-- it:  18  |Delta|:        0.2  alpha:          1  evals:  19  f(y):    29.0745  ACCEPT
# --newton-- it:  19  |Delta|:   0.186345  alpha:          1  evals:  20  f(y):    49.3001  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  21  f(y):    31.4223  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  22  f(y):    28.4057  ACCEPT
# --newton-- it:  20  |Delta|:   0.187914  alpha:      0.375  evals:  23  f(y):    27.6342  ACCEPT
# --newton-- it:  21  |Delta|:   0.138477  alpha:     0.5625  evals:  24  f(y):    27.1172  ACCEPT
# --newton-- it:  22  |Delta|:  0.0894432  alpha:    0.84375  evals:  25  f(y):    26.9352  ACCEPT
# --newton-- it:  23  |Delta|:   0.033243  alpha:          1  evals:  26  f(y):    26.9579  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  27  f(y):    26.8913  ACCEPT
# --newton-- it:  24  |Delta|:  0.0263407  alpha:       0.75  evals:  28  f(y):    26.9008  reject (lineSearch:0)
#                     (line search)        alpha:      0.375  evals:  29  f(y):    26.8678  ACCEPT
# --newton-- it:  25  |Delta|:  0.0143869  alpha:     0.5625  evals:  30  f(y):    26.9011  reject (lineSearch:0)
#                     (line search)        alpha:    0.28125  evals:  31  f(y):    26.8768  reject (lineSearch:1)
#                     (line search)        alpha:   0.140625  evals:  32  f(y):    26.8677  reject (lineSearch:2)
#                     (line search)        alpha:  0.0703125  evals:  33  f(y):     26.864  ACCEPT
# --newton-- it:  26  |Delta|:  0.0178775  alpha:   0.105469  evals:  34  f(y):    26.8659  reject (lineSearch:0)
#                     (line search)        alpha:  0.0527344  evals:  35  f(y):    26.8633  ACCEPT
# --newton-- it:  27  |Delta|:  0.0130566  alpha:  0.0791016  evals:  36  f(y):    26.8655  reject (lineSearch:0)
#                     (line search)        alpha:  0.0395508  evals:  37  f(y):    26.8634  reject (lineSearch:1)
#                     (line search)        alpha:  0.0197754  evals:  38  f(y):    26.8625  ACCEPT
# --newton-- it:  28  |Delta|:  0.0170649  alpha:  0.0296631  evals:  39  f(y):    26.8628  reject (lineSearch:0)
#                     (line search)        alpha:  0.0148315  evals:  40  f(y):    26.8621  ACCEPT
# --newton-- it:  29  |Delta|:  0.0127119  alpha:  0.0222473  evals:  41  f(y):    26.8629  reject (lineSearch:0)
#                     (line search)        alpha:  0.0111237  evals:  42  f(y):    26.8623  reject (lineSearch:1)
#                     (line search)        alpha: 0.00556183  evals:  43  f(y):    26.8621  ACCEPT
# --newton-- it:  30  |Delta|:  0.0168471  alpha: 0.00834274  evals:  44  f(y):     26.862  ACCEPT
# --newton-- it:  31  |Delta|:  0.0125796  alpha:  0.0125141  evals:  45  f(y):    26.8623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00625706  evals:  46  f(y):     26.862  ACCEPT
# --newton-- it:  32  |Delta|:  0.0167254  alpha: 0.00938559  evals:  47  f(y):    26.8619  ACCEPT
# --newton-- it:  33  |Delta|:  0.0124325  alpha:  0.0140784  evals:  48  f(y):    26.8623  reject (lineSearch:0)
#                     (line search)        alpha: 0.00703919  evals:  49  f(y):    26.8619  reject (lineSearch:1)
#                     (line search)        alpha: 0.00351959  evals:  50  f(y):    26.8618  ACCEPT
# --newton-- it:  34  |Delta|:  0.0165909  alpha: 0.00527939  evals:  51  f(y):    26.8618  reject (lineSearch:0)
#                     (line search)        alpha:  0.0026397  evals:  52  f(y):    26.8617  ACCEPT
# --newton-- it:  35  |Delta|:  0.0123739  alpha: 0.00395954  evals:  53  f(y):    26.8618  reject (lineSearch:0)
#                     (line search)        alpha: 0.00197977  evals:  54  f(y):    26.8617  reject (lineSearch:1)
#                     (line search)        alpha:0.000989886  evals:  55  f(y):    26.8617  reject (lineSearch:2)
#                     (line search)        alpha:0.000494943  evals:  56  f(y):    26.8617  ACCEPT
# --newton-- it:  36  |Delta|:  0.0165534  alpha:0.000742415  evals:  57  f(y):    26.8617  reject (lineSearch:0)
#                     (line search)        alpha:0.000371207  evals:  58  f(y):    26.8617  ACCEPT
# --newton-- it:  37  |Delta|:  0.0123656  alpha:0.000556811  evals:  59  f(y):    26.8617  reject (lineSearch:0)
#                     (line search)        alpha:0.000278405  evals:  60  f(y):    26.8617  reject (lineSearch:1)
#                     (line search)        alpha:0.000139203  evals:  61  f(y):    26.8617  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   1  evals:  61  A(x):    26.8617  f:    15.8503  g:   0.951825  h:    1.08358  |x-x'|:   0.362196 	stop:TinyXSteps (bad:1)
# ==nlp== it:   2  evals:  61  A(x):    72.9004  mu:25
# --newton-- it:  38  |Delta|:    0.18189  alpha:       0.01  evals:  62  f(y):    72.8784  ACCEPT
# --newton-- it:  39  |Delta|:   0.179715  alpha:      0.015  evals:  63  f(y):    72.8405  ACCEPT
# --newton-- it:  40  |Delta|:    0.17619  alpha:     0.0225  evals:  64  f(y):    72.7902  ACCEPT
# --newton-- it:  41  |Delta|:   0.171316  alpha:    0.03375  evals:  65  f(y):    72.7155  ACCEPT
# --newton-- it:  42  |Delta|:    0.16394  alpha:   0.050625  evals:  66  f(y):    72.6125  ACCEPT
# --newton-- it:  43  |Delta|:    0.15368  alpha:  0.0759375  evals:  67  f(y):    72.4777  ACCEPT
# --newton-- it:  44  |Delta|:   0.139105  alpha:   0.113906  evals:  68  f(y):    72.3026  ACCEPT
# --newton-- it:  45  |Delta|:   0.119777  alpha:   0.170859  evals:  69  f(y):    72.1167  ACCEPT
# --newton-- it:  46  |Delta|:  0.0950619  alpha:   0.256289  evals:  70  f(y):    71.9215  ACCEPT
# --newton-- it:  47  |Delta|:  0.0663468  alpha:   0.384434  evals:  71  f(y):    71.8151  ACCEPT
# --newton-- it:  48  |Delta|:  0.0458411  alpha:    0.57665  evals:  72  f(y):    71.7773  ACCEPT
# --newton-- it:  49  |Delta|:  0.0143497  alpha:   0.864976  evals:  73  f(y):     71.945  reject (lineSearch:0)
#                     (line search)        alpha:   0.432488  evals:  74  f(y):      71.68  ACCEPT
# --newton-- it:  50  |Delta|:  0.0183805  alpha:   0.648732  evals:  75  f(y):    71.8109  reject (lineSearch:0)
#                     (line search)        alpha:   0.324366  evals:  76  f(y):    71.6601  ACCEPT
# --newton-- it:  51  |Delta|: 0.00591173  alpha:   0.486549  evals:  77  f(y):      71.75  reject (lineSearch:0)
#                     (line search)        alpha:   0.243274  evals:  78  f(y):    71.6463  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   2  evals:  78  A(x):    71.6463  f:    16.7477  g:   0.875347  h:   0.962266  |x-x'|:   0.152027 	stop:DeltaConverge
# ==nlp== it:   3  evals:  78  A(x):    293.907  mu:125
# --newton-- it:  52  |Delta|:  0.0216456  alpha:   0.364912  evals:  79  f(y):    294.097  reject (lineSearch:0)
#                     (line search)        alpha:   0.182456  evals:  80  f(y):    293.772  ACCEPT
# --newton-- it:  53  |Delta|:        0.2  alpha:   0.273684  evals:  81  f(y):    314.027  reject (lineSearch:0)
#                     (line search)        alpha:   0.136842  evals:  82  f(y):    299.048  reject (lineSearch:1)
#                     (line search)        alpha:  0.0684209  evals:  83  f(y):    295.236  reject (lineSearch:2)
#                     (line search)        alpha:  0.0342105  evals:  84  f(y):    294.213  reject (lineSearch:3)
#                     (line search)        alpha:  0.0171052  evals:  85  f(y):    293.919  reject (lineSearch:4)
#                     (line search)        alpha: 0.00855262  evals:  86  f(y):    293.826  reject (lineSearch:5)
#                     (line search)        alpha: 0.00427631  evals:  87  f(y):    293.792  reject (lineSearch:6)
#                     (line search)        alpha: 0.00213815  evals:  88  f(y):    293.779  reject (lineSearch:7)
#                     (line search)        alpha: 0.00106908  evals:  89  f(y):    293.773  reject (lineSearch:8)
#                     (line search)        alpha:0.000534538  evals:  90  f(y):    293.771  ACCEPT
# --newton-- it:  54  |Delta|:        0.2  alpha:0.000801808  evals:  91  f(y):    293.774  reject (lineSearch:0)
#                     (line search)        alpha:0.000400904  evals:  92  f(y):    293.772  reject (lineSearch:1)
#                     (line search)        alpha:0.000200452  evals:  93  f(y):    293.771  reject (lineSearch:2)
#                     (line search)        alpha:0.000100226  evals:  94  f(y):    293.771  reject (lineSearch:3)
#                     (line search)        alpha: 5.0113e-05  evals:  95  f(y):    293.771  ACCEPT
# --newton-- it:  55  |Delta|:  0.0149034  alpha:7.51695e-05  evals:  96  f(y):     293.77  ACCEPT
# --newton-- it:  56  |Delta|:  0.0149023  alpha:0.000112754  evals:  97  f(y):     293.77  ACCEPT
# --newton-- it:  57  |Delta|:  0.0149006  alpha:0.000169131  evals:  98  f(y):     293.77  ACCEPT
# --newton-- it:  58  |Delta|:   0.014898  alpha:0.000253697  evals:  99  f(y):     293.77  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   3  evals:  99  A(x):     293.77  f:     16.773  g:   0.872176  h:   0.959816  |x-x'|: 0.00384441 	stop:TinyXSteps (bad:1)
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):293.77
# -- kin_physx.cpp:removeJoint:893(0) REMOVING JOINT 0x26f9580-0x30787f0 of type rigid

# %% [markdown]
# ### Clear config

# %%
C.clear()
