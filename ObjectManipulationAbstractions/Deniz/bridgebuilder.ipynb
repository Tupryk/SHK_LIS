# %%
import robotic as ry
import numpy as np
import random
from bridgebuild_env import create_n_boxes

# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import robot_execution as robex
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# ### Task Env: Bridge Builder

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
n_success = 0
while n_success <= 2:
    C.setJointState(qHome)
    box = np.random.choice(boxes)
    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])  # random.choice(['y', 'z']) #'x' not possible: box too large
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1.8e-1, accumulated_collisions=True
    )
    M.grasp_box(1.0, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if n_success > 1:

        print(f"3rd Block: ({box})")

        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.080])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        # M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

        print("Grasp Direction:", graspDirection)
        # M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

        if graspDirection == "x":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductXZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        elif graspDirection == "y":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductYZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )

    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)

        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.positionRel,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1.0],
            [0.0, 0.0, 0.1],
        )
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    #M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        # initial_pos= [0.020433060890705013, 0.08433819136314634]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2.0, box, table, initial_pos)
        M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
    
    ways = M.solve()

    if not M.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
        )
        continue
    print("Submotion 0")

    M2 = M.sub_motion(0)

    #M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.13)
    M2.approach([0.8, 1.0], gripper)
    M2.solve()
    if not M2.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :("
        )
        continue

    M3 = M.sub_motion(1)

    #M3.keep_distance([], table, box)
    
    if n_success > 1:
        M3.retract([0.0, 0.2], gripper, dist=0.13)
        M3.approach([0.8, 1.0], gripper)


    M3.solve()
    if not M3.ret.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :("
        )
        continue

    M2.play(C)
    C.attach(gripper, box)
    M3.play(C)
    C.attach(table, box)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1

del M
# Out:
# === placement 0: grasp y place z
# place direction: z
# 1st Block: (box3)
# Trying xy pos:  [0.0718337507698331, 0.026018038374756892]
#   -- infeasible:placement 0: grasp y place z
#      { time: 0.100613, evals: 201, done: 1, feasible: 0, sos: 0.131871, f: 0, ineq: 0.0373197, eq: 0.575488 }
# Failed placing block number 1 with grasp direction y at M :(
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.08275407234044804, 0.030327129919519382]
#   -- feasible:placement 0: grasp x place z
#      { time: 0.065125, evals: 134, done: 1, feasible: 1, sos: 0.215904, f: 0, ineq: 0.00233847, eq: 0.286784 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.044885, evals: 22, done: 1, feasible: 1, sos: 2.98437, f: 0, ineq: 2.51357e-07, eq: 0.320034 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.236935, evals: 98, done: 1, feasible: 1, sos: 0.142281, f: 0, ineq: 0, eq: 0.328114 }
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.044522, evals: 93, done: 1, feasible: 0, sos: 0.10979, f: 0, ineq: 0.0476679, eq: 0.898582 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- feasible:placement 1: grasp x place z
#      { time: 0.08317, evals: 200, done: 1, feasible: 1, sos: 0.247724, f: 0, ineq: 0.00357117, eq: 0.494581 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.05955, evals: 22, done: 1, feasible: 1, sos: 3.17012, f: 0, ineq: 1.87538e-07, eq: 0.297065 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.447901, evals: 156, done: 1, feasible: 1, sos: 0.144818, f: 0, ineq: 0, eq: 0.312251 }
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.047119, evals: 120, done: 1, feasible: 0, sos: 0.285061, f: 0, ineq: 0.0250102, eq: 0.75374 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034699, evals: 91, done: 1, feasible: 0, sos: 0.277067, f: 0, ineq: 0.0568674, eq: 1.04051 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.078949, evals: 201, done: 1, feasible: 0, sos: 0.285924, f: 0, ineq: 0.00710638, eq: 0.728204 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.036104, evals: 85, done: 1, feasible: 0, sos: 0.279853, f: 0, ineq: 0.0843905, eq: 1.08272 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.260242, evals: 200, done: 1, feasible: 0, sos: 0.575117, f: 0, ineq: 0.577467, eq: 2.64453 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.228261, evals: 201, done: 1, feasible: 0, sos: 0.575519, f: 0, ineq: 0.612664, eq: 2.59718 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.028397, evals: 80, done: 1, feasible: 0, sos: 0.284352, f: 0, ineq: 0.015226, eq: 0.742915 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.039309, evals: 107, done: 1, feasible: 0, sos: 0.274684, f: 0, ineq: 0.0661363, eq: 1.14839 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.04096, evals: 108, done: 1, feasible: 0, sos: 0.278678, f: 0, ineq: 0.0895431, eq: 1.19199 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.045951, evals: 120, done: 1, feasible: 0, sos: 0.27142, f: 0, ineq: 0.055202, eq: 1.09524 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.029715, evals: 80, done: 1, feasible: 0, sos: 0.278997, f: 0, ineq: 0.0964678, eq: 1.05723 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.051536, evals: 95, done: 1, feasible: 0, sos: 0.279418, f: 0, ineq: 0.0915556, eq: 1.201 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084007, evals: 201, done: 1, feasible: 0, sos: 0.28572, f: 0, ineq: 0.0145281, eq: 0.733115 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082538, evals: 200, done: 1, feasible: 0, sos: 0.285201, f: 0, ineq: 0.00896234, eq: 0.749411 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.038868, evals: 104, done: 1, feasible: 0, sos: 0.276604, f: 0, ineq: 0.0772727, eq: 1.20749 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.027757, evals: 77, done: 1, feasible: 0, sos: 0.285426, f: 0, ineq: 0.0190583, eq: 0.747659 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.029185, evals: 82, done: 1, feasible: 0, sos: 0.284655, f: 0, ineq: 0.0142675, eq: 0.769091 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.042893, evals: 114, done: 1, feasible: 0, sos: 0.591911, f: 0, ineq: 0.686184, eq: 2.52068 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.026839, evals: 73, done: 1, feasible: 0, sos: 0.278699, f: 0, ineq: 0.0949615, eq: 1.05423 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.045531, evals: 122, done: 1, feasible: 0, sos: 0.284561, f: 0, ineq: 0.0143659, eq: 0.73711 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.027899, evals: 77, done: 1, feasible: 0, sos: 0.277136, f: 0, ineq: 0.0805964, eq: 1.15947 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035291, evals: 88, done: 1, feasible: 0, sos: 0.274653, f: 0, ineq: 0.0669237, eq: 1.15826 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.048275, evals: 121, done: 1, feasible: 0, sos: 0.276957, f: 0, ineq: 0.0708405, eq: 1.16188 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.066174, evals: 175, done: 1, feasible: 0, sos: 0.285416, f: 0, ineq: 0.0206483, eq: 0.753812 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.032913, evals: 87, done: 1, feasible: 0, sos: 0.592452, f: 0, ineq: 0.611747, eq: 2.6715 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.038617, evals: 102, done: 1, feasible: 0, sos: 0.590758, f: 0, ineq: 0.683472, eq: 2.50529 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.034446, evals: 88, done: 1, feasible: 0, sos: 0.589905, f: 0, ineq: 0.70793, eq: 2.54761 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.076987, evals: 201, done: 1, feasible: 0, sos: 0.284877, f: 0, ineq: 0.0191157, eq: 0.772925 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.041467, evals: 106, done: 1, feasible: 0, sos: 0.276076, f: 0, ineq: 0.0820809, eq: 1.18765 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.040099, evals: 93, done: 1, feasible: 0, sos: 0.587132, f: 0, ineq: 0.691821, eq: 2.60049 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079305, evals: 200, done: 1, feasible: 0, sos: 0.528078, f: 0, ineq: 0.304148, eq: 2.4196 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079439, evals: 200, done: 1, feasible: 0, sos: 0.286603, f: 0, ineq: 0.0243757, eq: 0.736963 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.078509, evals: 85, done: 1, feasible: 0, sos: 0.276789, f: 0, ineq: 0.0698517, eq: 1.25632 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.139265, evals: 105, done: 1, feasible: 0, sos: 0.275191, f: 0, ineq: 0.0741562, eq: 1.18269 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.123786, evals: 77, done: 1, feasible: 0, sos: 0.27676, f: 0, ineq: 0.0545901, eq: 1.05596 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.145879, evals: 104, done: 1, feasible: 0, sos: 0.591311, f: 0, ineq: 0.728119, eq: 2.52686 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.279945, evals: 201, done: 1, feasible: 0, sos: 0.280556, f: 0, ineq: 0.0620463, eq: 1.05995 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.170889, evals: 96, done: 1, feasible: 0, sos: 0.275117, f: 0, ineq: 0.0748088, eq: 1.18225 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.294071, evals: 200, done: 1, feasible: 0, sos: 0.527581, f: 0, ineq: 0.297342, eq: 2.41736 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.095239, evals: 83, done: 1, feasible: 0, sos: 0.28041, f: 0, ineq: 0.0718725, eq: 1.08447 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.279572, evals: 200, done: 1, feasible: 0, sos: 0.285955, f: 0, ineq: 0.0179123, eq: 0.739221 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.139072, evals: 93, done: 1, feasible: 0, sos: 0.275085, f: 0, ineq: 0.0745272, eq: 1.1813 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.143672, evals: 99, done: 1, feasible: 0, sos: 0.277985, f: 0, ineq: 0.070327, eq: 1.08103 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.132181, evals: 156, done: 1, feasible: 0, sos: 0.528235, f: 0, ineq: 0.298811, eq: 2.43261 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.09801, evals: 100, done: 1, feasible: 0, sos: 0.277418, f: 0, ineq: 0.0596126, eq: 1.03267 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.172258, evals: 201, done: 1, feasible: 0, sos: 0.574233, f: 0, ineq: 0.632101, eq: 2.58765 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.038666, evals: 104, done: 1, feasible: 0, sos: 0.591499, f: 0, ineq: 0.665521, eq: 2.63136 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.072197, evals: 189, done: 1, feasible: 0, sos: 0.278188, f: 0, ineq: 0.0816727, eq: 1.17229 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.073531, evals: 87, done: 1, feasible: 0, sos: 0.27886, f: 0, ineq: 0.0738668, eq: 1.05738 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.277319, evals: 200, done: 1, feasible: 0, sos: 0.286682, f: 0, ineq: 0.0249229, eq: 0.740162 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.259342, evals: 200, done: 1, feasible: 0, sos: 0.287395, f: 0, ineq: 0.0258396, eq: 0.733798 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.237563, evals: 201, done: 1, feasible: 0, sos: 0.596477, f: 0, ineq: 0.586234, eq: 2.60639 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.277953, evals: 201, done: 1, feasible: 0, sos: 0.574237, f: 0, ineq: 0.634943, eq: 2.51788 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.128827, evals: 91, done: 1, feasible: 0, sos: 0.590147, f: 0, ineq: 0.659325, eq: 2.53104 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.146301, evals: 98, done: 1, feasible: 0, sos: 0.277652, f: 0, ineq: 0.0760473, eq: 1.22103 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.128913, evals: 98, done: 1, feasible: 0, sos: 0.284645, f: 0, ineq: 0.015156, eq: 0.763964 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.155761, evals: 113, done: 1, feasible: 0, sos: 0.275755, f: 0, ineq: 0.0694032, eq: 1.12377 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.12606, evals: 82, done: 1, feasible: 0, sos: 0.277666, f: 0, ineq: 0.0931519, eq: 1.24893 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.137343, evals: 93, done: 1, feasible: 0, sos: 0.580316, f: 0, ineq: 0.604186, eq: 2.5312 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.209602, evals: 155, done: 1, feasible: 0, sos: 0.279556, f: 0, ineq: 0.106696, eq: 1.08396 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084629, evals: 83, done: 1, feasible: 0, sos: 0.575237, f: 0, ineq: 0.708592, eq: 2.60316 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.129831, evals: 106, done: 1, feasible: 0, sos: 0.591706, f: 0, ineq: 0.689178, eq: 2.60113 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.062182, evals: 125, done: 1, feasible: 0, sos: 0.27614, f: 0, ineq: 0.0717789, eq: 1.1176 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.073429, evals: 174, done: 1, feasible: 0, sos: 0.285555, f: 0, ineq: 0.0143027, eq: 0.734798 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.054341, evals: 143, done: 1, feasible: 0, sos: 0.584715, f: 0, ineq: 0.713171, eq: 2.64611 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.029971, evals: 82, done: 1, feasible: 0, sos: 0.278172, f: 0, ineq: 0.0801356, eq: 1.05686 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.03464, evals: 85, done: 1, feasible: 0, sos: 0.285325, f: 0, ineq: 0.0185046, eq: 0.745232 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.038138, evals: 101, done: 1, feasible: 0, sos: 0.574032, f: 0, ineq: 0.63111, eq: 2.53519 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.059505, evals: 161, done: 1, feasible: 0, sos: 0.274791, f: 0, ineq: 0.0675185, eq: 1.1579 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.05136, evals: 136, done: 1, feasible: 0, sos: 0.583701, f: 0, ineq: 0.702694, eq: 2.46668 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.075694, evals: 201, done: 1, feasible: 0, sos: 0.286536, f: 0, ineq: 0.0230305, eq: 0.744756 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.074318, evals: 201, done: 1, feasible: 0, sos: 0.285995, f: 0, ineq: 0.0223594, eq: 0.740129 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.045372, evals: 119, done: 1, feasible: 0, sos: 0.563013, f: 0, ineq: 0.60776, eq: 2.70981 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.045897, evals: 127, done: 1, feasible: 0, sos: 0.277568, f: 0, ineq: 0.0844191, eq: 1.18822 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.035697, evals: 97, done: 1, feasible: 0, sos: 0.285082, f: 0, ineq: 0.0216061, eq: 0.749767 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.02923, evals: 80, done: 1, feasible: 0, sos: 0.276578, f: 0, ineq: 0.0874507, eq: 1.20354 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.040056, evals: 109, done: 1, feasible: 0, sos: 0.592663, f: 0, ineq: 0.721993, eq: 2.57255 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.057894, evals: 146, done: 1, feasible: 0, sos: 0.594825, f: 0, ineq: 0.653572, eq: 2.60436 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.032456, evals: 90, done: 1, feasible: 0, sos: 0.279119, f: 0, ineq: 0.0758293, eq: 1.06902 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082015, evals: 87, done: 1, feasible: 0, sos: 0.276738, f: 0, ineq: 0.0575365, eq: 1.06015 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.101531, evals: 76, done: 1, feasible: 0, sos: 0.284559, f: 0, ineq: 0.0138494, eq: 0.765862 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091634, evals: 89, done: 1, feasible: 0, sos: 0.27751, f: 0, ineq: 0.0823583, eq: 1.17546 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.124613, evals: 82, done: 1, feasible: 0, sos: 0.285437, f: 0, ineq: 0.0185013, eq: 0.742945 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083987, evals: 79, done: 1, feasible: 0, sos: 0.276316, f: 0, ineq: 0.076291, eq: 1.04974 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.113625, evals: 179, done: 1, feasible: 0, sos: 0.275117, f: 0, ineq: 0.0814664, eq: 1.09452 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.071131, evals: 76, done: 1, feasible: 0, sos: 0.27642, f: 0, ineq: 0.0765603, eq: 1.12398 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.04377, evals: 100, done: 1, feasible: 0, sos: 0.275443, f: 0, ineq: 0.0895767, eq: 1.09729 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079055, evals: 200, done: 1, feasible: 0, sos: 0.285437, f: 0, ineq: 0.017362, eq: 0.736069 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.031788, evals: 87, done: 1, feasible: 0, sos: 0.285267, f: 0, ineq: 0.0179106, eq: 0.742425 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.050086, evals: 135, done: 1, feasible: 0, sos: 0.278358, f: 0, ineq: 0.0796414, eq: 1.16398 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.032548, evals: 77, done: 1, feasible: 0, sos: 0.275045, f: 0, ineq: 0.074585, eq: 1.18645 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.124943, evals: 81, done: 1, feasible: 0, sos: 0.275865, f: 0, ineq: 0.0809412, eq: 1.19847 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.145722, evals: 94, done: 1, feasible: 0, sos: 0.278423, f: 0, ineq: 0.078687, eq: 1.07572 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.102488, evals: 83, done: 1, feasible: 0, sos: 0.291552, f: 0, ineq: 0.0133881, eq: 0.769644 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.036991, evals: 98, done: 1, feasible: 0, sos: 0.276043, f: 0, ineq: 0.0821156, eq: 1.18151 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.071285, evals: 191, done: 1, feasible: 0, sos: 0.28835, f: 0, ineq: 0.0259952, eq: 0.744655 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.036847, evals: 99, done: 1, feasible: 0, sos: 0.590051, f: 0, ineq: 0.677352, eq: 2.4727 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034064, evals: 93, done: 1, feasible: 0, sos: 0.275203, f: 0, ineq: 0.0754511, eq: 1.19176 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.172542, evals: 128, done: 1, feasible: 0, sos: 0.284817, f: 0, ineq: 0.0136668, eq: 0.752702 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.202315, evals: 104, done: 1, feasible: 0, sos: 0.567684, f: 0, ineq: 0.614696, eq: 2.66583 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.122598, evals: 101, done: 1, feasible: 0, sos: 0.590428, f: 0, ineq: 0.693571, eq: 2.59699 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.032059, evals: 87, done: 1, feasible: 0, sos: 0.284631, f: 0, ineq: 0.0143551, eq: 0.757365 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.029359, evals: 79, done: 1, feasible: 0, sos: 0.279197, f: 0, ineq: 0.0989975, eq: 1.06152 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034285, evals: 89, done: 1, feasible: 0, sos: 0.279767, f: 0, ineq: 0.0866439, eq: 1.0887 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.037549, evals: 100, done: 1, feasible: 0, sos: 0.278058, f: 0, ineq: 0.0822285, eq: 1.16557 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.069636, evals: 187, done: 1, feasible: 0, sos: 0.285638, f: 0, ineq: 0.0135938, eq: 0.742749 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034109, evals: 91, done: 1, feasible: 0, sos: 0.280294, f: 0, ineq: 0.0763058, eq: 1.12492 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.030597, evals: 82, done: 1, feasible: 0, sos: 0.274753, f: 0, ineq: 0.0672061, eq: 1.12004 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.029401, evals: 79, done: 1, feasible: 0, sos: 0.276056, f: 0, ineq: 0.0702094, eq: 1.10408 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.15399, evals: 172, done: 1, feasible: 0, sos: 0.278558, f: 0, ineq: 0.0911755, eq: 1.17469 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.106145, evals: 91, done: 1, feasible: 0, sos: 0.279167, f: 0, ineq: 0.11835, eq: 1.15347 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.197998, evals: 96, done: 1, feasible: 0, sos: 0.275534, f: 0, ineq: 0.0793175, eq: 1.20457 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.308029, evals: 151, done: 1, feasible: 0, sos: 0.284944, f: 0, ineq: 0.015321, eq: 0.7705 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.215756, evals: 102, done: 1, feasible: 0, sos: 0.275714, f: 0, ineq: 0.0811618, eq: 1.14304 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.203805, evals: 101, done: 1, feasible: 0, sos: 0.59137, f: 0, ineq: 0.661425, eq: 2.62121 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.19097, evals: 80, done: 1, feasible: 0, sos: 0.277544, f: 0, ineq: 0.0763837, eq: 1.05632 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.405626, evals: 201, done: 1, feasible: 0, sos: 0.285244, f: 0, ineq: 0.0165212, eq: 0.776252 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.236981, evals: 201, done: 1, feasible: 0, sos: 0.275515, f: 0, ineq: 0.0646266, eq: 1.16589 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.21671, evals: 118, done: 1, feasible: 0, sos: 0.593211, f: 0, ineq: 0.650824, eq: 2.65214 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.204792, evals: 99, done: 1, feasible: 0, sos: 0.277418, f: 0, ineq: 0.0808761, eq: 1.14101 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.402832, evals: 200, done: 1, feasible: 0, sos: 0.287406, f: 0, ineq: 0.0259146, eq: 0.742612 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.214353, evals: 111, done: 1, feasible: 0, sos: 0.589977, f: 0, ineq: 0.696621, eq: 2.57936 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.181189, evals: 79, done: 1, feasible: 0, sos: 0.275941, f: 0, ineq: 0.0851472, eq: 1.16316 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.20361, evals: 95, done: 1, feasible: 0, sos: 0.59121, f: 0, ineq: 0.677714, eq: 2.61424 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.188148, evals: 86, done: 1, feasible: 0, sos: 0.276777, f: 0, ineq: 0.102222, eq: 1.194 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.2226, evals: 127, done: 1, feasible: 0, sos: 0.284822, f: 0, ineq: 0.00922446, eq: 0.758369 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.178669, evals: 89, done: 1, feasible: 0, sos: 0.596907, f: 0, ineq: 0.628314, eq: 2.50741 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.378184, evals: 200, done: 1, feasible: 0, sos: 0.288356, f: 0, ineq: 0.0133261, eq: 0.719965 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.183039, evals: 98, done: 1, feasible: 0, sos: 0.589001, f: 0, ineq: 0.70808, eq: 2.57557 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.113017, evals: 108, done: 1, feasible: 0, sos: 0.279628, f: 0, ineq: 0.0822022, eq: 1.18479 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.031629, evals: 87, done: 1, feasible: 0, sos: 0.594994, f: 0, ineq: 0.647717, eq: 2.64507 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.133289, evals: 165, done: 1, feasible: 0, sos: 0.279111, f: 0, ineq: 0.0708537, eq: 1.21061 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035698, evals: 90, done: 1, feasible: 0, sos: 0.276435, f: 0, ineq: 0.056909, eq: 1.05732 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.033139, evals: 90, done: 1, feasible: 0, sos: 0.27803, f: 0, ineq: 0.071351, eq: 1.09058 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.076133, evals: 201, done: 1, feasible: 0, sos: 0.306165, f: 0, ineq: 0.100902, eq: 1.11375 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.02606, evals: 73, done: 1, feasible: 0, sos: 0.275453, f: 0, ineq: 0.0628209, eq: 1.04524 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.049357, evals: 135, done: 1, feasible: 0, sos: 0.589318, f: 0, ineq: 0.699219, eq: 2.61458 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.043822, evals: 118, done: 1, feasible: 0, sos: 0.276104, f: 0, ineq: 0.0703296, eq: 1.10318 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.028274, evals: 80, done: 1, feasible: 0, sos: 0.275373, f: 0, ineq: 0.0767929, eq: 1.19135 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.031491, evals: 88, done: 1, feasible: 0, sos: 0.278722, f: 0, ineq: 0.0870735, eq: 1.18258 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.094014, evals: 92, done: 1, feasible: 0, sos: 0.57131, f: 0, ineq: 0.625601, eq: 2.54984 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.104108, evals: 77, done: 1, feasible: 0, sos: 0.278758, f: 0, ineq: 0.0878798, eq: 1.17497 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.21901, evals: 124, done: 1, feasible: 0, sos: 0.280301, f: 0, ineq: 0.102665, eq: 1.10474 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.319361, evals: 200, done: 1, feasible: 0, sos: 0.272206, f: 0, ineq: 0.0552931, eq: 1.09054 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.137486, evals: 97, done: 1, feasible: 0, sos: 0.27491, f: 0, ineq: 0.0704426, eq: 1.16732 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.151116, evals: 95, done: 1, feasible: 0, sos: 0.285447, f: 0, ineq: 0.0117507, eq: 0.727239 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.314527, evals: 200, done: 1, feasible: 0, sos: 0.284994, f: 0, ineq: 0.0148155, eq: 0.737433 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.161743, evals: 83, done: 1, feasible: 0, sos: 0.27442, f: 0, ineq: 0.0634902, eq: 1.15571 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.194204, evals: 93, done: 1, feasible: 0, sos: 0.596562, f: 0, ineq: 0.631379, eq: 2.58278 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.209562, evals: 97, done: 1, feasible: 0, sos: 0.284628, f: 0, ineq: 0.0146701, eq: 0.76051 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.105501, evals: 76, done: 1, feasible: 0, sos: 0.275371, f: 0, ineq: 0.0769825, eq: 1.19582 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.253307, evals: 200, done: 1, feasible: 0, sos: 0.285947, f: 0, ineq: 0.0180376, eq: 0.738833 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
# ...
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.041956, evals: 103, done: 1, feasible: 0, sos: 0.588821, f: 0, ineq: 0.73314, eq: 2.54458 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.040501, evals: 92, done: 1, feasible: 0, sos: 0.591093, f: 0, ineq: 0.681458, eq: 2.57247 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.055914, evals: 136, done: 1, feasible: 0, sos: 0.275035, f: 0, ineq: 0.0572525, eq: 1.04424 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.04705, evals: 119, done: 1, feasible: 0, sos: 0.59319, f: 0, ineq: 0.651634, eq: 2.64244 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.06104, evals: 158, done: 1, feasible: 0, sos: 0.280212, f: 0, ineq: 0.0776606, eq: 1.07699 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.062765, evals: 165, done: 1, feasible: 0, sos: 0.585223, f: 0, ineq: 0.727634, eq: 2.69582 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.037213, evals: 95, done: 1, feasible: 0, sos: 0.566042, f: 0, ineq: 0.582353, eq: 2.70771 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.076592, evals: 201, done: 1, feasible: 0, sos: 0.2859, f: 0, ineq: 0.0129763, eq: 0.739161 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.047129, evals: 126, done: 1, feasible: 0, sos: 0.275916, f: 0, ineq: 0.073988, eq: 1.14499 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.032325, evals: 80, done: 1, feasible: 0, sos: 0.27661, f: 0, ineq: 0.0678371, eq: 1.25046 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.031804, evals: 81, done: 1, feasible: 0, sos: 0.277256, f: 0, ineq: 0.0801865, eq: 1.1598 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.041616, evals: 104, done: 1, feasible: 0, sos: 0.275874, f: 0, ineq: 0.0795892, eq: 1.20165 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.04555, evals: 95, done: 1, feasible: 0, sos: 0.592313, f: 0, ineq: 0.694812, eq: 2.51196 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.041044, evals: 88, done: 1, feasible: 0, sos: 0.284841, f: 0, ineq: 0.0146377, eq: 0.73737 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035843, evals: 87, done: 1, feasible: 0, sos: 0.276914, f: 0, ineq: 0.0883484, eq: 1.19257 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079705, evals: 201, done: 1, feasible: 0, sos: 0.284965, f: 0, ineq: 0.0170103, eq: 0.759401 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.033102, evals: 86, done: 1, feasible: 0, sos: 0.275306, f: 0, ineq: 0.0752508, eq: 1.18514 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.02852, evals: 76, done: 1, feasible: 0, sos: 0.285437, f: 0, ineq: 0.0186924, eq: 0.744789 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.070675, evals: 179, done: 1, feasible: 0, sos: 0.278866, f: 0, ineq: 0.0891271, eq: 1.07815 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035162, evals: 89, done: 1, feasible: 0, sos: 0.274805, f: 0, ineq: 0.0679098, eq: 1.15629 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.032776, evals: 87, done: 1, feasible: 0, sos: 0.285378, f: 0, ineq: 0.0182277, eq: 0.742715 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.039756, evals: 92, done: 1, feasible: 0, sos: 0.579123, f: 0, ineq: 0.594652, eq: 2.54398 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.046358, evals: 117, done: 1, feasible: 0, sos: 0.590415, f: 0, ineq: 0.666513, eq: 2.6771 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.039078, evals: 100, done: 1, feasible: 0, sos: 0.280068, f: 0, ineq: 0.0670257, eq: 1.09549 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.036652, evals: 93, done: 1, feasible: 0, sos: 0.274379, f: 0, ineq: 0.0745348, eq: 1.21973 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.039687, evals: 86, done: 1, feasible: 0, sos: 0.278735, f: 0, ineq: 0.0912767, eq: 1.0627 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.059512, evals: 127, done: 1, feasible: 0, sos: 0.284773, f: 0, ineq: 0.0167116, eq: 0.746707 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079036, evals: 200, done: 1, feasible: 0, sos: 0.285306, f: 0, ineq: 0.0154564, eq: 0.765129 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.045227, evals: 109, done: 1, feasible: 0, sos: 0.585772, f: 0, ineq: 0.71594, eq: 2.53142 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.033358, evals: 86, done: 1, feasible: 0, sos: 0.285264, f: 0, ineq: 0.0180531, eq: 0.743822 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.043056, evals: 112, done: 1, feasible: 0, sos: 0.276856, f: 0, ineq: 0.0871099, eq: 1.20174 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082913, evals: 200, done: 1, feasible: 0, sos: 0.285221, f: 0, ineq: 0.0142623, eq: 0.760337 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.034693, evals: 82, done: 1, feasible: 0, sos: 0.285382, f: 0, ineq: 0.0188685, eq: 0.747345 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.048172, evals: 126, done: 1, feasible: 0, sos: 0.277293, f: 0, ineq: 0.0613556, eq: 1.09154 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.029327, evals: 79, done: 1, feasible: 0, sos: 0.285415, f: 0, ineq: 0.0188954, eq: 0.746729 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.034968, evals: 93, done: 1, feasible: 0, sos: 0.284579, f: 0, ineq: 0.0115768, eq: 0.734404 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.041218, evals: 110, done: 1, feasible: 0, sos: 0.275021, f: 0, ineq: 0.0703371, eq: 1.16356 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.040699, evals: 108, done: 1, feasible: 0, sos: 0.589232, f: 0, ineq: 0.662009, eq: 2.52107 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.045662, evals: 119, done: 1, feasible: 0, sos: 0.275874, f: 0, ineq: 0.0808219, eq: 1.20175 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.034111, evals: 90, done: 1, feasible: 0, sos: 0.596886, f: 0, ineq: 0.616562, eq: 2.5341 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.042821, evals: 114, done: 1, feasible: 0, sos: 0.276328, f: 0, ineq: 0.0739291, eq: 1.12219 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035179, evals: 92, done: 1, feasible: 0, sos: 0.276486, f: 0, ineq: 0.0566685, eq: 1.05654 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.035487, evals: 83, done: 1, feasible: 0, sos: 0.277862, f: 0, ineq: 0.0848278, eq: 1.07746 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.034104, evals: 89, done: 1, feasible: 0, sos: 0.597557, f: 0, ineq: 0.622435, eq: 2.53691 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.040749, evals: 107, done: 1, feasible: 0, sos: 0.592802, f: 0, ineq: 0.663917, eq: 2.5817 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.070876, evals: 186, done: 1, feasible: 0, sos: 0.528316, f: 0, ineq: 0.301408, eq: 2.41678 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.03777, evals: 103, done: 1, feasible: 0, sos: 0.278388, f: 0, ineq: 0.0818645, eq: 1.17401 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.062699, evals: 165, done: 1, feasible: 0, sos: 0.275295, f: 0, ineq: 0.0667049, eq: 1.11744 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.030745, evals: 85, done: 1, feasible: 0, sos: 0.274207, f: 0, ineq: 0.058589, eq: 1.05345 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box3)
# Grasp Direction: x
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 99
#      96     M.target_relative_xy_position(2.0, box, table, initial_pos)
#      97     M.keep_dist_pairwise([], keep_dist_between, margin=0.08)
# ---> 99 ways = M.solve()
#     101 if not M.feasible:
#     102     print(
#     103         f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
#     104     )
#
# File ~/Desktop/SHK_LIS/manipulationAbstraction/manipulation.py:478, in ManipulationModelling.solve(self, verbose)
#     476 sol.setProblem(self.komo.nlp())
#     477 sol.setOptions(damping=1e-3, verbose=verbose-1, stopTolerance=1e-3, maxLambda=100., stopEvals=200)
# --> 478 self.ret = sol.solve()
#     479 if self.ret.feasible:
#     480     self.path = self.komo.getPath()
#
# KeyboardInterrupt:

# %% [markdown]
# ### On real robot: BotOp

# %%
import robotic as ry
import numpy as np
from bridgebuild_env import create_n_boxes
import robot_execution as robex
# this import the local manipulation.py .. to be integrated in robotic..
import manipulation as manip
import random
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
C = ry.Config()
C.addFile(ry.raiPath("scenarios/pandaSingle.g"))
n_boxes = 3
keep_dist_between = ["box1", "box2", "box3"]
C = create_n_boxes(C=C, N=n_boxes, position="fixed")

# remove so collision with wrist camera is ignored
C.delFrame("panda_collCameraWrist")

# for convenience, a few definitions:
qHome = C.getJointState()
gripper = "l_gripper"
palm = "l_palm"
box1 = "box1"
box2 = "box2"
box3 = "box3"
table = "table"
boxSize = C.frame(box1).getSize()

C.view()
# Out:
# 0

# %%
C.view()
bot = robex.Robot(C, on_real=True)
bot.goHome(C)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
C.setJointState(qHome)
C.view_raise()
boxes_pos = [
    C.frame(box1).getPosition(),
    C.frame(box2).getPosition(),
    C.frame(box3).getPosition(),
]
boxes = [box1, box2, box3]
last_box_memory = []
paths = []
vis = 1
n_success = 0
boxz = [box1, box3, box2]
while n_success <= 2:
    box = np.random.choice(boxes)
    qStart = C.getJointState()
    graspDirection = random.choice(["x", "y"])  # z grasp removed
    placeDirection = "z"  # random.choice(['x', 'y', 'z', 'xNeg', 'yNeg', 'zNeg'])
    info = f"placement {n_success}: grasp {graspDirection} place {placeDirection}"
    print("===", info)

    M = manip.ManipulationModelling(C, info, helpers=[gripper])
    M.setup_pick_and_place_waypoints(
        gripper, box, homing_scale=1.8e-1, accumulated_collisions=True
    )
    M.grasp_box(1.0, gripper, box, palm, graspDirection)
    print("place direction:", placeDirection)

    if n_success > 1:
        print(f"3rd Block: ({box})")
        dir_vec = (
            C.getFrame(last_box_memory[-2]).getPosition()
            - C.getFrame(last_box_memory[-1]).getPosition()
        )
        pos2 = C.getFrame(last_box_memory[-2]).getPosition()
        pos1 = C.getFrame(last_box_memory[-1]).getPosition()
        rel_pos = (pos1 + pos2) / 2 + np.array([0, 0, 0.08])
        dir_vec /= np.linalg.norm(dir_vec)

        M.komo.addObjective([2.0], ry.FS.position, [box], ry.OT.eq, [1e1], rel_pos)
        M.komo.addObjective([2.0], ry.FS.vectorZ, [box], ry.OT.eq, [1e1], dir_vec)
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

        print("Grasp Direction:", graspDirection)
        # M.komo.addObjective([2.], ry.FS.vectorZ, [gripper], ry.OT.eq, [1e1], [0, 0, 1])

        if graspDirection == "x":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductXZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )
        elif graspDirection == "y":
            M.komo.addObjective(
                [2.0], ry.FS.scalarProductYZ, [box, table], ry.OT.eq, [1e1], [0.0]
            )

    if n_success == 1:
        print(f"2nd Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        M.komo.addObjective(
            [2.0],
            ry.FS.negDistance,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [-0.04],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.scalarProductXY,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1e1],
            [0],
        )
        M.komo.addObjective(
            [2.0],
            ry.FS.positionRel,
            [box, last_box_memory[-1]],
            ry.OT.eq,
            [1.0],
            [0.0, 0.0, 0.1],
        )
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    M.keep_distance([], palm, table)
    # keep distance between boxes when placed defined by margin
    # x, y, z, smooth - table size: array([2.5 , 2.5 , 0.1 , 0.02])
    # place inital block as chosen by np.random.choice at a random location
    if n_success == 0:
        print(f"1st Block: ({box})")
        M.place_box(2.0, box, table, palm, placeDirection)
        initial_pos = [np.random.uniform(0.0, 0.1), np.random.uniform(0.0, 0.1)]
        # initial_pos= [0.020433060890705013, 0.08433819136314634]
        print("Trying xy pos: ", initial_pos)
        M.target_relative_xy_position(2.0, box, table, initial_pos)
        #M.keep_dist_pairwise([], keep_dist_between, margin=0.08)

    ways = M.solve()

    if not M.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M :("
        )
        continue
    print("Submotion 0")
    M2 = M.sub_motion(0)

    M2.keep_distance([0.3, 0.7], palm, box)

    M2.retract([0.0, 0.2], gripper, dist=0.15)
    M2.approach([0.8, 1.0], gripper)
    paths.append(M2.solve())

    if not M2.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M2 :("
        )
        continue

    M3 = M.sub_motion(1)

    M3.keep_distance([], table, box)

    if n_success > 1:
        M3.retract([0.0, 0.2], gripper, dist=0.15)
        M3.approach([0.8, 1.0], gripper)

    paths.append(M3.solve())
    if not M3.ret.feasible:
        print(
            f"Failed placing block number {n_success+1} with grasp direction {graspDirection} at M3 :("
        )
        continue

    bot.execute_path_blocking(C, path=paths[-2])
    C.attach(gripper, box)
    bot.grasp(C)

    bot.execute_path_blocking(C, path=paths[-1])
    C.attach(table, box)
    bot.release(C)
    # update memory
    last_box_memory.append(box)
    # remove box that was previously used
    boxes.remove(box)
    # update positions
    boxes_pos = [
        C.frame(box1).getPosition(),
        C.frame(box2).getPosition(),
        C.frame(box3).getPosition(),
    ]
    n_success += 1

del M
# Out:
# === placement 0: grasp x place z
# place direction: z
# 1st Block: (box2)
# Trying xy pos:  [0.05081675454154131, 0.0009059812097997]
#   -- feasible:placement 0: grasp x place z
#      { time: 0.051205, evals: 111, done: 1, feasible: 1, sos: 0.207519, f: 0, ineq: 0.0132057, eq: 0.393276 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 0: grasp x place z
#      { time: 0.037942, evals: 21, done: 1, feasible: 1, sos: 3.61862, f: 0, ineq: 1.49874e-07, eq: 0.322577 }
#   -- feasible:sub_motion_1--placement 0: grasp x place z
#      { time: 0.428904, evals: 179, done: 1, feasible: 1, sos: 0.188491, f: 0, ineq: 0, eq: 0.342142 }
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.094855, evals: 200, done: 1, feasible: 0, sos: 0.315035, f: 0, ineq: 0.0837747, eq: 0.680344 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.025669, evals: 55, done: 1, feasible: 0, sos: 0.115449, f: 0, ineq: 0.0467605, eq: 0.833847 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.047339, evals: 103, done: 1, feasible: 0, sos: 0.209608, f: 0, ineq: 0.0131672, eq: 0.636986 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.092935, evals: 200, done: 1, feasible: 0, sos: 0.13333, f: 0, ineq: 0.0339976, eq: 0.814922 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.091873, evals: 201, done: 1, feasible: 0, sos: 0.209153, f: 0, ineq: 0.0132872, eq: 0.63863 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.034465, evals: 68, done: 1, feasible: 0, sos: 0.399125, f: 0, ineq: 0.0736867, eq: 0.914601 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.028448, evals: 54, done: 1, feasible: 0, sos: 0.367484, f: 0, ineq: 0.364891, eq: 1.35696 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.078371, evals: 166, done: 1, feasible: 0, sos: 0.123022, f: 0, ineq: 0.0463004, eq: 0.793185 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.101517, evals: 200, done: 1, feasible: 0, sos: 0.374631, f: 0, ineq: 0.357536, eq: 1.42343 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.096701, evals: 200, done: 1, feasible: 0, sos: 0.310551, f: 0, ineq: 0.0794879, eq: 0.641042 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.05854, evals: 128, done: 1, feasible: 0, sos: 0.209235, f: 0, ineq: 0.0152486, eq: 0.636912 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.093882, evals: 201, done: 1, feasible: 0, sos: 0.207987, f: 0, ineq: 0.0162947, eq: 0.658145 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.027404, evals: 58, done: 1, feasible: 0, sos: 0.204433, f: 0, ineq: 0.0163354, eq: 0.687157 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.039931, evals: 64, done: 1, feasible: 0, sos: 0.204177, f: 0, ineq: 0.0285183, eq: 0.696825 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.107569, evals: 201, done: 1, feasible: 0, sos: 0.376912, f: 0, ineq: 0.316484, eq: 1.4195 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.053841, evals: 111, done: 1, feasible: 0, sos: 0.403212, f: 0, ineq: 0.0438338, eq: 0.872772 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.034172, evals: 75, done: 1, feasible: 0, sos: 0.204451, f: 0, ineq: 0.0163229, eq: 0.686796 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box3)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.033697, evals: 71, done: 1, feasible: 0, sos: 0.118451, f: 0, ineq: 0.0593186, eq: 0.821471 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.028848, evals: 51, done: 1, feasible: 0, sos: 0.132194, f: 0, ineq: 0.0320506, eq: 0.789368 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp x place z
#      { time: 0.023073, evals: 50, done: 1, feasible: 0, sos: 0.185103, f: 0, ineq: 0.0370004, eq: 2.59286 }
# Failed placing block number 2 with grasp direction x at M :(
# === placement 1: grasp y place z
# place direction: z
# 2nd Block: (box1)
#   -- infeasible:placement 1: grasp y place z
#      { time: 0.039877, evals: 86, done: 1, feasible: 0, sos: 0.131927, f: 0, ineq: 0.0299574, eq: 0.790559 }
# Failed placing block number 2 with grasp direction y at M :(
# === placement 1: grasp x place z
# place direction: z
# 2nd Block: (box3)
#   -- feasible:placement 1: grasp x place z
#      { time: 0.070613, evals: 156, done: 1, feasible: 1, sos: 0.155145, f: 0, ineq: 0.00442791, eq: 0.494375 }
# Submotion 0
#   -- feasible:sub_motion_0--placement 1: grasp x place z
#      { time: 0.15281, evals: 69, done: 1, feasible: 1, sos: 2.21759, f: 0, ineq: 0.00186562, eq: 0.300001 }
#   -- feasible:sub_motion_1--placement 1: grasp x place z
#      { time: 0.022369, evals: 9, done: 1, feasible: 1, sos: 0.0278154, f: 0, ineq: 0.0104236, eq: 0.297562 }
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085576, evals: 201, done: 1, feasible: 0, sos: 0.312166, f: 0, ineq: 0.0261359, eq: 1.17133 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084572, evals: 201, done: 1, feasible: 0, sos: 0.310939, f: 0, ineq: 0.0282002, eq: 1.16728 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08394, evals: 201, done: 1, feasible: 0, sos: 0.312146, f: 0, ineq: 0.0303314, eq: 1.16144 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082621, evals: 201, done: 1, feasible: 0, sos: 0.473981, f: 0, ineq: 0.0360016, eq: 0.593509 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082741, evals: 200, done: 1, feasible: 0, sos: 0.311364, f: 0, ineq: 0.0265937, eq: 1.17031 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083877, evals: 200, done: 1, feasible: 0, sos: 0.310647, f: 0, ineq: 0.0290832, eq: 1.16698 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079483, evals: 196, done: 1, feasible: 0, sos: 0.475987, f: 0, ineq: 0.0364099, eq: 0.584681 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08275, evals: 200, done: 1, feasible: 0, sos: 0.312718, f: 0, ineq: 0.0224341, eq: 1.18395 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084579, evals: 200, done: 1, feasible: 0, sos: 0.416635, f: 0, ineq: 0.030393, eq: 1.14119 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083243, evals: 200, done: 1, feasible: 0, sos: 0.313709, f: 0, ineq: 0.0314357, eq: 1.22037 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.055961, evals: 138, done: 1, feasible: 0, sos: 0.398839, f: 0, ineq: 0.0533043, eq: 1.16081 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.073974, evals: 182, done: 1, feasible: 0, sos: 0.474698, f: 0, ineq: 0.0276107, eq: 0.600282 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.046749, evals: 113, done: 1, feasible: 0, sos: 0.310308, f: 0, ineq: 0.0360894, eq: 1.16316 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084572, evals: 200, done: 1, feasible: 0, sos: 0.311437, f: 0, ineq: 0.0281138, eq: 1.17504 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085302, evals: 201, done: 1, feasible: 0, sos: 0.310908, f: 0, ineq: 0.0328741, eq: 1.16986 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085269, evals: 200, done: 1, feasible: 0, sos: 0.416135, f: 0, ineq: 0.0318316, eq: 1.14656 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08477, evals: 201, done: 1, feasible: 0, sos: 0.41661, f: 0, ineq: 0.0312913, eq: 1.14218 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083357, evals: 200, done: 1, feasible: 0, sos: 0.3114, f: 0, ineq: 0.0262434, eq: 1.16922 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.086285, evals: 201, done: 1, feasible: 0, sos: 0.313432, f: 0, ineq: 0.025906, eq: 1.15609 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083326, evals: 201, done: 1, feasible: 0, sos: 0.424444, f: 0, ineq: 0.0612384, eq: 0.798606 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.028374, evals: 68, done: 1, feasible: 0, sos: 0.310718, f: 0, ineq: 0.0232588, eq: 1.16173 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083329, evals: 201, done: 1, feasible: 0, sos: 0.312242, f: 0, ineq: 0.0327759, eq: 1.15907 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084497, evals: 201, done: 1, feasible: 0, sos: 0.474321, f: 0, ineq: 0.0369417, eq: 0.589909 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.045796, evals: 109, done: 1, feasible: 0, sos: 0.310529, f: 0, ineq: 0.0277956, eq: 1.16084 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084321, evals: 200, done: 1, feasible: 0, sos: 0.311378, f: 0, ineq: 0.0293521, eq: 1.17081 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082272, evals: 201, done: 1, feasible: 0, sos: 0.311264, f: 0, ineq: 0.0285763, eq: 1.17299 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08357, evals: 200, done: 1, feasible: 0, sos: 0.310987, f: 0, ineq: 0.0284799, eq: 1.17088 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083228, evals: 200, done: 1, feasible: 0, sos: 0.311451, f: 0, ineq: 0.0274781, eq: 1.157 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082953, evals: 201, done: 1, feasible: 0, sos: 0.312892, f: 0, ineq: 0.0265981, eq: 1.17052 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082989, evals: 200, done: 1, feasible: 0, sos: 0.310964, f: 0, ineq: 0.0280659, eq: 1.15815 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.069616, evals: 170, done: 1, feasible: 0, sos: 0.473202, f: 0, ineq: 0.0344446, eq: 0.601699 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082953, evals: 200, done: 1, feasible: 0, sos: 0.31222, f: 0, ineq: 0.0261446, eq: 1.16925 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085121, evals: 200, done: 1, feasible: 0, sos: 0.415727, f: 0, ineq: 0.0323758, eq: 1.14676 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081217, evals: 200, done: 1, feasible: 0, sos: 0.472738, f: 0, ineq: 0.034596, eq: 0.58698 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08226, evals: 200, done: 1, feasible: 0, sos: 0.312662, f: 0, ineq: 0.0230087, eq: 1.16621 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083479, evals: 200, done: 1, feasible: 0, sos: 0.310635, f: 0, ineq: 0.0369551, eq: 1.1601 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082628, evals: 201, done: 1, feasible: 0, sos: 0.474156, f: 0, ineq: 0.0283763, eq: 0.600091 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.023395, evals: 56, done: 1, feasible: 0, sos: 0.304642, f: 0, ineq: 0.0150305, eq: 3.63362 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082971, evals: 200, done: 1, feasible: 0, sos: 0.312472, f: 0, ineq: 0.0235524, eq: 1.19323 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086363, evals: 201, done: 1, feasible: 0, sos: 0.417637, f: 0, ineq: 0.031349, eq: 1.13747 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085506, evals: 200, done: 1, feasible: 0, sos: 0.419084, f: 0, ineq: 0.0304297, eq: 1.13109 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.073889, evals: 183, done: 1, feasible: 0, sos: 0.470672, f: 0, ineq: 0.0329867, eq: 0.596491 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080995, evals: 200, done: 1, feasible: 0, sos: 0.473603, f: 0, ineq: 0.0331836, eq: 0.621303 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085815, evals: 201, done: 1, feasible: 0, sos: 0.313528, f: 0, ineq: 0.0250725, eq: 1.14099 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.067299, evals: 165, done: 1, feasible: 0, sos: 0.475045, f: 0, ineq: 0.0353123, eq: 0.600442 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080428, evals: 200, done: 1, feasible: 0, sos: 0.396507, f: 0, ineq: 0.0448706, eq: 1.18383 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.070087, evals: 171, done: 1, feasible: 0, sos: 0.473504, f: 0, ineq: 0.0346571, eq: 0.597124 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.074128, evals: 183, done: 1, feasible: 0, sos: 0.474314, f: 0, ineq: 0.0360413, eq: 0.595011 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080843, evals: 200, done: 1, feasible: 0, sos: 0.474463, f: 0, ineq: 0.0365662, eq: 0.590002 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083218, evals: 200, done: 1, feasible: 0, sos: 0.3107, f: 0, ineq: 0.0312105, eq: 1.16596 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080638, evals: 200, done: 1, feasible: 0, sos: 0.474715, f: 0, ineq: 0.0363787, eq: 0.591852 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084228, evals: 201, done: 1, feasible: 0, sos: 0.416743, f: 0, ineq: 0.0317432, eq: 1.14155 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083222, evals: 200, done: 1, feasible: 0, sos: 0.312479, f: 0, ineq: 0.0266513, eq: 1.17985 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.064566, evals: 155, done: 1, feasible: 0, sos: 0.474003, f: 0, ineq: 0.0365867, eq: 0.591546 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080547, evals: 201, done: 1, feasible: 0, sos: 0.395759, f: 0, ineq: 0.0476183, eq: 1.19331 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081281, evals: 201, done: 1, feasible: 0, sos: 0.474073, f: 0, ineq: 0.0364266, eq: 0.596738 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084735, evals: 201, done: 1, feasible: 0, sos: 0.417107, f: 0, ineq: 0.0302186, eq: 1.13997 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080827, evals: 197, done: 1, feasible: 0, sos: 0.472269, f: 0, ineq: 0.0370159, eq: 0.590139 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.034542, evals: 83, done: 1, feasible: 0, sos: 0.311763, f: 0, ineq: 0.0244732, eq: 1.21029 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083806, evals: 200, done: 1, feasible: 0, sos: 0.311149, f: 0, ineq: 0.0246158, eq: 1.16762 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084951, evals: 200, done: 1, feasible: 0, sos: 0.312793, f: 0, ineq: 0.0230882, eq: 1.15988 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083469, evals: 201, done: 1, feasible: 0, sos: 0.310328, f: 0, ineq: 0.0394787, eq: 1.18985 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088201, evals: 201, done: 1, feasible: 0, sos: 0.31186, f: 0, ineq: 0.0276976, eq: 1.15174 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087418, evals: 200, done: 1, feasible: 0, sos: 0.417606, f: 0, ineq: 0.0326785, eq: 1.14222 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085764, evals: 200, done: 1, feasible: 0, sos: 0.311487, f: 0, ineq: 0.0294702, eq: 1.16987 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084436, evals: 201, done: 1, feasible: 0, sos: 0.311521, f: 0, ineq: 0.0320058, eq: 1.17262 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.056465, evals: 137, done: 1, feasible: 0, sos: 0.399422, f: 0, ineq: 0.0492133, eq: 1.16416 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.065293, evals: 159, done: 1, feasible: 0, sos: 0.472294, f: 0, ineq: 0.0355693, eq: 0.611551 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083257, evals: 201, done: 1, feasible: 0, sos: 0.312247, f: 0, ineq: 0.0274881, eq: 1.18267 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083193, evals: 201, done: 1, feasible: 0, sos: 0.311644, f: 0, ineq: 0.0287371, eq: 1.16009 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083021, evals: 200, done: 1, feasible: 0, sos: 0.310795, f: 0, ineq: 0.0282178, eq: 1.179 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084743, evals: 201, done: 1, feasible: 0, sos: 0.311155, f: 0, ineq: 0.0273614, eq: 1.16894 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083477, evals: 200, done: 1, feasible: 0, sos: 0.313479, f: 0, ineq: 0.0291245, eq: 1.20728 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083458, evals: 200, done: 1, feasible: 0, sos: 0.311218, f: 0, ineq: 0.0424951, eq: 1.14945 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083962, evals: 201, done: 1, feasible: 0, sos: 0.311708, f: 0, ineq: 0.0244467, eq: 1.18323 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080941, evals: 200, done: 1, feasible: 0, sos: 0.398444, f: 0, ineq: 0.0581241, eq: 1.17508 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083303, evals: 201, done: 1, feasible: 0, sos: 0.471967, f: 0, ineq: 0.0344023, eq: 0.600501 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.014965, evals: 34, done: 1, feasible: 0, sos: 0.326883, f: 0, ineq: 0.0893003, eq: 3.2596 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.043512, evals: 104, done: 1, feasible: 0, sos: 0.311778, f: 0, ineq: 0.0227577, eq: 1.20033 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083311, evals: 200, done: 1, feasible: 0, sos: 0.311796, f: 0, ineq: 0.0253105, eq: 1.17729 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085383, evals: 200, done: 1, feasible: 0, sos: 0.41779, f: 0, ineq: 0.0308182, eq: 1.13607 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08437, evals: 201, done: 1, feasible: 0, sos: 0.311337, f: 0, ineq: 0.0252926, eq: 1.17535 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085497, evals: 201, done: 1, feasible: 0, sos: 0.415736, f: 0, ineq: 0.0312988, eq: 1.14773 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083817, evals: 200, done: 1, feasible: 0, sos: 0.311918, f: 0, ineq: 0.0358795, eq: 1.15327 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.066841, evals: 164, done: 1, feasible: 0, sos: 0.475341, f: 0, ineq: 0.0211998, eq: 0.594518 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084729, evals: 200, done: 1, feasible: 0, sos: 0.312063, f: 0, ineq: 0.0341649, eq: 1.15537 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085797, evals: 201, done: 1, feasible: 0, sos: 0.415463, f: 0, ineq: 0.0336327, eq: 1.1485 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081664, evals: 200, done: 1, feasible: 0, sos: 0.473054, f: 0, ineq: 0.0367987, eq: 0.599382 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.069761, evals: 170, done: 1, feasible: 0, sos: 0.474319, f: 0, ineq: 0.0371333, eq: 0.58923 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084107, evals: 201, done: 1, feasible: 0, sos: 0.313517, f: 0, ineq: 0.0228568, eq: 1.17519 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083731, evals: 200, done: 1, feasible: 0, sos: 0.311669, f: 0, ineq: 0.0299396, eq: 1.15951 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084107, evals: 201, done: 1, feasible: 0, sos: 0.310649, f: 0, ineq: 0.0350489, eq: 1.16432 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.030284, evals: 73, done: 1, feasible: 0, sos: 0.310963, f: 0, ineq: 0.0321013, eq: 1.18435 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081753, evals: 200, done: 1, feasible: 0, sos: 0.395603, f: 0, ineq: 0.0506124, eq: 1.19557 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.0677, evals: 166, done: 1, feasible: 0, sos: 0.473703, f: 0, ineq: 0.0343024, eq: 0.604673 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.060909, evals: 147, done: 1, feasible: 0, sos: 0.47415, f: 0, ineq: 0.0351956, eq: 0.584185 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081861, evals: 201, done: 1, feasible: 0, sos: 0.47526, f: 0, ineq: 0.0358852, eq: 0.601767 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.072592, evals: 175, done: 1, feasible: 0, sos: 0.473725, f: 0, ineq: 0.0348836, eq: 0.605415 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081914, evals: 201, done: 1, feasible: 0, sos: 0.475273, f: 0, ineq: 0.0342387, eq: 0.586503 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085353, evals: 200, done: 1, feasible: 0, sos: 0.416703, f: 0, ineq: 0.0335744, eq: 1.14417 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.066165, evals: 159, done: 1, feasible: 0, sos: 0.310993, f: 0, ineq: 0.0272941, eq: 1.1776 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084349, evals: 201, done: 1, feasible: 0, sos: 0.31194, f: 0, ineq: 0.0282957, eq: 1.16371 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08305, evals: 200, done: 1, feasible: 0, sos: 0.310856, f: 0, ineq: 0.051109, eq: 1.26882 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.077635, evals: 189, done: 1, feasible: 0, sos: 0.474068, f: 0, ineq: 0.0355307, eq: 0.589024 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085807, evals: 200, done: 1, feasible: 0, sos: 0.413909, f: 0, ineq: 0.0371995, eq: 1.15792 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085959, evals: 201, done: 1, feasible: 0, sos: 0.47144, f: 0, ineq: 0.0288104, eq: 0.602461 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085686, evals: 200, done: 1, feasible: 0, sos: 0.417047, f: 0, ineq: 0.0316691, eq: 1.14102 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082896, evals: 200, done: 1, feasible: 0, sos: 0.312322, f: 0, ineq: 0.02779, eq: 1.16102 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086278, evals: 200, done: 1, feasible: 0, sos: 0.414771, f: 0, ineq: 0.0335811, eq: 1.15269 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083771, evals: 201, done: 1, feasible: 0, sos: 0.311422, f: 0, ineq: 0.0318098, eq: 1.17421 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083947, evals: 201, done: 1, feasible: 0, sos: 0.312134, f: 0, ineq: 0.0290827, eq: 1.16161 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.029798, evals: 71, done: 1, feasible: 0, sos: 0.308901, f: 0, ineq: 0.0412557, eq: 1.19553 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083425, evals: 200, done: 1, feasible: 0, sos: 0.312271, f: 0, ineq: 0.0286954, eq: 1.17102 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083939, evals: 200, done: 1, feasible: 0, sos: 0.311234, f: 0, ineq: 0.0333435, eq: 1.16028 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.089693, evals: 200, done: 1, feasible: 0, sos: 0.310962, f: 0, ineq: 0.0257822, eq: 1.16572 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087441, evals: 201, done: 1, feasible: 0, sos: 0.416134, f: 0, ineq: 0.0321919, eq: 1.14516 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.09201, evals: 200, done: 1, feasible: 0, sos: 0.4232, f: 0, ineq: 0.291539, eq: 3.66578 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08511, evals: 200, done: 1, feasible: 0, sos: 0.311498, f: 0, ineq: 0.0240956, eq: 1.17539 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085878, evals: 200, done: 1, feasible: 0, sos: 0.416231, f: 0, ineq: 0.0314594, eq: 1.14564 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.047885, evals: 113, done: 1, feasible: 0, sos: 0.311017, f: 0, ineq: 0.0213045, eq: 1.16993 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083415, evals: 200, done: 1, feasible: 0, sos: 0.311168, f: 0, ineq: 0.0312938, eq: 1.17116 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082875, evals: 200, done: 1, feasible: 0, sos: 0.310666, f: 0, ineq: 0.0256422, eq: 1.16891 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084672, evals: 201, done: 1, feasible: 0, sos: 0.311994, f: 0, ineq: 0.0359716, eq: 1.15105 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082368, evals: 201, done: 1, feasible: 0, sos: 0.472897, f: 0, ineq: 0.0370484, eq: 0.597412 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.073051, evals: 177, done: 1, feasible: 0, sos: 0.469907, f: 0, ineq: 0.0358685, eq: 0.605747 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.04311, evals: 103, done: 1, feasible: 0, sos: 0.313838, f: 0, ineq: 0.0278029, eq: 1.14686 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086549, evals: 201, done: 1, feasible: 0, sos: 0.416932, f: 0, ineq: 0.0322882, eq: 1.14165 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.078568, evals: 190, done: 1, feasible: 0, sos: 0.473544, f: 0, ineq: 0.036996, eq: 0.592329 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083856, evals: 200, done: 1, feasible: 0, sos: 0.310788, f: 0, ineq: 0.0262976, eq: 1.15913 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086348, evals: 201, done: 1, feasible: 0, sos: 0.415711, f: 0, ineq: 0.0329016, eq: 1.14683 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085524, evals: 201, done: 1, feasible: 0, sos: 0.417576, f: 0, ineq: 0.0290103, eq: 1.13929 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.082023, evals: 201, done: 1, feasible: 0, sos: 0.472682, f: 0, ineq: 0.0347623, eq: 0.60831 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084187, evals: 201, done: 1, feasible: 0, sos: 0.311923, f: 0, ineq: 0.0379021, eq: 1.1435 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.06084, evals: 151, done: 1, feasible: 0, sos: 0.471381, f: 0, ineq: 0.0342111, eq: 0.594454 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
# ...
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086328, evals: 200, done: 1, feasible: 0, sos: 0.417394, f: 0, ineq: 0.0286925, eq: 1.13887 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.085977, evals: 200, done: 1, feasible: 0, sos: 0.313468, f: 0, ineq: 0.037051, eq: 1.16254 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.080619, evals: 201, done: 1, feasible: 0, sos: 0.4723, f: 0, ineq: 0.0348393, eq: 0.593155 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083083, evals: 201, done: 1, feasible: 0, sos: 0.311588, f: 0, ineq: 0.0343975, eq: 1.15952 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.069358, evals: 171, done: 1, feasible: 0, sos: 0.474668, f: 0, ineq: 0.0332645, eq: 0.586933 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082248, evals: 200, done: 1, feasible: 0, sos: 0.31097, f: 0, ineq: 0.0273527, eq: 1.17378 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083595, evals: 201, done: 1, feasible: 0, sos: 0.310886, f: 0, ineq: 0.0334469, eq: 1.17073 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083194, evals: 201, done: 1, feasible: 0, sos: 0.414998, f: 0, ineq: 0.0327068, eq: 1.15017 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086948, evals: 200, done: 1, feasible: 0, sos: 0.415244, f: 0, ineq: 0.0333257, eq: 1.1501 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083546, evals: 201, done: 1, feasible: 0, sos: 0.313287, f: 0, ineq: 0.0206786, eq: 1.17931 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082446, evals: 200, done: 1, feasible: 0, sos: 0.310567, f: 0, ineq: 0.0285099, eq: 1.16775 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087164, evals: 201, done: 1, feasible: 0, sos: 0.417639, f: 0, ineq: 0.0311335, eq: 1.1393 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084484, evals: 200, done: 1, feasible: 0, sos: 0.415629, f: 0, ineq: 0.0317911, eq: 1.14947 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086047, evals: 201, done: 1, feasible: 0, sos: 0.416553, f: 0, ineq: 0.0301927, eq: 1.14246 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.084527, evals: 200, done: 1, feasible: 0, sos: 0.414786, f: 0, ineq: 0.0350356, eq: 1.15383 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.068193, evals: 166, done: 1, feasible: 0, sos: 0.473488, f: 0, ineq: 0.0356653, eq: 0.596133 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081077, evals: 201, done: 1, feasible: 0, sos: 0.398556, f: 0, ineq: 0.0574188, eq: 1.17166 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085501, evals: 201, done: 1, feasible: 0, sos: 0.417369, f: 0, ineq: 0.0294693, eq: 1.13886 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082711, evals: 200, done: 1, feasible: 0, sos: 0.311478, f: 0, ineq: 0.0260131, eq: 1.20514 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.081121, evals: 201, done: 1, feasible: 0, sos: 0.474359, f: 0, ineq: 0.036543, eq: 0.594097 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.057244, evals: 140, done: 1, feasible: 0, sos: 0.474573, f: 0, ineq: 0.0323825, eq: 0.600937 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.069372, evals: 171, done: 1, feasible: 0, sos: 0.47305, f: 0, ineq: 0.0338476, eq: 0.591849 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082298, evals: 200, done: 1, feasible: 0, sos: 0.312502, f: 0, ineq: 0.0208343, eq: 1.19848 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082186, evals: 201, done: 1, feasible: 0, sos: 0.310438, f: 0, ineq: 0.0331392, eq: 1.17824 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.057633, evals: 140, done: 1, feasible: 0, sos: 0.397069, f: 0, ineq: 0.0571561, eq: 1.17955 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083843, evals: 200, done: 1, feasible: 0, sos: 0.310536, f: 0, ineq: 0.0269131, eq: 1.15972 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082942, evals: 200, done: 1, feasible: 0, sos: 0.312372, f: 0, ineq: 0.0340568, eq: 1.15269 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083468, evals: 200, done: 1, feasible: 0, sos: 0.311838, f: 0, ineq: 0.0246543, eq: 1.16508 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.086976, evals: 200, done: 1, feasible: 0, sos: 0.416548, f: 0, ineq: 0.0307731, eq: 1.14283 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.084743, evals: 201, done: 1, feasible: 0, sos: 0.311603, f: 0, ineq: 0.0313285, eq: 1.15732 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.085746, evals: 201, done: 1, feasible: 0, sos: 0.415586, f: 0, ineq: 0.03197, eq: 1.14749 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.08307, evals: 201, done: 1, feasible: 0, sos: 0.311653, f: 0, ineq: 0.0320378, eq: 1.16543 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.072288, evals: 177, done: 1, feasible: 0, sos: 0.475297, f: 0, ineq: 0.0372911, eq: 0.581823 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.063841, evals: 156, done: 1, feasible: 0, sos: 0.474126, f: 0, ineq: 0.0370049, eq: 0.587595 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079951, evals: 200, done: 1, feasible: 0, sos: 0.422584, f: 0, ineq: 0.0575298, eq: 0.799257 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.079907, evals: 199, done: 1, feasible: 0, sos: 0.474576, f: 0, ineq: 0.0360941, eq: 0.593592 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082193, evals: 201, done: 1, feasible: 0, sos: 0.312639, f: 0, ineq: 0.0257092, eq: 1.15337 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08367, evals: 200, done: 1, feasible: 0, sos: 0.417205, f: 0, ineq: 0.0320154, eq: 1.13944 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.07537, evals: 187, done: 1, feasible: 0, sos: 0.474779, f: 0, ineq: 0.0339867, eq: 0.587215 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082202, evals: 200, done: 1, feasible: 0, sos: 0.311434, f: 0, ineq: 0.0246759, eq: 1.15678 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.082879, evals: 200, done: 1, feasible: 0, sos: 0.311836, f: 0, ineq: 0.0259442, eq: 1.17476 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.083332, evals: 201, done: 1, feasible: 0, sos: 0.312578, f: 0, ineq: 0.0293178, eq: 1.1646 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.091158, evals: 201, done: 1, feasible: 0, sos: 0.313163, f: 0, ineq: 0.0289469, eq: 1.16274 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088187, evals: 201, done: 1, feasible: 0, sos: 0.312568, f: 0, ineq: 0.031642, eq: 1.19264 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.087106, evals: 200, done: 1, feasible: 0, sos: 0.310857, f: 0, ineq: 0.0288591, eq: 1.17208 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087957, evals: 200, done: 1, feasible: 0, sos: 0.39473, f: 0, ineq: 0.0855339, eq: 1.27722 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.088933, evals: 201, done: 1, feasible: 0, sos: 0.311778, f: 0, ineq: 0.0295818, eq: 1.15409 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.08766, evals: 201, done: 1, feasible: 0, sos: 0.474421, f: 0, ineq: 0.0367553, eq: 0.592416 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
#   -- infeasible:placement 2: grasp x place z
#      { time: 0.033282, evals: 74, done: 1, feasible: 0, sos: 0.310385, f: 0, ineq: 0.032453, eq: 1.16862 }
# Failed placing block number 3 with grasp direction x at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087417, evals: 201, done: 1, feasible: 0, sos: 0.417717, f: 0, ineq: 0.0298177, eq: 1.13654 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.083748, evals: 200, done: 1, feasible: 0, sos: 0.46807, f: 0, ineq: 0.0242748, eq: 0.617541 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp y place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: y
#   -- infeasible:placement 2: grasp y place z
#      { time: 0.087361, evals: 201, done: 1, feasible: 0, sos: 0.418438, f: 0, ineq: 0.0329828, eq: 1.13488 }
# Failed placing block number 3 with grasp direction y at M :(
# === placement 2: grasp x place z
# place direction: z
# 3rd Block: (box1)
# Grasp Direction: x
